# %% [markdown]
# ## Prepaiting data and training CRF

# %%
# %load_ext autoreload
# %autoreload 2

import os
os.environ['CUDA_VISIBLE_DEVICES'] = '3'

import sys

# %%
import torch

device = torch.device('cuda')
for i in range(torch.cuda.device_count()):
    print(torch.cuda.get_device_name(i))
# Out:
# GeForce RTX 2080 Ti

# %%
import pandas as pd
import numpy as np
from tqdm import tqdm_notebook as tqdm
import json

# %%
# !pip install sklearn_crfsuite
# Out:
# Requirement already satisfied: sklearn_crfsuite in /opt/.pyenv/versions/3.7.4/lib/python3.7/site-packages (0.3.6)
# Requirement already satisfied: tqdm>=2.0 in /opt/.pyenv/versions/3.7.4/lib/python3.7/site-packages (from sklearn_crfsuite) (4.38.0)
# Requirement already satisfied: python-crfsuite>=0.8.3 in /opt/.pyenv/versions/3.7.4/lib/python3.7/site-packages (from sklearn_crfsuite) (0.9.6)
# Requirement already satisfied: tabulate in /opt/.pyenv/versions/3.7.4/lib/python3.7/site-packages (from sklearn_crfsuite) (0.8.6)
# Requirement already satisfied: six in /opt/.pyenv/versions/3.7.4/lib/python3.7/site-packages (from sklearn_crfsuite) (1.13.0)
# WARNING: You are using pip version 19.3.1; however, version 20.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
from logger import initialize_logger
logger = initialize_logger('../workdir/logs/biomed_ie.log', 'biomed_ie')

# %%
from itertools import chain

import nltk
import sklearn
import scipy.stats
from sklearn.metrics import make_scorer
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RandomizedSearchCV

import sklearn_crfsuite
from sklearn_crfsuite import scorers
from sklearn_crfsuite import metrics
from pytorch_transformers import AdamW, WarmupLinearSchedule

# %%
# !pip install pyprind
# Out:
# Requirement already satisfied: pyprind in /opt/.pyenv/versions/3.7.4/lib/python3.7/site-packages (2.11.2)
# WARNING: You are using pip version 19.3.1; however, version 20.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import math
import warnings
import pyprind

# %%
ner_data = pd.read_csv("../data/conll2003/eng.train.txt", sep=" ", header=None, skip_blank_lines=False, encoding="utf-8")
ner_data.columns = ["token", "pos", "chunk", "ne"]

# Explore the distribution of NE tags in the dataset
tag_distribution = ner_data.groupby("ne").size().reset_index(name='counts')
print(tag_distribution)
# Out:
#        ne  counts
# 0   B-LOC      11
# 1  B-MISC      37
# 2   B-ORG      24
# 3   I-LOC    8286
# 4  I-MISC    4556
# 5   I-ORG   10001
# 6   I-PER   11128
# 7       O  168346

# %%
classes = list(filter(lambda x: x not in ["O", np.nan], list(ner_data["ne"].unique())))
print(classes)
# Out:
# ['I-ORG', 'I-MISC', 'I-PER', 'I-LOC', 'B-LOC', 'B-MISC', 'B-ORG']

# %%
sentences, sentence = [], []
pbar = pyprind.ProgBar(len(ner_data))

for index, row in ner_data.iterrows():
    # If the row is empty (no string in the token column)
    if type(row["token"]) != str:
        # If the current sentence is not empty, append it to the sentences and create a new sentence
        if len(sentence) > 0:
            sentences.append(sentence)
            sentence = []
    else:
        # If the row does not indicate the start of a document, add the token to the current sentence
        if type(row["token"]) != float and type(row["pos"]) != float and type(row["ne"]) != float:
            if not row["token"].startswith("-DOCSTART-"):
                sentence.append([row["token"], row["pos"], row["chunk"], row["ne"]])
    pbar.update()
# Out:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:31

# %%
def word_features(sentence, i, use_chunks=False):
    # Get the current word and POS
    word = sentence[i][0]
    pos = sentence[i][1]
    
    features = { "bias": 1.0,
                 "word.lower()": word.lower(),
                 "word[-3:]": word[-3:],
                 "word[-2:]": word[-2:],
                 "word.isupper()": word.isupper(),
                 "word.istitle()": word.istitle(),
                 "word.isdigit()": word.isdigit(),
                 "pos": pos,
                 "pos[:2]": pos[:2],
               }
    # If chunks are being used, add the current chunk to the feature dictionary
    if use_chunks:
        chunk = sentence[i][2]
        features.update({ "chunk": chunk })
    # If this is not the first word in the sentence...
    if i > 0:
        # Get the sentence's previous word and POS
        prev_word = sentence[i-1][0]
        prev_pos = sentence[i-1][1]
        # Add characteristics of the sentence's previous word and POS to the feature dictionary
        features.update({ "-1:word.lower()": prev_word.lower(),
                          "-1:word.istitle()": prev_word.istitle(),
                          "-1:word.isupper()": prev_word.isupper(),
                          "-1:pos": prev_pos,
                          "-1:pos[:2]": prev_pos[:2],
                        })
        # If chunks are being used, add the previous chunk to the feature dictionary
        if use_chunks:
            prev_chunk = sentence[i-1][2]
            features.update({ "-1:chunk": prev_chunk })
    # Otherwise, add 'BOS' (beginning of sentence) to the feature dictionary
    else:
        features["BOS"] = True
    # If this is not the last word in the sentence...
    if i < len(sentence)-1:
        # Get the sentence's next word and POS
        next_word = sentence[i+1][0]
        next_pos = sentence[i+1][1]
        # Add characteristics of the sentence's previous next and POS to the feature dictionary
        features.update({ "+1:word.lower()": next_word.lower(),
                          "+1:word.istitle()": next_word.istitle(),
                          "+1:word.isupper()": next_word.isupper(),
                          "+1:pos": next_pos,
                          "+1:pos[:2]": next_pos[:2],
                        })
        # If chunks are being used, add the next chunk to the feature dictionary
        if use_chunks:
            next_chunk = sentence[i+1][2]
            features.update({ "+1:chunk": next_chunk })
    # Otherwise, add 'EOS' (end of sentence) to the feature dictionary
    else:
        features["EOS"] = True
    # Return the feature dictionary
    return features

# %%
def sentence_features(sentence, use_chunks=False):
    return [word_features(sentence, i, use_chunks) for i in range(len(sentence))]

# Return the label (NER tag) for each word in a given sentence
def sentence_labels(sentence):
    return [label for token, pos, chunk, label in sentence]

# %%
from sklearn.model_selection import train_test_split
X = [sentence_features(sentence) for sentence in sentences]
y = [sentence_labels(sentence) for sentence in sentences]

# Split X and y into training (80%) and test (20%) sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

print("First token features:\n{}\n{}".format("-"*21, X_train[0][0]))
print("\nFirst token label:\n{}\n{}".format("-"*18, y_train[0][0]))
# Out:
# First token features:
# ---------------------
# {'bias': 1.0, 'word.lower()': 'the', 'word[-3:]': 'The', 'word[-2:]': 'he', 'word.isupper()': False, 'word.istitle()': True, 'word.isdigit()': False, 'pos': 'DT', 'pos[:2]': 'DT', 'BOS': True, '+1:word.lower()': 'entire', '+1:word.istitle()': False, '+1:word.isupper()': False, '+1:pos': 'JJ', '+1:pos[:2]': 'JJ'}
#
# First token label:
# ------------------
# O

# %%
for i in range(len(y_train)):
    y_train[i] = np.where(y_train[i] == 'B-LOC', 'I-LOC', y_train[i])
    y_train[i] = np.where(y_train[i] == 'B-LOC', 'I-LOC', y_train[i])
    y_train[i] = np.where(y_train[i] == 'B-MISC', 'I-MISC', y_train[i])
    y_train[i] = np.where(y_train[i] == 'B-ORG', 'I-ORG', y_train[i])
    
for i in range(len(y_test)):
    y_test[i] = np.where(y_test[i] == 'B-LOC', 'I-LOC', y_test[i])
    y_test[i] = np.where(y_test[i] == 'B-LOC', 'I-LOC', y_test[i])
    y_test[i] = np.where(y_test[i] == 'B-MISC', 'I-MISC', y_test[i])
    y_test[i] = np.where(y_test[i] == 'B-ORG', 'I-ORG', y_test[i])

# %%
X_lens = [len(X_train[i]) for i in range(len(X_train))]
y_lens = [len(y_train[i]) for i in range(len(y_train))]
X_lens == y_lens
# Out:
# True

# %%
X_lens = [len(X_test[i]) for i in range(len(X_test))]
y_lens = [len(y_test[i]) for i in range(len(y_test))]
X_lens == y_lens
# Out:
# True

# %%
crf = sklearn_crfsuite.CRF(algorithm="lbfgs",
          c1=0.1,
          c2=0.1,
          max_iterations=100,
          all_possible_transitions=True)

# Train the CRF model on the supplied training data
# %timeit crf.fit(X_train, y_train)
# Out:
# 20.6 s ± 68 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
classes = ['I-ORG', 'I-MISC', 'I-PER', 'I-LOC']
y_pred = crf.predict(X_test)
print(metrics.flat_classification_report(y_test, y_pred, labels=classes))
# Out:
#               precision    recall  f1-score   support
#
#        I-ORG       0.90      0.87      0.89      2090
#       I-MISC       0.93      0.84      0.88       937
#        I-PER       0.93      0.94      0.94      2220
#        I-LOC       0.91      0.92      0.92      1616
#
#    micro avg       0.92      0.90      0.91      6863
#    macro avg       0.92      0.90      0.91      6863
# weighted avg       0.92      0.90      0.91      6863

# %% [markdown]
# ## AL setup

# %%
#!pip install seqeval

# %%
#!pip uninstall -y libact
#!pip install git+https://github.com/IINemo/libact.git@seq

# %%
#!pip uninstall -y actleto
#!pip install git+https://github.com/IINemo/active_learning_toolbox.git@seq

# %%
#!pip install git+https://github.com/IINemo/bert_sequence_tagger.git

# %%
#!pip install flair
# Out:
# [autoreload of _pytest.assertion failed: Traceback (most recent call last):
#   File "/opt/.pyenv/versions/3.7.4/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/opt/.pyenv/versions/3.7.4/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/opt/.pyenv/versions/3.7.4/lib/python3.7/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/opt/.pyenv/versions/3.7.4/lib/python3.7/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/opt/.pyenv/versions/3.7.4/lib/python3.7/site-packages/_pytest/assertion/__init__.py", line 12, in <module>
#     from _pytest.assertion.rewrite import assertstate_key
# ImportError: cannot import name 'assertstate_key' from '_pytest.assertion.rewrite' (/opt/.pyenv/versions/3.7.4/lib/python3.7/site-packages/_pytest/assertion/rewrite.py)
# ]
# [autoreload of _pytest.assertion.rewrite failed: Traceback (most recent call last):
#   File "/opt/.pyenv/versions/3.7.4/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/opt/.pyenv/versions/3.7.4/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/opt/.pyenv/versions/3.7.4/lib/python3.7/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/opt/.pyenv/versions/3.7.4/lib/python3.7/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/opt/.pyenv/versions/3.7.4/lib/python3.7/site-packages/_pytest/assertion/rewrite.py", line 28, in <module>
#     from _pytest.compat import fspath
# ImportError: cannot import name 'fspath' from '_pytest.compat' (/opt/.pyenv/versions/3.7.4/lib/python3.7/site-packages/_pytest/compat.py)
# ]
# [autoreload of _pytest._code.code failed: Traceback (most recent call last):
#   File "/opt/.pyenv/versions/3.7.4/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/opt/.pyenv/versions/3.7.4/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/opt/.pyenv/versions/3.7.4/lib/python3.7/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/opt/.pyenv/versions/3.7.4/lib/python3.7/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/opt/.pyenv/versions/3.7.4/lib/python3.7/site-packages/_pytest/_code/code.py", line 36, in <module>
#     from _pytest.compat import TYPE_CHECKING
# ImportError: cannot import name 'TYPE_CHECKING' from '_pytest.compat' (/opt/.pyenv/versions/3.7.4/lib/python3.7/site-packages/_pytest/compat.py)
# ]
# [autoreload of _pytest._code.source failed: Traceback (most recent call last):
#   File "/opt/.pyenv/versions/3.7.4/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/opt/.pyenv/versions/3.7.4/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/opt/.pyenv/versions/3.7.4/lib/python3.7/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/opt/.pyenv/versions/3.7.4/lib/python3.7/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/opt/.pyenv/versions/3.7.4/lib/python3.7/site-packages/_pytest/_code/source.py", line 23, in <module>
#     from _pytest.compat import TYPE_CHECKING
# ImportError: cannot import name 'TYPE_CHECKING' from '_pytest.compat' (/opt/.pyenv/versions/3.7.4/lib/python3.7/site-packages/_pytest/compat.py)
# ]
# [autoreload of _pytest.fixtures failed: Traceback (most recent call last):
#   File "/opt/.pyenv/versions/3.7.4/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/opt/.pyenv/versions/3.7.4/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/opt/.pyenv/versions/3.7.4/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/opt/.pyenv/versions/3.7.4/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 317, in update_class
#     update_instances(old, new)
#   File "/opt/.pyenv/versions/3.7.4/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 280, in update_instances
#     ref.__class__ = new
#   File "/opt/.pyenv/versions/3.7.4/lib/python3.7/site-packages/attr/_make.py", line 419, in _frozen_setattrs
#     raise FrozenInstanceError()
# attr.exceptions.FrozenInstanceError
# ]
# [autoreload of _pytest.mark.structures failed: Traceback (most recent call last):
#   File "/opt/.pyenv/versions/3.7.4/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/opt/.pyenv/versions/3.7.4/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/opt/.pyenv/versions/3.7.4/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/opt/.pyenv/versions/3.7.4/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 317, in update_class
#     update_instances(old, new)
#   File "/opt/.pyenv/versions/3.7.4/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 280, in update_instances
#     ref.__class__ = new
#   File "/opt/.pyenv/versions/3.7.4/lib/python3.7/site-packages/attr/_make.py", line 419, in _frozen_setattrs
#     raise FrozenInstanceError()
# attr.exceptions.FrozenInstanceError
# ]
# [autoreload of _pytest.main failed: Traceback (most recent call last):
#   File "/opt/.pyenv/versions/3.7.4/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/opt/.pyenv/versions/3.7.4/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/opt/.pyenv/versions/3.7.4/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/opt/.pyenv/versions/3.7.4/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/opt/.pyenv/versions/3.7.4/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/opt/.pyenv/versions/3.7.4/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: gethookproxy() requires a code object with 0 free vars, not 1
# ]
# [autoreload of _pytest.python failed: Traceback (most recent call last):
#   File "/opt/.pyenv/versions/3.7.4/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/opt/.pyenv/versions/3.7.4/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/opt/.pyenv/versions/3.7.4/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/opt/.pyenv/versions/3.7.4/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/opt/.pyenv/versions/3.7.4/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/opt/.pyenv/versions/3.7.4/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: gethookproxy() requires a code object with 0 free vars, not 1
# ]
# [autoreload of _pytest.python_api failed: Traceback (most recent call last):
#   File "/opt/.pyenv/versions/3.7.4/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/opt/.pyenv/versions/3.7.4/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/opt/.pyenv/versions/3.7.4/lib/python3.7/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/opt/.pyenv/versions/3.7.4/lib/python3.7/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/opt/.pyenv/versions/3.7.4/lib/python3.7/site-packages/_pytest/python_api.py", line 561, in <module>
#     ) -> _pytest._code.ExceptionInfo[_E]:
# AttributeError: module '_pytest' has no attribute '_code'
# ]
# [autoreload of urllib3.packages.six failed: Traceback (most recent call last):
#   File "/opt/.pyenv/versions/3.7.4/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/opt/.pyenv/versions/3.7.4/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/opt/.pyenv/versions/3.7.4/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/opt/.pyenv/versions/3.7.4/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 287, in update_class
#     old_obj = getattr(old, key)
#   File "/opt/.pyenv/versions/3.7.4/lib/python3.7/site-packages/urllib3/packages/six.py", line 93, in __get__
#     setattr(obj, self.name, result)  # Invokes __set__.
# AttributeError: 'NoneType' object has no attribute 'cStringIO'
# ]

# %%
import click
import pandas as pd
import numpy as np
import itertools
import os
import re
import torch
#from seqeval.metrics import f1_score

from libact.query_strategies import UncertaintySampling, RandomSampling
from active_learning_seq import RandomSamplingWithRetraining

from actleto import ActiveLearner, make_libact_strategy_ctor

from libact.base.dataset import Dataset

from biomed_ie.packages.vadim_ml.memoize import memoize
from biomed_ie.packages.vadim_ml.io import load_file, dump_file

from flair_libact import PositiveLessCertain

# %%
def append_to_file(path, val):
    with open(path, 'a') as f:
        print(str(val), file=f, end='\n')

# %%
from libact.base.interfaces import ProbabilisticModel

class CRF_active(ProbabilisticModel):

    def __init__(self, *args, **kwargs):
        self.model = sklearn_crfsuite.CRF(*args, **kwargs)

    def train(self, libact_dataset, indexes=None):
        if indexes is not None:
            libact_dataset = Dataset([libact_dataset.data[i][0] for i in indexes], 
                                     [libact_dataset.data[i][1] for i in indexes])

        X, y = libact_dataset.format_sklearn()
        return self.model.fit(X, y)

    def predict(self, feature, *args, **kwargs):
        pred = self.model.predict(feature, *args, **kwargs)
        #pred_list = list(map(list, pred))
        #print(pred_list[0])
        return pred

    def score(self, X, y, *args, **kwargs):
        #return self.model.score(X, y, **kwargs)
        pass

    def predict_proba(self, X, *args, **kwargs):
        #all_labels = self.model.predict_marginals(X, *args, **kwargs)
        #return [[max(dict_.values()) for dict_ in l] for l in all_labels]
        all_labels = self.model.predict_marginals(X, *args, **kwargs)
        #maxlen = max(map(len, all_labels))
        #out = [np.mean(np.log([max(dict_.values()) for dict_ in l])) for l in all_labels]
        #print([[dict_.values() for dict_ in l] for l in all_labels][0])
        #print([[max(dict_.values()) for dict_ in l] for l in all_labels][0])
        out = [np.mean([max(dict_.values()) for dict_ in l]) for l in all_labels]

        return np.array(out).reshape(-1, 1)

    
    #def fit(self, libact_dataset, *args, **kwargs):
        #dataset = libact_dataset.format_sklearn()
        #return self.model.fit(dataset, **kwargs)

# %%
class ActiveLearner1(object):
    """The class that implements active learning logic."""
    
    def __init__(self, 
                 active_learn_alg_ctor,
                 X_full_dataset, 
                 y_dtype='int',
                 y_full_dataset = None, 
                 model_evaluate = None,
                 X_test_dataset = None,
                 y_test_dataset = None,
                 eval_metrics = None,
                 rnd_start_steps = 0,
                 rnd_start_samples = 10): 
        """ActiveLearner constructor.
        
        Args:
            active_learn_alg_ctor (functor): functor object that returns active learning strategy.
            X_full_dataset (np.array or sparse matrix): feature matrix.
            y_dtype: type of y labels.
            y_full_dataset (np.array): known answers (e.g., None -- unknown, True -- positive class, False -- negative class) 
            model_evaluate: the model that will be evaluated on the holdout.
            X_test_dataset: feature matrix for testing via holdout.
            y_test_dataset: y labels for testing via holdout.
            eval_metrics (list): list of sklearn evaluation metrics.
            rnd_start_steps: AL will can make several seed steps by choosing random samples (without model suggestions).
            logger (logging.Logger): the object for logging.
            
        """
        super().__init__()
        
        self._y_dtype = y_dtype
        self._model_evaluate = model_evaluate
        self._eval_metrics = eval_metrics
        
        self._X_full_dataset = X_full_dataset
        if y_full_dataset is not None:
            self._y_full_dataset = y_full_dataset # TODO: validate dimentions
        else:
            self._y_full_dataset = [None] * self._X_full_dataset.shape[0]
            
        self._active_learn_algorithm = active_learn_alg_ctor(self._X_full_dataset, 
                                                             self._y_full_dataset)
        
        self._X_test_dataset = X_test_dataset
        self._y_test_dataset = y_test_dataset
        
        self._iteration_num = 0
        self._rnd_start_steps = rnd_start_steps
        self._rnd_start_samples = rnd_start_samples

    def _select_unannotated(self, labels):
        return np.where([(e is None) for e in labels])[0]
    
    def start(self):
        self._active_learn_algorithm.start()

    def choose_random_sample_for_annotation(self, number):
        return np.random.choice(self._select_unannotated(self._y_full_dataset), 
                                size = number, 
                                replace = False)
        
    def choose_samples_for_annotation(self):
        if self._iteration_num < self._rnd_start_steps:
            return self.choose_random_sample_for_annotation(self._rnd_start_samples)
        else:
            return self._active_learn_algorithm.choose_samples_for_annotation()
    
    def evaluate(self, fit_model=True):
        if self._model_evaluate is None:
            return None
        
        if fit_model:
            selector = [False for _ in range(len(self._y_full_dataset))]
            for ind, answ in enumerate(self._y_full_dataset):
                if answ is None:
                    selector[ind] = False
                elif all(e is None for e in self._y_full_dataset):
                    selector[ind] = False
                else:
                    selector[ind] = True
            
            y_fit = np.array(self._y_full_dataset)[selector]
            #y_fit = [e for e in self._y_full_dataset if e is not None]
            #y_fit = pd.Series(self._y_full_dataset)
            #y_fit = y_fit[y_fit.notnull()].astype(self._y_dtype)
            
            logger.info('Number of training samples: {}'.format(len(y_fit)))
            
            self._model_evaluate.train(Dataset(self._X_full_dataset, self._y_full_dataset), np.ravel(np.argwhere(np.array(selector) == True)))
        
        preds = self._model_evaluate.predict(self._X_test_dataset)
        return {metric.__name__ : metric(preds, self._y_test_dataset) 
                for metric in self._eval_metrics}
    
    def get_annotation(self):
        return self._y_full_dataset
    
    def make_iteration(self, indexes, answers):
        self._iteration_num += 1
        
        selector = [False for _ in range(answers.shape[0])]
        for ind, answ in enumerate(answers):
            if answ is None:
                selector[ind] = False
            elif all(e is None for e in answ):
                selector[ind] = False
            else:
                selector[ind] = True
                
        #selector = ((answers == np.array(None)).sum(axis=1) == 0)
        answers = answers[selector]
        indexes = np.array(indexes)[selector]
        #print(indexes)
#         with open('tmp_log.log', 'w') as f:
#             f.write(str(indexes))
        for num, i in enumerate(indexes):
            self._y_full_dataset[i] = answers[num]

        return self._active_learn_algorithm.make_iteration(indexes, answers)

# %%
def emulate_active_learning(train_tags, active_learner, 
                            max_iterations=12, 
                           fit_model=False):
    print('Start emulating active learning.')
    active_learner.start()
    print('Evaluation:', active_learner.evaluate(fit_model=False))

    statistics = []
    for i in range(max_iterations):
        print('Active learning iteration: #{}'.format(i))
        samples_to_annotate = active_learner.choose_samples_for_annotation()
        annotations = np.array([train_tags[idx] for idx in samples_to_annotate])
        #print(len(annotations))
        active_learner.make_iteration(samples_to_annotate, annotations)
        perf = active_learner.evaluate(fit_model=True)
        statistics.append(perf)
        print('Performance:', perf)
    
    return statistics

# %%
def y_train2y_seed(y_train, n_seeds_per_class=10):
    y_vals = set(tag for row in y_train for tag in row)
    
    indexes = np.array(range(len(y_train)))
    known_indexes = []
    for label in y_vals:
        selected_indices = indexes[[label in y for y in y_train]]
        known_indexes += list(np.random.choice(selected_indices, size=n_seeds_per_class))

    known_indexes = list(set(known_indexes))
    tags_seed = [None for _ in range(len(y_train))]

    for i in known_indexes:
        tags_seed[i] = y_train[i]

    Y_seed = tags_seed
    
    return Y_seed

# %%
"""Metrics to assess performance on sequence labeling task given prediction
Functions named as ``*_score`` return a scalar value to maximize: the higher
the better
"""

from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

from collections import defaultdict

import numpy as np

def get_entities(seq, suffix=False):
    """Gets entities from sequence.
    Args:
        seq (list): sequence of labels.
    Returns:
        list: list of (chunk_type, chunk_start, chunk_end).
    Example:
        >>> from seqeval.metrics.sequence_labeling import get_entities
        >>> seq = ['B-PER', 'I-PER', 'O', 'B-LOC']
        >>> get_entities(seq)
        [('PER', 0, 1), ('LOC', 3, 3)]
    """
            
    if any(isinstance(s, list) for s in seq):
        seq = [item for sublist in seq for item in sublist + ['O']]

    prev_tag = 'O'
    prev_type = ''
    begin_offset = 0
    chunks = []
    for i, chunk in enumerate(seq + ['O']):
        if suffix:
            tag = chunk[-1]
            type_ = chunk.split('-')[0]
        else:
            tag = chunk[0]
            type_ = chunk.split('-')[-1]

        if end_of_chunk(prev_tag, tag, prev_type, type_):
            chunks.append((prev_type, begin_offset, i-1))
        if start_of_chunk(prev_tag, tag, prev_type, type_):
            begin_offset = i
        prev_tag = tag
        prev_type = type_

    return chunks


def end_of_chunk(prev_tag, tag, prev_type, type_):
    """Checks if a chunk ended between the previous and current word.
    Args:
        prev_tag: previous chunk tag.
        tag: current chunk tag.
        prev_type: previous type.
        type_: current type.
    Returns:
        chunk_end: boolean.
    """
    chunk_end = False

    if prev_tag == 'E': chunk_end = True
    if prev_tag == 'S': chunk_end = True

    if prev_tag == 'B' and tag == 'B': chunk_end = True
    if prev_tag == 'B' and tag == 'S': chunk_end = True
    if prev_tag == 'B' and tag == 'O': chunk_end = True
    if prev_tag == 'I' and tag == 'B': chunk_end = True
    if prev_tag == 'I' and tag == 'S': chunk_end = True
    if prev_tag == 'I' and tag == 'O': chunk_end = True

    if prev_tag != 'O' and prev_tag != '.' and prev_type != type_:
        chunk_end = True

    return chunk_end


def start_of_chunk(prev_tag, tag, prev_type, type_):
    """Checks if a chunk started between the previous and current word.
    Args:
        prev_tag: previous chunk tag.
        tag: current chunk tag.
        prev_type: previous type.
        type_: current type.
    Returns:
        chunk_start: boolean.
    """
    chunk_start = False

    if tag == 'B': chunk_start = True
    if tag == 'S': chunk_start = True

    if prev_tag == 'E' and tag == 'E': chunk_start = True
    if prev_tag == 'E' and tag == 'I': chunk_start = True
    if prev_tag == 'S' and tag == 'E': chunk_start = True
    if prev_tag == 'S' and tag == 'I': chunk_start = True
    if prev_tag == 'O' and tag == 'E': chunk_start = True
    if prev_tag == 'O' and tag == 'I': chunk_start = True

    if tag != 'O' and tag != '.' and prev_type != type_:
        chunk_start = True

    return chunk_start


def f1_score(y_true, y_pred, average='micro', suffix=False):
    """Compute the F1 score.
    The F1 score can be interpreted as a weighted average of the precision and
    recall, where an F1 score reaches its best value at 1 and worst score at 0.
    The relative contribution of precision and recall to the F1 score are
    equal. The formula for the F1 score is::
        F1 = 2 * (precision * recall) / (precision + recall)
    Args:
        y_true : 2d array. Ground truth (correct) target values.
        y_pred : 2d array. Estimated targets as returned by a tagger.
    Returns:
        score : float.
    Example:
        >>> from seqeval.metrics import f1_score
        >>> y_true = [['O', 'O', 'O', 'B-MISC', 'I-MISC', 'I-MISC', 'O'], ['B-PER', 'I-PER', 'O']]
        >>> y_pred = [['O', 'O', 'B-MISC', 'I-MISC', 'I-MISC', 'I-MISC', 'O'], ['B-PER', 'I-PER', 'O']]
        >>> f1_score(y_true, y_pred)
        0.50
    """
    true_entities = set(get_entities(y_true, suffix))
    y_pred = list(map(list, y_pred))
    pred_entities = set(get_entities(y_pred, suffix))
    
    nb_correct = len(true_entities & pred_entities)
    nb_pred = len(pred_entities)
    nb_true = len(true_entities)

    p = nb_correct / nb_pred if nb_pred > 0 else 0
    r = nb_correct / nb_true if nb_true > 0 else 0
    score = 2 * p * r / (p + r) if p + r > 0 else 0
    

    return score

# %%
strategies_to_try = {
    'uncertainty': lambda trn_ds, libact_model: UncertaintySampling(trn_ds, model=libact_model, method='lc'),
    'random': lambda trn_ds, libact_model: RandomSamplingWithRetraining(trn_ds, model=libact_model, method='lc'),
    #'positivelesscertain': lambda tr_ds, libact_model: UncertaintySampling(tr_ds, model=PositiveLessCertain(libact_model), method='lc')
}

# %%
max_samples_number = 30
repeats = 10
active_iterations = 25
N_SAMPLES_PER_AL_ITER = 100

for repeat in range(repeats):
    for strat_name, strat in strategies_to_try.items():
        
        path = os.path.join('../workdir/experiments/crf_10/', strat_name)
        if os.path.exists(os.path.join(path, f'statistics{repeat}.json')):
            print(f'statistics{repeat}.json already exists. Next')
            continue
    
        print('Active learning strategy', strat_name)
        print('Repeat', repeat)
    
        y_seed = y_train2y_seed(y_train, n_seeds_per_class=10)
    
        active_tagger = CRF_active(algorithm="lbfgs",
              c1=0.1,
              c2=0.1,
              max_iterations=100,
              all_possible_transitions=True)
        
        active_learn_alg_ctor = make_libact_strategy_ctor(lambda tr_ds: strat(tr_ds, active_tagger), max_samples_number=max_samples_number)
        
        active_learner = ActiveLearner1(active_learn_alg_ctor = active_learn_alg_ctor,
                                y_dtype = 'str',
                                X_full_dataset = X_train, 
                                y_full_dataset = y_seed,
                                X_test_dataset = X_test,
                                y_test_dataset = y_test,
                                model_evaluate=active_tagger,
                                eval_metrics=[f1_score],
                                rnd_start_steps=0,
                                rnd_start_samples=max_samples_number)                
            
        statistics = emulate_active_learning(y_train, active_learner, max_iterations=active_iterations)
        dump_file(statistics, path, f'statistics{repeat}.json')
# Out:
# Active learning strategy uncertainty
# Repeat 0
# Start emulating active learning.
# Evaluation: {'f1_score': 0.5201897733263047}
# Active learning iteration: #0
# 2020-04-01 10:07:14,173 - biomed_ie - INFO - Number of training samples: 80
# Performance: {'f1_score': 0.517909957279001}
# Active learning iteration: #1
# 2020-04-01 10:07:17,330 - biomed_ie - INFO - Number of training samples: 110
# Performance: {'f1_score': 0.5318376773342133}
# Active learning iteration: #2
# 2020-04-01 10:07:20,687 - biomed_ie - INFO - Number of training samples: 140
# Performance: {'f1_score': 0.5454941227688288}
# Active learning iteration: #3
# 2020-04-01 10:07:23,962 - biomed_ie - INFO - Number of training samples: 170
# Performance: {'f1_score': 0.5449537241075364}
# Active learning iteration: #4
# 2020-04-01 10:07:27,204 - biomed_ie - INFO - Number of training samples: 200
# Performance: {'f1_score': 0.5403617115130128}
# Active learning iteration: #5
# 2020-04-01 10:07:30,589 - biomed_ie - INFO - Number of training samples: 230
# Performance: {'f1_score': 0.5515571695829207}
# Active learning iteration: #6
# 2020-04-01 10:07:33,829 - biomed_ie - INFO - Number of training samples: 260
# Performance: {'f1_score': 0.5507373981950252}
# Active learning iteration: #7
# 2020-04-01 10:07:37,088 - biomed_ie - INFO - Number of training samples: 290
# Performance: {'f1_score': 0.5558504755585048}
# Active learning iteration: #8
# 2020-04-01 10:07:40,508 - biomed_ie - INFO - Number of training samples: 320
# Performance: {'f1_score': 0.5622649856226498}
# Active learning iteration: #9
# 2020-04-01 10:07:43,857 - biomed_ie - INFO - Number of training samples: 350
# Performance: {'f1_score': 0.5694644639095243}
# Active learning iteration: #10
# 2020-04-01 10:07:47,218 - biomed_ie - INFO - Number of training samples: 380
# Performance: {'f1_score': 0.5886516978210375}
# Active learning iteration: #11
# 2020-04-01 10:07:50,570 - biomed_ie - INFO - Number of training samples: 410
# Performance: {'f1_score': 0.5978537448832836}
# Active learning iteration: #12
# 2020-04-01 10:07:54,099 - biomed_ie - INFO - Number of training samples: 440
# Performance: {'f1_score': 0.6072064056939502}
# Active learning iteration: #13
# 2020-04-01 10:07:57,488 - biomed_ie - INFO - Number of training samples: 470
# Performance: {'f1_score': 0.6145426114151681}
# Active learning iteration: #14
# 2020-04-01 10:08:00,920 - biomed_ie - INFO - Number of training samples: 500
# Performance: {'f1_score': 0.6207591535102451}
# Active learning iteration: #15
# 2020-04-01 10:08:04,353 - biomed_ie - INFO - Number of training samples: 530
# Performance: {'f1_score': 0.6190102120974077}
# Active learning iteration: #16
# 2020-04-01 10:08:07,941 - biomed_ie - INFO - Number of training samples: 560
# Performance: {'f1_score': 0.6232046678635549}
# Active learning iteration: #17
# 2020-04-01 10:08:11,418 - biomed_ie - INFO - Number of training samples: 590
# Performance: {'f1_score': 0.6264600179694519}
# Active learning iteration: #18
# 2020-04-01 10:08:14,900 - biomed_ie - INFO - Number of training samples: 620
# Performance: {'f1_score': 0.6361704507325802}
# Active learning iteration: #19
# 2020-04-01 10:08:18,537 - biomed_ie - INFO - Number of training samples: 650
# Performance: {'f1_score': 0.6476781558240055}
# Active learning iteration: #20
# 2020-04-01 10:08:22,076 - biomed_ie - INFO - Number of training samples: 680
# Performance: {'f1_score': 0.651142160124196}
# Active learning iteration: #21
# 2020-04-01 10:08:25,650 - biomed_ie - INFO - Number of training samples: 710
# Performance: {'f1_score': 0.6643835616438356}
# Active learning iteration: #22
# 2020-04-01 10:08:29,274 - biomed_ie - INFO - Number of training samples: 740
# Performance: {'f1_score': 0.6705099778270511}
# Active learning iteration: #23
# 2020-04-01 10:08:32,993 - biomed_ie - INFO - Number of training samples: 770
# Performance: {'f1_score': 0.6804878048780488}
# Active learning iteration: #24
# 2020-04-01 10:08:36,626 - biomed_ie - INFO - Number of training samples: 800
# Performance: {'f1_score': 0.6807149161518093}
# Active learning strategy random
# Repeat 0
# Start emulating active learning.
# Evaluation: {'f1_score': 0.5039965435299201}
# Active learning iteration: #0
# 2020-04-01 10:08:39,390 - biomed_ie - INFO - Number of training samples: 80
# Performance: {'f1_score': 0.5445175438596491}
# Active learning iteration: #1
# 2020-04-01 10:08:40,888 - biomed_ie - INFO - Number of training samples: 110
# Performance: {'f1_score': 0.5607186425640458}
# Active learning iteration: #2
# 2020-04-01 10:08:42,442 - biomed_ie - INFO - Number of training samples: 140
# Performance: {'f1_score': 0.5813163946993758}
# Active learning iteration: #3
# 2020-04-01 10:08:44,055 - biomed_ie - INFO - Number of training samples: 170
# Performance: {'f1_score': 0.59062296505318}
# Active learning iteration: #4
# 2020-04-01 10:08:45,714 - biomed_ie - INFO - Number of training samples: 200
# Performance: {'f1_score': 0.6095569826929357}
# Active learning iteration: #5
# 2020-04-01 10:08:47,327 - biomed_ie - INFO - Number of training samples: 230
# Performance: {'f1_score': 0.6203753932949984}
# Active learning iteration: #6
# 2020-04-01 10:08:49,053 - biomed_ie - INFO - Number of training samples: 260
# Performance: {'f1_score': 0.639392295170917}
# Active learning iteration: #7
# 2020-04-01 10:08:50,834 - biomed_ie - INFO - Number of training samples: 290
# Performance: {'f1_score': 0.6478199412852017}
# Active learning iteration: #8
# 2020-04-01 10:08:52,691 - biomed_ie - INFO - Number of training samples: 320
# Performance: {'f1_score': 0.6601647160814911}
# Active learning iteration: #9
# 2020-04-01 10:08:54,593 - biomed_ie - INFO - Number of training samples: 350
# Performance: {'f1_score': 0.6670278470040092}
# Active learning iteration: #10
# 2020-04-01 10:08:56,565 - biomed_ie - INFO - Number of training samples: 380
# Performance: {'f1_score': 0.6696989387047867}
# Active learning iteration: #11
# 2020-04-01 10:08:58,554 - biomed_ie - INFO - Number of training samples: 410
# Performance: {'f1_score': 0.6765565782349756}
# Active learning iteration: #12
# 2020-04-01 10:09:00,623 - biomed_ie - INFO - Number of training samples: 440
# Performance: {'f1_score': 0.6835607537361923}
# Active learning iteration: #13
# 2020-04-01 10:09:02,602 - biomed_ie - INFO - Number of training samples: 470
# Performance: {'f1_score': 0.6878870179250407}
# Active learning iteration: #14
# 2020-04-01 10:09:04,755 - biomed_ie - INFO - Number of training samples: 500
# Performance: {'f1_score': 0.6888696029507485}
# Active learning iteration: #15
# 2020-04-01 10:09:06,973 - biomed_ie - INFO - Number of training samples: 530
# Performance: {'f1_score': 0.6969434207673965}
# Active learning iteration: #16
# 2020-04-01 10:09:09,224 - biomed_ie - INFO - Number of training samples: 560
# Performance: {'f1_score': 0.6967700118828994}
# Active learning iteration: #17
# 2020-04-01 10:09:11,396 - biomed_ie - INFO - Number of training samples: 590
# Performance: {'f1_score': 0.7037317468902109}
# Active learning iteration: #18
# 2020-04-01 10:09:13,782 - biomed_ie - INFO - Number of training samples: 620
# Performance: {'f1_score': 0.7088197146562905}
# Active learning iteration: #19
# 2020-04-01 10:09:16,215 - biomed_ie - INFO - Number of training samples: 650
# Performance: {'f1_score': 0.7111495620201147}
# Active learning iteration: #20
# 2020-04-01 10:09:18,570 - biomed_ie - INFO - Number of training samples: 680
# Performance: {'f1_score': 0.7155191020936759}
# Active learning iteration: #21
# 2020-04-01 10:09:21,131 - biomed_ie - INFO - Number of training samples: 710
# Performance: {'f1_score': 0.7162147564005618}
# Active learning iteration: #22
# 2020-04-01 10:09:23,757 - biomed_ie - INFO - Number of training samples: 740
# Performance: {'f1_score': 0.7232432432432433}
# Active learning iteration: #23
# 2020-04-01 10:09:26,283 - biomed_ie - INFO - Number of training samples: 770
# Performance: {'f1_score': 0.7257383966244725}
# Active learning iteration: #24
# 2020-04-01 10:09:29,025 - biomed_ie - INFO - Number of training samples: 800
# Performance: {'f1_score': 0.7267617812364894}
# Active learning strategy uncertainty
# Repeat 1
# Start emulating active learning.
# Evaluation: {'f1_score': 0.5091658531294068}
# Active learning iteration: #0
# 2020-04-01 10:09:34,557 - biomed_ie - INFO - Number of training samples: 80
# Performance: {'f1_score': 0.5163348366516335}
# Active learning iteration: #1
# 2020-04-01 10:09:37,711 - biomed_ie - INFO - Number of training samples: 110
# Performance: {'f1_score': 0.5125440140845071}
# Active learning iteration: #2
# 2020-04-01 10:09:40,875 - biomed_ie - INFO - Number of training samples: 140
# Performance: {'f1_score': 0.5120614035087719}
# Active learning iteration: #3
# 2020-04-01 10:09:44,056 - biomed_ie - INFO - Number of training samples: 170
# Performance: {'f1_score': 0.5237674110103914}
# Active learning iteration: #4
# 2020-04-01 10:09:47,422 - biomed_ie - INFO - Number of training samples: 200
# Performance: {'f1_score': 0.5523370638578012}
# Active learning iteration: #5
# 2020-04-01 10:09:50,656 - biomed_ie - INFO - Number of training samples: 230
# Performance: {'f1_score': 0.5652607107273332}
# Active learning iteration: #6
# 2020-04-01 10:09:53,920 - biomed_ie - INFO - Number of training samples: 260
# Performance: {'f1_score': 0.57180675049636}
# Active learning iteration: #7
# 2020-04-01 10:09:57,340 - biomed_ie - INFO - Number of training samples: 290
# Performance: {'f1_score': 0.576957695769577}
# Active learning iteration: #8
# 2020-04-01 10:10:00,610 - biomed_ie - INFO - Number of training samples: 320
# Performance: {'f1_score': 0.560251798561151}
# Active learning iteration: #9
# 2020-04-01 10:10:03,931 - biomed_ie - INFO - Number of training samples: 350
# Performance: {'f1_score': 0.6010904134484325}
# Active learning iteration: #10
# 2020-04-01 10:10:07,452 - biomed_ie - INFO - Number of training samples: 380
# Performance: {'f1_score': 0.6004043126684636}
# Active learning iteration: #11
# 2020-04-01 10:10:10,791 - biomed_ie - INFO - Number of training samples: 410
# Performance: {'f1_score': 0.600562746201463}
# Active learning iteration: #12
# 2020-04-01 10:10:14,184 - biomed_ie - INFO - Number of training samples: 440
# Performance: {'f1_score': 0.6210871284890949}
# Active learning iteration: #13
# 2020-04-01 10:10:17,567 - biomed_ie - INFO - Number of training samples: 470
# Performance: {'f1_score': 0.6141891891891893}
# Active learning iteration: #14
# 2020-04-01 10:10:21,131 - biomed_ie - INFO - Number of training samples: 500
# Performance: {'f1_score': 0.6266832635509789}
# Active learning iteration: #15
# 2020-04-01 10:10:24,554 - biomed_ie - INFO - Number of training samples: 530
# Performance: {'f1_score': 0.6415689810640215}
# Active learning iteration: #16
# 2020-04-01 10:10:27,983 - biomed_ie - INFO - Number of training samples: 560
# Performance: {'f1_score': 0.6455337937280652}
# Active learning iteration: #17
# 2020-04-01 10:10:31,610 - biomed_ie - INFO - Number of training samples: 590
# Performance: {'f1_score': 0.6500960343464016}
# Active learning iteration: #18
# 2020-04-01 10:10:35,114 - biomed_ie - INFO - Number of training samples: 620
# Performance: {'f1_score': 0.6568315932818884}
# Active learning iteration: #19
# 2020-04-01 10:10:38,617 - biomed_ie - INFO - Number of training samples: 650
# Performance: {'f1_score': 0.6588526991998196}
# Active learning iteration: #20
# 2020-04-01 10:10:42,289 - biomed_ie - INFO - Number of training samples: 680
# Performance: {'f1_score': 0.667866786678668}
# Active learning iteration: #21
# 2020-04-01 10:10:45,834 - biomed_ie - INFO - Number of training samples: 710
# Performance: {'f1_score': 0.6767304036676731}
# Active learning iteration: #22
# 2020-04-01 10:10:49,388 - biomed_ie - INFO - Number of training samples: 740
# Performance: {'f1_score': 0.6741899441340782}
# Active learning iteration: #23
# 2020-04-01 10:10:52,983 - biomed_ie - INFO - Number of training samples: 770
# Performance: {'f1_score': 0.687354020687354}
# Active learning iteration: #24
# 2020-04-01 10:10:56,738 - biomed_ie - INFO - Number of training samples: 800
# Performance: {'f1_score': 0.688470066518847}
# Active learning strategy random
# Repeat 1
# Start emulating active learning.
# Evaluation: {'f1_score': 0.5255965049848773}
# Active learning iteration: #0
# 2020-04-01 10:10:59,509 - biomed_ie - INFO - Number of training samples: 80
# Performance: {'f1_score': 0.5533509700176367}
# Active learning iteration: #1
# 2020-04-01 10:11:01,014 - biomed_ie - INFO - Number of training samples: 110
# Performance: {'f1_score': 0.5731414868105515}
# Active learning iteration: #2
# 2020-04-01 10:11:02,547 - biomed_ie - INFO - Number of training samples: 140
# Performance: {'f1_score': 0.5841116360839467}
# Active learning iteration: #3
# 2020-04-01 10:11:04,002 - biomed_ie - INFO - Number of training samples: 170
# Performance: {'f1_score': 0.5944032739741179}
# Active learning iteration: #4
# 2020-04-01 10:11:05,657 - biomed_ie - INFO - Number of training samples: 200
# Performance: {'f1_score': 0.6143631736195639}
# Active learning iteration: #5
# 2020-04-01 10:11:07,396 - biomed_ie - INFO - Number of training samples: 230
# Performance: {'f1_score': 0.6270794315302413}
# Active learning iteration: #6
# 2020-04-01 10:11:09,168 - biomed_ie - INFO - Number of training samples: 260
# Performance: {'f1_score': 0.6264051135111306}
# Active learning iteration: #7
# 2020-04-01 10:11:10,987 - biomed_ie - INFO - Number of training samples: 290
# Performance: {'f1_score': 0.628747795414462}
# Active learning iteration: #8
# 2020-04-01 10:11:12,909 - biomed_ie - INFO - Number of training samples: 320
# Performance: {'f1_score': 0.645934065934066}
# Active learning iteration: #9
# 2020-04-01 10:11:14,717 - biomed_ie - INFO - Number of training samples: 350
# Performance: {'f1_score': 0.6526106634286345}
# Active learning iteration: #10
# 2020-04-01 10:11:16,672 - biomed_ie - INFO - Number of training samples: 380
# Performance: {'f1_score': 0.6574950473255559}
# Active learning iteration: #11
# 2020-04-01 10:11:18,696 - biomed_ie - INFO - Number of training samples: 410
# Performance: {'f1_score': 0.6697439279041653}
# Active learning iteration: #12
# 2020-04-01 10:11:20,771 - biomed_ie - INFO - Number of training samples: 440
# Performance: {'f1_score': 0.6737674316459866}
# Active learning iteration: #13
# 2020-04-01 10:11:22,904 - biomed_ie - INFO - Number of training samples: 470
# Performance: {'f1_score': 0.6826005920403464}
# Active learning iteration: #14
# 2020-04-01 10:11:25,084 - biomed_ie - INFO - Number of training samples: 500
# Performance: {'f1_score': 0.6952339309138609}
# Active learning iteration: #15
# 2020-04-01 10:11:27,168 - biomed_ie - INFO - Number of training samples: 530
# Performance: {'f1_score': 0.6955285886082869}
# Active learning iteration: #16
# 2020-04-01 10:11:29,444 - biomed_ie - INFO - Number of training samples: 560
# Performance: {'f1_score': 0.7017467248908297}
# Active learning iteration: #17
# 2020-04-01 10:11:31,764 - biomed_ie - INFO - Number of training samples: 590
# Performance: {'f1_score': 0.7012421006755284}
# Active learning iteration: #18
# 2020-04-01 10:11:33,988 - biomed_ie - INFO - Number of training samples: 620
# Performance: {'f1_score': 0.708647644036296}
# Active learning iteration: #19
# 2020-04-01 10:11:36,396 - biomed_ie - INFO - Number of training samples: 650
# Performance: {'f1_score': 0.7090213231273921}
# Active learning iteration: #20
# 2020-04-01 10:11:38,902 - biomed_ie - INFO - Number of training samples: 680
# Performance: {'f1_score': 0.7127240926978575}
# Active learning iteration: #21
# 2020-04-01 10:11:41,408 - biomed_ie - INFO - Number of training samples: 710
# Performance: {'f1_score': 0.7222040013119055}
# Active learning iteration: #22
# 2020-04-01 10:11:43,821 - biomed_ie - INFO - Number of training samples: 740
# Performance: {'f1_score': 0.7271733187534173}
# Active learning iteration: #23
# 2020-04-01 10:11:46,457 - biomed_ie - INFO - Number of training samples: 770
# Performance: {'f1_score': 0.7349476439790577}
# Active learning iteration: #24
# 2020-04-01 10:11:49,124 - biomed_ie - INFO - Number of training samples: 800
# Performance: {'f1_score': 0.7327078332969671}
# Active learning strategy uncertainty
# Repeat 2
# Start emulating active learning.
# Evaluation: {'f1_score': 0.5033010563380281}
# Active learning iteration: #0
# 2020-04-01 10:11:54,527 - biomed_ie - INFO - Number of training samples: 80
# Performance: {'f1_score': 0.5230664857530528}
# Active learning iteration: #1
# 2020-04-01 10:11:57,702 - biomed_ie - INFO - Number of training samples: 110
# Performance: {'f1_score': 0.5294249775381851}
# Active learning iteration: #2
# 2020-04-01 10:12:01,032 - biomed_ie - INFO - Number of training samples: 140
# Performance: {'f1_score': 0.530741410488246}
# Active learning iteration: #3
# 2020-04-01 10:12:04,167 - biomed_ie - INFO - Number of training samples: 170
# Performance: {'f1_score': 0.5296782963298594}
# Active learning iteration: #4
# 2020-04-01 10:12:07,329 - biomed_ie - INFO - Number of training samples: 200
# Performance: {'f1_score': 0.5352967625899281}
# Active learning iteration: #5
# 2020-04-01 10:12:10,522 - biomed_ie - INFO - Number of training samples: 230
# Performance: {'f1_score': 0.5432649420160571}
# Active learning iteration: #6
# 2020-04-01 10:12:13,886 - biomed_ie - INFO - Number of training samples: 260
# Performance: {'f1_score': 0.5582275662435983}
# Active learning iteration: #7
# 2020-04-01 10:12:17,105 - biomed_ie - INFO - Number of training samples: 290
# Performance: {'f1_score': 0.560088938299055}
# Active learning iteration: #8
# 2020-04-01 10:12:20,361 - biomed_ie - INFO - Number of training samples: 320
# Performance: {'f1_score': 0.5691020131192038}
# Active learning iteration: #9
# 2020-04-01 10:12:23,775 - biomed_ie - INFO - Number of training samples: 350
# Performance: {'f1_score': 0.5709721588315838}
# Active learning iteration: #10
# 2020-04-01 10:12:27,037 - biomed_ie - INFO - Number of training samples: 380
# Performance: {'f1_score': 0.5899705014749262}
# Active learning iteration: #11
# 2020-04-01 10:12:30,308 - biomed_ie - INFO - Number of training samples: 410
# Performance: {'f1_score': 0.5921067771257623}
# Active learning iteration: #12
# 2020-04-01 10:12:33,621 - biomed_ie - INFO - Number of training samples: 440
# Performance: {'f1_score': 0.5882756256427838}
# Active learning iteration: #13
# 2020-04-01 10:12:37,059 - biomed_ie - INFO - Number of training samples: 470
# Performance: {'f1_score': 0.6032621180794854}
# Active learning iteration: #14
# 2020-04-01 10:12:40,413 - biomed_ie - INFO - Number of training samples: 500
# Performance: {'f1_score': 0.6041069175174946}
# Active learning iteration: #15
# 2020-04-01 10:12:43,781 - biomed_ie - INFO - Number of training samples: 530
# Performance: {'f1_score': 0.6114285714285714}
# Active learning iteration: #16
# 2020-04-01 10:12:47,299 - biomed_ie - INFO - Number of training samples: 560
# Performance: {'f1_score': 0.619101891953499}
# Active learning iteration: #17
# 2020-04-01 10:12:50,695 - biomed_ie - INFO - Number of training samples: 590
# Performance: {'f1_score': 0.614804660726525}
# Active learning iteration: #18
# 2020-04-01 10:12:54,129 - biomed_ie - INFO - Number of training samples: 620
# Performance: {'f1_score': 0.6154895939952235}
# Active learning iteration: #19
# 2020-04-01 10:12:57,535 - biomed_ie - INFO - Number of training samples: 650
# Performance: {'f1_score': 0.6164833919056796}
# Active learning iteration: #20
# 2020-04-01 10:13:01,118 - biomed_ie - INFO - Number of training samples: 680
# Performance: {'f1_score': 0.6307935790187655}
# Active learning iteration: #21
# 2020-04-01 10:13:04,568 - biomed_ie - INFO - Number of training samples: 710
# Performance: {'f1_score': 0.6430665163472379}
# Active learning iteration: #22
# 2020-04-01 10:13:08,079 - biomed_ie - INFO - Number of training samples: 740
# Performance: {'f1_score': 0.6587042253521126}
# Active learning iteration: #23
# 2020-04-01 10:13:11,765 - biomed_ie - INFO - Number of training samples: 770
# Performance: {'f1_score': 0.67241765628501}
# Active learning iteration: #24
# 2020-04-01 10:13:15,288 - biomed_ie - INFO - Number of training samples: 800
# Performance: {'f1_score': 0.6754385964912281}
# Active learning strategy random
# Repeat 2
# Start emulating active learning.
# Evaluation: {'f1_score': 0.49370277078085645}
# Active learning iteration: #0
# 2020-04-01 10:13:17,971 - biomed_ie - INFO - Number of training samples: 80
# Performance: {'f1_score': 0.5288292253521126}
# Active learning iteration: #1
# 2020-04-01 10:13:19,420 - biomed_ie - INFO - Number of training samples: 110
# Performance: {'f1_score': 0.5715222380067753}
# Active learning iteration: #2
# 2020-04-01 10:13:20,954 - biomed_ie - INFO - Number of training samples: 140
# Performance: {'f1_score': 0.5919133893062307}
# Active learning iteration: #3
# 2020-04-01 10:13:22,396 - biomed_ie - INFO - Number of training samples: 170
# Performance: {'f1_score': 0.6091626479614205}
# Active learning iteration: #4
# 2020-04-01 10:13:24,017 - biomed_ie - INFO - Number of training samples: 200
# Performance: {'f1_score': 0.6202559576345985}
# Active learning iteration: #5
# 2020-04-01 10:13:25,684 - biomed_ie - INFO - Number of training samples: 230
# Performance: {'f1_score': 0.638470833791058}
# Active learning iteration: #6
# 2020-04-01 10:13:27,398 - biomed_ie - INFO - Number of training samples: 260
# Performance: {'f1_score': 0.6392663794055905}
# Active learning iteration: #7
# 2020-04-01 10:13:29,156 - biomed_ie - INFO - Number of training samples: 290
# Performance: {'f1_score': 0.6507324595219737}
# Active learning iteration: #8
# 2020-04-01 10:13:30,981 - biomed_ie - INFO - Number of training samples: 319
# Performance: {'f1_score': 0.6593164277839031}
# Active learning iteration: #9
# 2020-04-01 10:13:32,726 - biomed_ie - INFO - Number of training samples: 349
# Performance: {'f1_score': 0.6667399186902537}
# Active learning iteration: #10
# 2020-04-01 10:13:34,653 - biomed_ie - INFO - Number of training samples: 379
# Performance: {'f1_score': 0.6733216322948661}
# Active learning iteration: #11
# 2020-04-01 10:13:36,664 - biomed_ie - INFO - Number of training samples: 408
# Performance: {'f1_score': 0.6755272407732864}
# Active learning iteration: #12
# 2020-04-01 10:13:38,742 - biomed_ie - INFO - Number of training samples: 438
# Performance: {'f1_score': 0.6815139879319803}
# Active learning iteration: #13
# 2020-04-01 10:13:40,857 - biomed_ie - INFO - Number of training samples: 468
# Performance: {'f1_score': 0.6832584146475168}
# Active learning iteration: #14
# 2020-04-01 10:13:42,909 - biomed_ie - INFO - Number of training samples: 498
# Performance: {'f1_score': 0.6925523746846551}
# Active learning iteration: #15
# 2020-04-01 10:13:45,132 - biomed_ie - INFO - Number of training samples: 528
# Performance: {'f1_score': 0.6970491803278688}
# Active learning iteration: #16
# 2020-04-01 10:13:47,435 - biomed_ie - INFO - Number of training samples: 558
# Performance: {'f1_score': 0.7050691244239631}
# Active learning iteration: #17
# 2020-04-01 10:13:49,800 - biomed_ie - INFO - Number of training samples: 588
# Performance: {'f1_score': 0.7034482758620689}
# Active learning iteration: #18
# 2020-04-01 10:13:52,081 - biomed_ie - INFO - Number of training samples: 618
# Performance: {'f1_score': 0.7088164515423321}
# Active learning iteration: #19
# 2020-04-01 10:13:54,566 - biomed_ie - INFO - Number of training samples: 648
# Performance: {'f1_score': 0.7122475856014047}
# Active learning iteration: #20
# 2020-04-01 10:13:57,076 - biomed_ie - INFO - Number of training samples: 678
# Performance: {'f1_score': 0.7180558610072576}
# Active learning iteration: #21
# 2020-04-01 10:13:59,498 - biomed_ie - INFO - Number of training samples: 708
# Performance: {'f1_score': 0.724414642189733}
# Active learning iteration: #22
# 2020-04-01 10:14:02,139 - biomed_ie - INFO - Number of training samples: 738
# Performance: {'f1_score': 0.7306596537365769}
# Active learning iteration: #23
# 2020-04-01 10:14:04,811 - biomed_ie - INFO - Number of training samples: 768
# Performance: {'f1_score': 0.7393686979395002}
# Active learning iteration: #24
# 2020-04-01 10:14:07,439 - biomed_ie - INFO - Number of training samples: 798
# Performance: {'f1_score': 0.7398311588641595}
# Active learning strategy uncertainty
# Repeat 3
# Start emulating active learning.
# Evaluation: {'f1_score': 0.5374408676589361}
# Active learning iteration: #0
# 2020-04-01 10:14:12,963 - biomed_ie - INFO - Number of training samples: 80
# Performance: {'f1_score': 0.5365853658536586}
# Active learning iteration: #1
# 2020-04-01 10:14:16,053 - biomed_ie - INFO - Number of training samples: 110
# Performance: {'f1_score': 0.5400478523413467}
# Active learning iteration: #2
# 2020-04-01 10:14:19,177 - biomed_ie - INFO - Number of training samples: 140
# Performance: {'f1_score': 0.5366909753874202}
# Active learning iteration: #3
# 2020-04-01 10:14:22,496 - biomed_ie - INFO - Number of training samples: 170
# Performance: {'f1_score': 0.5611527115951894}
# Active learning iteration: #4
# 2020-04-01 10:14:25,634 - biomed_ie - INFO - Number of training samples: 200
# Performance: {'f1_score': 0.5848481427119794}
# Active learning iteration: #5
# 2020-04-01 10:14:28,781 - biomed_ie - INFO - Number of training samples: 230
# Performance: {'f1_score': 0.5870938628158845}
# Active learning iteration: #6
# 2020-04-01 10:14:32,115 - biomed_ie - INFO - Number of training samples: 260
# Performance: {'f1_score': 0.6014801525005607}
# Active learning iteration: #7
# 2020-04-01 10:14:35,314 - biomed_ie - INFO - Number of training samples: 290
# Performance: {'f1_score': 0.6108198549916342}
# Active learning iteration: #8
# 2020-04-01 10:14:38,547 - biomed_ie - INFO - Number of training samples: 320
# Performance: {'f1_score': 0.6135931026760721}
# Active learning iteration: #9
# 2020-04-01 10:14:41,802 - biomed_ie - INFO - Number of training samples: 350
# Performance: {'f1_score': 0.6250418106812353}
# Active learning iteration: #10
# 2020-04-01 10:14:45,211 - biomed_ie - INFO - Number of training samples: 380
# Performance: {'f1_score': 0.6316490838423098}
# Active learning iteration: #11
# 2020-04-01 10:14:48,500 - biomed_ie - INFO - Number of training samples: 410
# Performance: {'f1_score': 0.6266993536884333}
# Active learning iteration: #12
# 2020-04-01 10:14:51,823 - biomed_ie - INFO - Number of training samples: 440
# Performance: {'f1_score': 0.6338075501288227}
# Active learning iteration: #13
# 2020-04-01 10:14:55,323 - biomed_ie - INFO - Number of training samples: 470
# Performance: {'f1_score': 0.6443924713219734}
# Active learning iteration: #14
# 2020-04-01 10:14:58,657 - biomed_ie - INFO - Number of training samples: 500
# Performance: {'f1_score': 0.6516425608252047}
# Active learning iteration: #15
# 2020-04-01 10:15:02,037 - biomed_ie - INFO - Number of training samples: 530
# Performance: {'f1_score': 0.6548494983277591}
# Active learning iteration: #16
# 2020-04-01 10:15:05,557 - biomed_ie - INFO - Number of training samples: 560
# Performance: {'f1_score': 0.6543582857782254}
# Active learning iteration: #17
# 2020-04-01 10:15:08,945 - biomed_ie - INFO - Number of training samples: 590
# Performance: {'f1_score': 0.6585148955091151}
# Active learning iteration: #18
# 2020-04-01 10:15:12,373 - biomed_ie - INFO - Number of training samples: 620
# Performance: {'f1_score': 0.6681529372422249}
# Active learning iteration: #19
# 2020-04-01 10:15:15,817 - biomed_ie - INFO - Number of training samples: 650
# Performance: {'f1_score': 0.6681499610635221}
# Active learning iteration: #20
# 2020-04-01 10:15:19,447 - biomed_ie - INFO - Number of training samples: 680
# Performance: {'f1_score': 0.6767519466073416}
# Active learning iteration: #21
# 2020-04-01 10:15:22,954 - biomed_ie - INFO - Number of training samples: 710
# Performance: {'f1_score': 0.6889380530973451}
# Active learning iteration: #22
# 2020-04-01 10:15:26,484 - biomed_ie - INFO - Number of training samples: 740
# Performance: {'f1_score': 0.691150442477876}
# Active learning iteration: #23
# 2020-04-01 10:15:30,145 - biomed_ie - INFO - Number of training samples: 770
# Performance: {'f1_score': 0.7062084257206209}
# Active learning iteration: #24
# 2020-04-01 10:15:33,696 - biomed_ie - INFO - Number of training samples: 800
# Performance: {'f1_score': 0.7111111111111111}
# Active learning strategy random
# Repeat 3
# Start emulating active learning.
# Evaluation: {'f1_score': 0.5200982581509602}
# Active learning iteration: #0
# 2020-04-01 10:15:36,497 - biomed_ie - INFO - Number of training samples: 80
# Performance: {'f1_score': 0.5463747386951259}
# Active learning iteration: #1
# 2020-04-01 10:15:38,001 - biomed_ie - INFO - Number of training samples: 110
# Performance: {'f1_score': 0.5556542990446568}
# Active learning iteration: #2
# 2020-04-01 10:15:39,583 - biomed_ie - INFO - Number of training samples: 140
# Performance: {'f1_score': 0.5840244434744652}
# Active learning iteration: #3
# 2020-04-01 10:15:41,187 - biomed_ie - INFO - Number of training samples: 170
# Performance: {'f1_score': 0.5923734385272847}
# Active learning iteration: #4
# 2020-04-01 10:15:42,857 - biomed_ie - INFO - Number of training samples: 200
# Performance: {'f1_score': 0.6015317286652079}
# Active learning iteration: #5
# 2020-04-01 10:15:44,447 - biomed_ie - INFO - Number of training samples: 230
# Performance: {'f1_score': 0.6071389346512904}
# Active learning iteration: #6
# 2020-04-01 10:15:46,205 - biomed_ie - INFO - Number of training samples: 260
# Performance: {'f1_score': 0.6174496644295302}
# Active learning iteration: #7
# 2020-04-01 10:15:48,014 - biomed_ie - INFO - Number of training samples: 290
# Performance: {'f1_score': 0.6249726656461841}
# Active learning iteration: #8
# 2020-04-01 10:15:49,871 - biomed_ie - INFO - Number of training samples: 320
# Performance: {'f1_score': 0.6409948729137123}
# Active learning iteration: #9
# 2020-04-01 10:15:51,776 - biomed_ie - INFO - Number of training samples: 350
# Performance: {'f1_score': 0.6477247986065753}
# Active learning iteration: #10
# 2020-04-01 10:15:53,764 - biomed_ie - INFO - Number of training samples: 380
# Performance: {'f1_score': 0.660420525111668}
# Active learning iteration: #11
# 2020-04-01 10:15:55,763 - biomed_ie - INFO - Number of training samples: 410
# Performance: {'f1_score': 0.6664485165794066}
# Active learning iteration: #12
# 2020-04-01 10:15:57,837 - biomed_ie - INFO - Number of training samples: 440
# Performance: {'f1_score': 0.6707544070951496}
# Active learning iteration: #13
# 2020-04-01 10:15:59,829 - biomed_ie - INFO - Number of training samples: 470
# Performance: {'f1_score': 0.6799694689783011}
# Active learning iteration: #14
# 2020-04-01 10:16:02,008 - biomed_ie - INFO - Number of training samples: 500
# Performance: {'f1_score': 0.683458728601025}
# Active learning iteration: #15
# 2020-04-01 10:16:04,241 - biomed_ie - INFO - Number of training samples: 530
# Performance: {'f1_score': 0.6903310104529616}
# Active learning iteration: #16
# 2020-04-01 10:16:06,545 - biomed_ie - INFO - Number of training samples: 560
# Performance: {'f1_score': 0.6939265074691964}
# Active learning iteration: #17
# 2020-04-01 10:16:08,803 - biomed_ie - INFO - Number of training samples: 590
# Performance: {'f1_score': 0.6973096612569437}
# Active learning iteration: #18
# 2020-04-01 10:16:11,229 - biomed_ie - INFO - Number of training samples: 620
# Performance: {'f1_score': 0.7041853349360726}
# Active learning iteration: #19
# 2020-04-01 10:16:13,711 - biomed_ie - INFO - Number of training samples: 650
# Performance: {'f1_score': 0.7093175853018373}
# Active learning iteration: #20
# 2020-04-01 10:16:16,102 - biomed_ie - INFO - Number of training samples: 680
# Performance: {'f1_score': 0.7170140783586161}
# Active learning iteration: #21
# 2020-04-01 10:16:18,703 - biomed_ie - INFO - Number of training samples: 710
# Performance: {'f1_score': 0.7212721925716152}
# Active learning iteration: #22
# 2020-04-01 10:16:21,376 - biomed_ie - INFO - Number of training samples: 740
# Performance: {'f1_score': 0.7232512529962956}
# Active learning iteration: #23
# 2020-04-01 10:16:24,135 - biomed_ie - INFO - Number of training samples: 770
# Performance: {'f1_score': 0.7315217391304348}
# Active learning iteration: #24
# 2020-04-01 10:16:26,803 - biomed_ie - INFO - Number of training samples: 800
# Performance: {'f1_score': 0.7333696243875885}
# Active learning strategy uncertainty
# Repeat 4
# Start emulating active learning.
# Evaluation: {'f1_score': 0.5092203170494987}
# Active learning iteration: #0
# 2020-04-01 10:16:32,352 - biomed_ie - INFO - Number of training samples: 80
# Performance: {'f1_score': 0.5202600216684723}
# Active learning iteration: #1
# 2020-04-01 10:16:35,500 - biomed_ie - INFO - Number of training samples: 110
# Performance: {'f1_score': 0.5205630085770837}
# Active learning iteration: #2
# 2020-04-01 10:16:38,666 - biomed_ie - INFO - Number of training samples: 140
# Performance: {'f1_score': 0.566846094694057}
# Active learning iteration: #3
# 2020-04-01 10:16:41,999 - biomed_ie - INFO - Number of training samples: 170
# Performance: {'f1_score': 0.5830022075055187}
# Active learning iteration: #4
# 2020-04-01 10:16:45,170 - biomed_ie - INFO - Number of training samples: 200
# Performance: {'f1_score': 0.5821357506080035}
# Active learning iteration: #5
# 2020-04-01 10:16:48,375 - biomed_ie - INFO - Number of training samples: 230
# Performance: {'f1_score': 0.5803249097472923}
# Active learning iteration: #6
# 2020-04-01 10:16:51,598 - biomed_ie - INFO - Number of training samples: 260
# Performance: {'f1_score': 0.5828518604113705}
# Active learning iteration: #7
# 2020-04-01 10:16:55,034 - biomed_ie - INFO - Number of training samples: 290
# Performance: {'f1_score': 0.5894009216589863}
# Active learning iteration: #8
# 2020-04-01 10:16:58,300 - biomed_ie - INFO - Number of training samples: 320
# Performance: {'f1_score': 0.5928899082568807}
# Active learning iteration: #9
# 2020-04-01 10:17:01,597 - biomed_ie - INFO - Number of training samples: 350
# Performance: {'f1_score': 0.6001825650387951}
# Active learning iteration: #10
# 2020-04-01 10:17:05,045 - biomed_ie - INFO - Number of training samples: 380
# Performance: {'f1_score': 0.6062134586724751}
# Active learning iteration: #11
# 2020-04-01 10:17:08,376 - biomed_ie - INFO - Number of training samples: 410
# Performance: {'f1_score': 0.6139588100686498}
# Active learning iteration: #12
# 2020-04-01 10:17:11,748 - biomed_ie - INFO - Number of training samples: 440
# Performance: {'f1_score': 0.6068161024702653}
# Active learning iteration: #13
# 2020-04-01 10:17:15,086 - biomed_ie - INFO - Number of training samples: 470
# Performance: {'f1_score': 0.6073430172709596}
# Active learning iteration: #14
# 2020-04-01 10:17:18,615 - biomed_ie - INFO - Number of training samples: 500
# Performance: {'f1_score': 0.6216525520714121}
# Active learning iteration: #15
# 2020-04-01 10:17:22,026 - biomed_ie - INFO - Number of training samples: 530
# Performance: {'f1_score': 0.6324398000908679}
# Active learning iteration: #16
# 2020-04-01 10:17:25,423 - biomed_ie - INFO - Number of training samples: 560
# Performance: {'f1_score': 0.6340857787810384}
# Active learning iteration: #17
# 2020-04-01 10:17:28,983 - biomed_ie - INFO - Number of training samples: 590
# Performance: {'f1_score': 0.6414288923837341}
# Active learning iteration: #18
# 2020-04-01 10:17:32,404 - biomed_ie - INFO - Number of training samples: 620
# Performance: {'f1_score': 0.6462615766885023}
# Active learning iteration: #19
# 2020-04-01 10:17:35,863 - biomed_ie - INFO - Number of training samples: 650
# Performance: {'f1_score': 0.6489349712611293}
# Active learning iteration: #20
# 2020-04-01 10:17:39,485 - biomed_ie - INFO - Number of training samples: 680
# Performance: {'f1_score': 0.6613375365908578}
# Active learning iteration: #21
# 2020-04-01 10:17:42,984 - biomed_ie - INFO - Number of training samples: 710
# Performance: {'f1_score': 0.6697268248992386}
# Active learning iteration: #22
# 2020-04-01 10:17:46,499 - biomed_ie - INFO - Number of training samples: 740
# Performance: {'f1_score': 0.6718069057995306}
# Active learning iteration: #23
# 2020-04-01 10:17:50,035 - biomed_ie - INFO - Number of training samples: 770
# Performance: {'f1_score': 0.6806656986484978}
# Active learning iteration: #24
# 2020-04-01 10:17:53,774 - biomed_ie - INFO - Number of training samples: 800
# Performance: {'f1_score': 0.6772180115916183}
# Active learning strategy random
# Repeat 4
# Start emulating active learning.
# Evaluation: {'f1_score': 0.5589196253539533}
# Active learning iteration: #0
# 2020-04-01 10:17:56,538 - biomed_ie - INFO - Number of training samples: 79
# Performance: {'f1_score': 0.5626041550938784}
# Active learning iteration: #1
# 2020-04-01 10:17:57,990 - biomed_ie - INFO - Number of training samples: 109
# Performance: {'f1_score': 0.5754790120722117}
# Active learning iteration: #2
# 2020-04-01 10:17:59,375 - biomed_ie - INFO - Number of training samples: 139
# Performance: {'f1_score': 0.5886338797814207}
# Active learning iteration: #3
# 2020-04-01 10:18:00,925 - biomed_ie - INFO - Number of training samples: 169
# Performance: {'f1_score': 0.5970735968552086}
# Active learning iteration: #4
# 2020-04-01 10:18:02,547 - biomed_ie - INFO - Number of training samples: 199
# Performance: {'f1_score': 0.6134241458859716}
# Active learning iteration: #5
# 2020-04-01 10:18:04,245 - biomed_ie - INFO - Number of training samples: 229
# Performance: {'f1_score': 0.6215174540248871}
# Active learning iteration: #6
# 2020-04-01 10:18:06,014 - biomed_ie - INFO - Number of training samples: 259
# Performance: {'f1_score': 0.6398337525976155}
# Active learning iteration: #7
# 2020-04-01 10:18:07,847 - biomed_ie - INFO - Number of training samples: 289
# Performance: {'f1_score': 0.6504864983054554}
# Active learning iteration: #8
# 2020-04-01 10:18:09,544 - biomed_ie - INFO - Number of training samples: 319
# Performance: {'f1_score': 0.6592325352574615}
# Active learning iteration: #9
# 2020-04-01 10:18:11,427 - biomed_ie - INFO - Number of training samples: 349
# Performance: {'f1_score': 0.6678321678321678}
# Active learning iteration: #10
# 2020-04-01 10:18:13,350 - biomed_ie - INFO - Number of training samples: 379
# Performance: {'f1_score': 0.6668853175904667}
# Active learning iteration: #11
# 2020-04-01 10:18:15,324 - biomed_ie - INFO - Number of training samples: 409
# Performance: {'f1_score': 0.671617341924211}
# Active learning iteration: #12
# 2020-04-01 10:18:17,375 - biomed_ie - INFO - Number of training samples: 439
# Performance: {'f1_score': 0.6791175185670598}
# Active learning iteration: #13
# 2020-04-01 10:18:19,305 - biomed_ie - INFO - Number of training samples: 469
# Performance: {'f1_score': 0.6816094467526788}
# Active learning iteration: #14
# 2020-04-01 10:18:21,416 - biomed_ie - INFO - Number of training samples: 499
# Performance: {'f1_score': 0.68836291913215}
# Active learning iteration: #15
# 2020-04-01 10:18:23,596 - biomed_ie - INFO - Number of training samples: 529
# Performance: {'f1_score': 0.6892543859649124}
# Active learning iteration: #16
# 2020-04-01 10:18:25,660 - biomed_ie - INFO - Number of training samples: 559
# Performance: {'f1_score': 0.6966637401229149}
# Active learning iteration: #17
# 2020-04-01 10:18:27,909 - biomed_ie - INFO - Number of training samples: 589
# Performance: {'f1_score': 0.6995300032790468}
# Active learning iteration: #18
# 2020-04-01 10:18:30,226 - biomed_ie - INFO - Number of training samples: 619
# Performance: {'f1_score': 0.7007187976475714}
# Active learning iteration: #19
# 2020-04-01 10:18:32,606 - biomed_ie - INFO - Number of training samples: 649
# Performance: {'f1_score': 0.7038532911254229}
# Active learning iteration: #20
# 2020-04-01 10:18:34,909 - biomed_ie - INFO - Number of training samples: 679
# Performance: {'f1_score': 0.7052528120563505}
# Active learning iteration: #21
# 2020-04-01 10:18:37,419 - biomed_ie - INFO - Number of training samples: 709
# Performance: {'f1_score': 0.7128669649678053}
# Active learning iteration: #22
# 2020-04-01 10:18:39,981 - biomed_ie - INFO - Number of training samples: 739
# Performance: {'f1_score': 0.7154542480095976}
# Active learning iteration: #23
# 2020-04-01 10:18:42,449 - biomed_ie - INFO - Number of training samples: 769
# Performance: {'f1_score': 0.7201655052264809}
# Active learning iteration: #24
# 2020-04-01 10:18:45,138 - biomed_ie - INFO - Number of training samples: 799
# Performance: {'f1_score': 0.7287784679089028}
# Active learning strategy uncertainty
# Repeat 5
# Start emulating active learning.
# Evaluation: {'f1_score': 0.5076020851433537}
# Active learning iteration: #0
# 2020-04-01 10:18:50,437 - biomed_ie - INFO - Number of training samples: 80
# Performance: {'f1_score': 0.5411945880541195}
# Active learning iteration: #1
# 2020-04-01 10:18:53,699 - biomed_ie - INFO - Number of training samples: 110
# Performance: {'f1_score': 0.5403270053769341}
# Active learning iteration: #2
# 2020-04-01 10:18:56,808 - biomed_ie - INFO - Number of training samples: 140
# Performance: {'f1_score': 0.5399473222124671}
# Active learning iteration: #3
# 2020-04-01 10:18:59,916 - biomed_ie - INFO - Number of training samples: 170
# Performance: {'f1_score': 0.5368212794020664}
# Active learning iteration: #4
# 2020-04-01 10:19:03,188 - biomed_ie - INFO - Number of training samples: 200
# Performance: {'f1_score': 0.5372475444211455}
# Active learning iteration: #5
# 2020-04-01 10:19:06,336 - biomed_ie - INFO - Number of training samples: 230
# Performance: {'f1_score': 0.5570536007892141}
# Active learning iteration: #6
# 2020-04-01 10:19:09,563 - biomed_ie - INFO - Number of training samples: 260
# Performance: {'f1_score': 0.5629531970995386}
# Active learning iteration: #7
# 2020-04-01 10:19:12,903 - biomed_ie - INFO - Number of training samples: 290
# Performance: {'f1_score': 0.5652077807250222}
# Active learning iteration: #8
# 2020-04-01 10:19:16,102 - biomed_ie - INFO - Number of training samples: 320
# Performance: {'f1_score': 0.5739494871512077}
# Active learning iteration: #9
# 2020-04-01 10:19:19,340 - biomed_ie - INFO - Number of training samples: 350
# Performance: {'f1_score': 0.5799051505459357}
# Active learning iteration: #10
# 2020-04-01 10:19:22,619 - biomed_ie - INFO - Number of training samples: 380
# Performance: {'f1_score': 0.5909794384258237}
# Active learning iteration: #11
# 2020-04-01 10:19:26,015 - biomed_ie - INFO - Number of training samples: 410
# Performance: {'f1_score': 0.596218020022247}
# Active learning iteration: #12
# 2020-04-01 10:19:29,280 - biomed_ie - INFO - Number of training samples: 440
# Performance: {'f1_score': 0.596568898727172}
# Active learning iteration: #13
# 2020-04-01 10:19:32,598 - biomed_ie - INFO - Number of training samples: 470
# Performance: {'f1_score': 0.5916648193305255}
# Active learning iteration: #14
# 2020-04-01 10:19:36,060 - biomed_ie - INFO - Number of training samples: 500
# Performance: {'f1_score': 0.6060404912047793}
# Active learning iteration: #15
# 2020-04-01 10:19:39,397 - biomed_ie - INFO - Number of training samples: 530
# Performance: {'f1_score': 0.6159822419533851}
# Active learning iteration: #16
# 2020-04-01 10:19:42,757 - biomed_ie - INFO - Number of training samples: 560
# Performance: {'f1_score': 0.6208277703604805}
# Active learning iteration: #17
# 2020-04-01 10:19:46,106 - biomed_ie - INFO - Number of training samples: 590
# Performance: {'f1_score': 0.6328888888888888}
# Active learning iteration: #18
# 2020-04-01 10:19:49,655 - biomed_ie - INFO - Number of training samples: 620
# Performance: {'f1_score': 0.6453327427748864}
# Active learning iteration: #19
# 2020-04-01 10:19:53,093 - biomed_ie - INFO - Number of training samples: 650
# Performance: {'f1_score': 0.6439662821650399}
# Active learning iteration: #20
# 2020-04-01 10:19:56,595 - biomed_ie - INFO - Number of training samples: 680
# Performance: {'f1_score': 0.6596218020022246}
# Active learning iteration: #21
# 2020-04-01 10:20:00,092 - biomed_ie - INFO - Number of training samples: 710
# Performance: {'f1_score': 0.6762685575005539}
# Active learning iteration: #22
# 2020-04-01 10:20:03,741 - biomed_ie - INFO - Number of training samples: 740
# Performance: {'f1_score': 0.6789316191953897}
# Active learning iteration: #23
# 2020-04-01 10:20:07,276 - biomed_ie - INFO - Number of training samples: 770
# Performance: {'f1_score': 0.6886446886446886}
# Active learning iteration: #24
# 2020-04-01 10:20:10,835 - biomed_ie - INFO - Number of training samples: 800
# Performance: {'f1_score': 0.6935286935286934}
# Active learning strategy random
# Repeat 5
# Start emulating active learning.
# Evaluation: {'f1_score': 0.5330944114682495}
# Active learning iteration: #0
# 2020-04-01 10:20:13,573 - biomed_ie - INFO - Number of training samples: 80
# Performance: {'f1_score': 0.5625}
# Active learning iteration: #1
# 2020-04-01 10:20:15,034 - biomed_ie - INFO - Number of training samples: 110
# Performance: {'f1_score': 0.5834546065151686}
# Active learning iteration: #2
# 2020-04-01 10:20:16,561 - biomed_ie - INFO - Number of training samples: 140
# Performance: {'f1_score': 0.5881826320501343}
# Active learning iteration: #3
# 2020-04-01 10:20:18,137 - biomed_ie - INFO - Number of training samples: 170
# Performance: {'f1_score': 0.6110429447852761}
# Active learning iteration: #4
# 2020-04-01 10:20:19,789 - biomed_ie - INFO - Number of training samples: 200
# Performance: {'f1_score': 0.6119302949061662}
# Active learning iteration: #5
# 2020-04-01 10:20:21,482 - biomed_ie - INFO - Number of training samples: 230
# Performance: {'f1_score': 0.6297748403719056}
# Active learning iteration: #6
# 2020-04-01 10:20:23,237 - biomed_ie - INFO - Number of training samples: 260
# Performance: {'f1_score': 0.6414884135472372}
# Active learning iteration: #7
# 2020-04-01 10:20:24,888 - biomed_ie - INFO - Number of training samples: 290
# Performance: {'f1_score': 0.6589224471733599}
# Active learning iteration: #8
# 2020-04-01 10:20:26,808 - biomed_ie - INFO - Number of training samples: 320
# Performance: {'f1_score': 0.663356504468719}
# Active learning iteration: #9
# 2020-04-01 10:20:28,717 - biomed_ie - INFO - Number of training samples: 350
# Performance: {'f1_score': 0.6654156087868418}
# Active learning iteration: #10
# 2020-04-01 10:20:30,723 - biomed_ie - INFO - Number of training samples: 379
# Performance: {'f1_score': 0.6791036538249254}
# Active learning iteration: #11
# 2020-04-01 10:20:32,757 - biomed_ie - INFO - Number of training samples: 409
# Performance: {'f1_score': 0.6831421006178287}
# Active learning iteration: #12
# 2020-04-01 10:20:34,701 - biomed_ie - INFO - Number of training samples: 439
# Performance: {'f1_score': 0.690148596587782}
# Active learning iteration: #13
# 2020-04-01 10:20:36,835 - biomed_ie - INFO - Number of training samples: 469
# Performance: {'f1_score': 0.6937603533959139}
# Active learning iteration: #14
# 2020-04-01 10:20:39,032 - biomed_ie - INFO - Number of training samples: 499
# Performance: {'f1_score': 0.698454455771128}
# Active learning iteration: #15
# 2020-04-01 10:20:41,254 - biomed_ie - INFO - Number of training samples: 529
# Performance: {'f1_score': 0.703207381370826}
# Active learning iteration: #16
# 2020-04-01 10:20:43,386 - biomed_ie - INFO - Number of training samples: 559
# Performance: {'f1_score': 0.7091048537306891}
# Active learning iteration: #17
# 2020-04-01 10:20:45,722 - biomed_ie - INFO - Number of training samples: 589
# Performance: {'f1_score': 0.7091029023746702}
# Active learning iteration: #18
# 2020-04-01 10:20:48,139 - biomed_ie - INFO - Number of training samples: 619
# Performance: {'f1_score': 0.7133098281181137}
# Active learning iteration: #19
# 2020-04-01 10:20:50,494 - biomed_ie - INFO - Number of training samples: 649
# Performance: {'f1_score': 0.7154346149608902}
# Active learning iteration: #20
# 2020-04-01 10:20:53,024 - biomed_ie - INFO - Number of training samples: 679
# Performance: {'f1_score': 0.7228942159665714}
# Active learning iteration: #21
# 2020-04-01 10:20:55,621 - biomed_ie - INFO - Number of training samples: 709
# Performance: {'f1_score': 0.7273725834797892}
# Active learning iteration: #22
# 2020-04-01 10:20:58,250 - biomed_ie - INFO - Number of training samples: 739
# Performance: {'f1_score': 0.7291689537819739}
# Active learning iteration: #23
# 2020-04-01 10:21:00,762 - biomed_ie - INFO - Number of training samples: 769
# Performance: {'f1_score': 0.7320333041191937}
# Active learning iteration: #24
# 2020-04-01 10:21:03,469 - biomed_ie - INFO - Number of training samples: 799
# Performance: {'f1_score': 0.7357581069237511}
# Active learning strategy uncertainty
# Repeat 6
# Start emulating active learning.
# Evaluation: {'f1_score': 0.5319805910895455}
# Active learning iteration: #0
# 2020-04-01 10:21:08,837 - biomed_ie - INFO - Number of training samples: 80
# Performance: {'f1_score': 0.5414047855331349}
# Active learning iteration: #1
# 2020-04-01 10:21:12,128 - biomed_ie - INFO - Number of training samples: 110
# Performance: {'f1_score': 0.5444275472517923}
# Active learning iteration: #2
# ...
# Active learning iteration: #24
# 2020-04-01 10:25:44,691 - biomed_ie - INFO - Number of training samples: 798
# Performance: {'f1_score': 0.7389830508474576}
# Active learning strategy uncertainty
# Repeat 8
# Start emulating active learning.
# Evaluation: {'f1_score': 0.521623714190908}
# Active learning iteration: #0
# 2020-04-01 10:25:50,212 - biomed_ie - INFO - Number of training samples: 80
# Performance: {'f1_score': 0.5159034513873224}
# Active learning iteration: #1
# 2020-04-01 10:25:53,354 - biomed_ie - INFO - Number of training samples: 110
# Performance: {'f1_score': 0.5124023105674481}
# Active learning iteration: #2
# 2020-04-01 10:25:56,693 - biomed_ie - INFO - Number of training samples: 140
# Performance: {'f1_score': 0.5096359743040685}
# Active learning iteration: #3
# 2020-04-01 10:25:59,852 - biomed_ie - INFO - Number of training samples: 170
# Performance: {'f1_score': 0.5140980636394519}
# Active learning iteration: #4
# 2020-04-01 10:26:03,061 - biomed_ie - INFO - Number of training samples: 200
# Performance: {'f1_score': 0.5288704853922245}
# Active learning iteration: #5
# 2020-04-01 10:26:06,410 - biomed_ie - INFO - Number of training samples: 230
# Performance: {'f1_score': 0.5295774647887325}
# Active learning iteration: #6
# 2020-04-01 10:26:09,674 - biomed_ie - INFO - Number of training samples: 260
# Performance: {'f1_score': 0.552129221732746}
# Active learning iteration: #7
# 2020-04-01 10:26:12,930 - biomed_ie - INFO - Number of training samples: 290
# Performance: {'f1_score': 0.5557324840764332}
# Active learning iteration: #8
# 2020-04-01 10:26:16,367 - biomed_ie - INFO - Number of training samples: 320
# Performance: {'f1_score': 0.5407754775248771}
# Active learning iteration: #9
# 2020-04-01 10:26:19,619 - biomed_ie - INFO - Number of training samples: 350
# Performance: {'f1_score': 0.5426745778183477}
# Active learning iteration: #10
# 2020-04-01 10:26:22,913 - biomed_ie - INFO - Number of training samples: 380
# Performance: {'f1_score': 0.5556317112177291}
# Active learning iteration: #11
# 2020-04-01 10:26:26,244 - biomed_ie - INFO - Number of training samples: 410
# Performance: {'f1_score': 0.5796279491833032}
# Active learning iteration: #12
# 2020-04-01 10:26:29,705 - biomed_ie - INFO - Number of training samples: 440
# Performance: {'f1_score': 0.5800342270393611}
# Active learning iteration: #13
# 2020-04-01 10:26:33,048 - biomed_ie - INFO - Number of training samples: 470
# Performance: {'f1_score': 0.5835245525470399}
# Active learning iteration: #14
# 2020-04-01 10:26:36,459 - biomed_ie - INFO - Number of training samples: 500
# Performance: {'f1_score': 0.5956571428571428}
# Active learning iteration: #15
# 2020-04-01 10:26:40,001 - biomed_ie - INFO - Number of training samples: 530
# Performance: {'f1_score': 0.6098066298342542}
# Active learning iteration: #16
# 2020-04-01 10:26:43,434 - biomed_ie - INFO - Number of training samples: 560
# Performance: {'f1_score': 0.6075306075306076}
# Active learning iteration: #17
# 2020-04-01 10:26:46,887 - biomed_ie - INFO - Number of training samples: 590
# Performance: {'f1_score': 0.6170114942528736}
# Active learning iteration: #18
# 2020-04-01 10:26:50,494 - biomed_ie - INFO - Number of training samples: 620
# Performance: {'f1_score': 0.620253164556962}
# Active learning iteration: #19
# 2020-04-01 10:26:53,983 - biomed_ie - INFO - Number of training samples: 650
# Performance: {'f1_score': 0.6347346657477602}
# Active learning iteration: #20
# 2020-04-01 10:26:57,500 - biomed_ie - INFO - Number of training samples: 680
# Performance: {'f1_score': 0.6437492838317864}
# Active learning iteration: #21
# 2020-04-01 10:27:01,019 - biomed_ie - INFO - Number of training samples: 710
# Performance: {'f1_score': 0.6553969160479727}
# Active learning iteration: #22
# 2020-04-01 10:27:04,698 - biomed_ie - INFO - Number of training samples: 740
# Performance: {'f1_score': 0.6614083219021489}
# Active learning iteration: #23
# 2020-04-01 10:27:08,233 - biomed_ie - INFO - Number of training samples: 770
# Performance: {'f1_score': 0.6644691975448966}
# Active learning iteration: #24
# 2020-04-01 10:27:11,840 - biomed_ie - INFO - Number of training samples: 800
# Performance: {'f1_score': 0.6668176670441677}
# Active learning strategy random
# Repeat 8
# Start emulating active learning.
# Evaluation: {'f1_score': 0.5486385477843032}
# Active learning iteration: #0
# 2020-04-01 10:27:14,785 - biomed_ie - INFO - Number of training samples: 80
# Performance: {'f1_score': 0.5780296425457715}
# Active learning iteration: #1
# 2020-04-01 10:27:16,142 - biomed_ie - INFO - Number of training samples: 110
# Performance: {'f1_score': 0.5747051114023592}
# Active learning iteration: #2
# 2020-04-01 10:27:17,697 - biomed_ie - INFO - Number of training samples: 140
# Performance: {'f1_score': 0.5969792458980768}
# Active learning iteration: #3
# 2020-04-01 10:27:19,303 - biomed_ie - INFO - Number of training samples: 170
# Performance: {'f1_score': 0.6156696088046202}
# Active learning iteration: #4
# 2020-04-01 10:27:20,954 - biomed_ie - INFO - Number of training samples: 200
# Performance: {'f1_score': 0.6203126708210343}
# Active learning iteration: #5
# 2020-04-01 10:27:22,715 - biomed_ie - INFO - Number of training samples: 230
# Performance: {'f1_score': 0.6237051575618798}
# Active learning iteration: #6
# 2020-04-01 10:27:24,491 - biomed_ie - INFO - Number of training samples: 260
# Performance: {'f1_score': 0.628965215488952}
# Active learning iteration: #7
# 2020-04-01 10:27:26,312 - biomed_ie - INFO - Number of training samples: 290
# Performance: {'f1_score': 0.6423790189838692}
# Active learning iteration: #8
# 2020-04-01 10:27:28,069 - biomed_ie - INFO - Number of training samples: 320
# Performance: {'f1_score': 0.6547933157431838}
# Active learning iteration: #9
# 2020-04-01 10:27:30,027 - biomed_ie - INFO - Number of training samples: 350
# Performance: {'f1_score': 0.663081650570676}
# Active learning iteration: #10
# 2020-04-01 10:27:32,064 - biomed_ie - INFO - Number of training samples: 380
# Performance: {'f1_score': 0.668418747262374}
# Active learning iteration: #11
# 2020-04-01 10:27:34,125 - biomed_ie - INFO - Number of training samples: 410
# Performance: {'f1_score': 0.6882166648465655}
# Active learning iteration: #12
# 2020-04-01 10:27:36,236 - biomed_ie - INFO - Number of training samples: 440
# Performance: {'f1_score': 0.6884564932225623}
# Active learning iteration: #13
# 2020-04-01 10:27:38,395 - biomed_ie - INFO - Number of training samples: 470
# Performance: {'f1_score': 0.6934147405146097}
# Active learning iteration: #14
# 2020-04-01 10:27:40,533 - biomed_ie - INFO - Number of training samples: 499
# Performance: {'f1_score': 0.703844897070036}
# Active learning iteration: #15
# 2020-04-01 10:27:42,801 - biomed_ie - INFO - Number of training samples: 529
# Performance: {'f1_score': 0.7024093770349468}
# Active learning iteration: #16
# 2020-04-01 10:27:45,109 - biomed_ie - INFO - Number of training samples: 559
# Performance: {'f1_score': 0.7072931429194373}
# Active learning iteration: #17
# 2020-04-01 10:27:47,332 - biomed_ie - INFO - Number of training samples: 589
# Performance: {'f1_score': 0.7113480578827114}
# Active learning iteration: #18
# 2020-04-01 10:27:49,798 - biomed_ie - INFO - Number of training samples: 619
# Performance: {'f1_score': 0.7141770776751766}
# Active learning iteration: #19
# 2020-04-01 10:27:52,282 - biomed_ie - INFO - Number of training samples: 649
# Performance: {'f1_score': 0.7195997389601914}
# Active learning iteration: #20
# 2020-04-01 10:27:54,823 - biomed_ie - INFO - Number of training samples: 679
# Performance: {'f1_score': 0.7219140837411636}
# Active learning iteration: #21
# 2020-04-01 10:27:57,279 - biomed_ie - INFO - Number of training samples: 709
# Performance: {'f1_score': 0.7251385718943594}
# Active learning iteration: #22
# 2020-04-01 10:27:59,926 - biomed_ie - INFO - Number of training samples: 739
# Performance: {'f1_score': 0.7282017829963036}
# Active learning iteration: #23
# 2020-04-01 10:28:02,599 - biomed_ie - INFO - Number of training samples: 769
# Performance: {'f1_score': 0.7384648789490826}
# Active learning iteration: #24
# 2020-04-01 10:28:05,169 - biomed_ie - INFO - Number of training samples: 799
# Performance: {'f1_score': 0.7397438680269156}
# Active learning strategy uncertainty
# Repeat 9
# Start emulating active learning.
# Evaluation: {'f1_score': 0.5378282153983088}
# Active learning iteration: #0
# 2020-04-01 10:28:10,676 - biomed_ie - INFO - Number of training samples: 80
# Performance: {'f1_score': 0.5411128632574904}
# Active learning iteration: #1
# 2020-04-01 10:28:13,782 - biomed_ie - INFO - Number of training samples: 110
# Performance: {'f1_score': 0.5383492419988771}
# Active learning iteration: #2
# 2020-04-01 10:28:16,899 - biomed_ie - INFO - Number of training samples: 140
# Performance: {'f1_score': 0.5416713029932123}
# Active learning iteration: #3
# 2020-04-01 10:28:20,164 - biomed_ie - INFO - Number of training samples: 170
# Performance: {'f1_score': 0.5319670305190466}
# Active learning iteration: #4
# 2020-04-01 10:28:23,339 - biomed_ie - INFO - Number of training samples: 200
# Performance: {'f1_score': 0.5483798882681565}
# Active learning iteration: #5
# 2020-04-01 10:28:26,513 - biomed_ie - INFO - Number of training samples: 230
# Performance: {'f1_score': 0.5482358195623047}
# Active learning iteration: #6
# 2020-04-01 10:28:29,702 - biomed_ie - INFO - Number of training samples: 260
# Performance: {'f1_score': 0.5783933518005541}
# Active learning iteration: #7
# 2020-04-01 10:28:33,035 - biomed_ie - INFO - Number of training samples: 290
# Performance: {'f1_score': 0.5828457887184016}
# Active learning iteration: #8
# 2020-04-01 10:28:36,237 - biomed_ie - INFO - Number of training samples: 320
# Performance: {'f1_score': 0.5895017201198535}
# Active learning iteration: #9
# 2020-04-01 10:28:39,498 - biomed_ie - INFO - Number of training samples: 350
# Performance: {'f1_score': 0.593579917805176}
# Active learning iteration: #10
# 2020-04-01 10:28:42,918 - biomed_ie - INFO - Number of training samples: 380
# Performance: {'f1_score': 0.5962456958791513}
# Active learning iteration: #11
# 2020-04-01 10:28:46,217 - biomed_ie - INFO - Number of training samples: 410
# Performance: {'f1_score': 0.5976985559566786}
# Active learning iteration: #12
# 2020-04-01 10:28:49,538 - biomed_ie - INFO - Number of training samples: 440
# Performance: {'f1_score': 0.6061153108428297}
# Active learning iteration: #13
# 2020-04-01 10:28:52,998 - biomed_ie - INFO - Number of training samples: 470
# Performance: {'f1_score': 0.6202027103974492}
# Active learning iteration: #14
# 2020-04-01 10:28:56,423 - biomed_ie - INFO - Number of training samples: 500
# Performance: {'f1_score': 0.6297648938598495}
# Active learning iteration: #15
# 2020-04-01 10:28:59,795 - biomed_ie - INFO - Number of training samples: 530
# Performance: {'f1_score': 0.6457317764425803}
# Active learning iteration: #16
# 2020-04-01 10:29:03,201 - biomed_ie - INFO - Number of training samples: 560
# Performance: {'f1_score': 0.6495649225901231}
# Active learning iteration: #17
# 2020-04-01 10:29:06,740 - biomed_ie - INFO - Number of training samples: 590
# Performance: {'f1_score': 0.6518652090611969}
# Active learning iteration: #18
# 2020-04-01 10:29:10,164 - biomed_ie - INFO - Number of training samples: 620
# Performance: {'f1_score': 0.6598286744815149}
# Active learning iteration: #19
# 2020-04-01 10:29:13,640 - biomed_ie - INFO - Number of training samples: 650
# Performance: {'f1_score': 0.665990990990991}
# Active learning iteration: #20
# 2020-04-01 10:29:17,262 - biomed_ie - INFO - Number of training samples: 680
# Performance: {'f1_score': 0.6643450909907885}
# Active learning iteration: #21
# 2020-04-01 10:29:20,774 - biomed_ie - INFO - Number of training samples: 710
# Performance: {'f1_score': 0.6738984567210915}
# Active learning iteration: #22
# 2020-04-01 10:29:24,267 - biomed_ie - INFO - Number of training samples: 740
# Performance: {'f1_score': 0.6762638098426514}
# Active learning iteration: #23
# 2020-04-01 10:29:27,958 - biomed_ie - INFO - Number of training samples: 770
# Performance: {'f1_score': 0.6885136636303043}
# Active learning iteration: #24
# 2020-04-01 10:29:31,528 - biomed_ie - INFO - Number of training samples: 800
# Performance: {'f1_score': 0.6976640711902113}
# Active learning strategy random
# Repeat 9
# Start emulating active learning.
# Evaluation: {'f1_score': 0.5114452423698386}
# Active learning iteration: #0
# 2020-04-01 10:29:34,256 - biomed_ie - INFO - Number of training samples: 79
# Performance: {'f1_score': 0.5173529739984377}
# Active learning iteration: #1
# 2020-04-01 10:29:35,727 - biomed_ie - INFO - Number of training samples: 109
# Performance: {'f1_score': 0.5892023994667851}
# Active learning iteration: #2
# 2020-04-01 10:29:37,243 - biomed_ie - INFO - Number of training samples: 139
# Performance: {'f1_score': 0.6079608627974206}
# Active learning iteration: #3
# 2020-04-01 10:29:38,812 - biomed_ie - INFO - Number of training samples: 169
# Performance: {'f1_score': 0.6224342616221014}
# Active learning iteration: #4
# 2020-04-01 10:29:40,320 - biomed_ie - INFO - Number of training samples: 199
# Performance: {'f1_score': 0.6360517870974881}
# Active learning iteration: #5
# 2020-04-01 10:29:42,015 - biomed_ie - INFO - Number of training samples: 229
# Performance: {'f1_score': 0.6418911489829576}
# Active learning iteration: #6
# 2020-04-01 10:29:43,748 - biomed_ie - INFO - Number of training samples: 259
# Performance: {'f1_score': 0.6458218650225697}
# Active learning iteration: #7
# 2020-04-01 10:29:45,536 - biomed_ie - INFO - Number of training samples: 289
# Performance: {'f1_score': 0.6509985655963808}
# Active learning iteration: #8
# 2020-04-01 10:29:47,436 - biomed_ie - INFO - Number of training samples: 319
# Performance: {'f1_score': 0.6575644131248622}
# Active learning iteration: #9
# 2020-04-01 10:29:49,346 - biomed_ie - INFO - Number of training samples: 349
# Performance: {'f1_score': 0.663063857946399}
# Active learning iteration: #10
# 2020-04-01 10:29:51,315 - biomed_ie - INFO - Number of training samples: 379
# Performance: {'f1_score': 0.6699779249448125}
# Active learning iteration: #11
# 2020-04-01 10:29:53,189 - biomed_ie - INFO - Number of training samples: 409
# Performance: {'f1_score': 0.6750635288918351}
# Active learning iteration: #12
# 2020-04-01 10:29:55,271 - biomed_ie - INFO - Number of training samples: 438
# Performance: {'f1_score': 0.6826625386996904}
# Active learning iteration: #13
# 2020-04-01 10:29:57,411 - biomed_ie - INFO - Number of training samples: 468
# Performance: {'f1_score': 0.6851769911504425}
# Active learning iteration: #14
# 2020-04-01 10:29:59,606 - biomed_ie - INFO - Number of training samples: 498
# Performance: {'f1_score': 0.6944996686547382}
# Active learning iteration: #15
# 2020-04-01 10:30:01,703 - biomed_ie - INFO - Number of training samples: 528
# Performance: {'f1_score': 0.6981007067137809}
# Active learning iteration: #16
# 2020-04-01 10:30:04,019 - biomed_ie - INFO - Number of training samples: 558
# Performance: {'f1_score': 0.7028929710702893}
# Active learning iteration: #17
# 2020-04-01 10:30:06,362 - biomed_ie - INFO - Number of training samples: 588
# Performance: {'f1_score': 0.7089413055403182}
# Active learning iteration: #18
# 2020-04-01 10:30:08,628 - biomed_ie - INFO - Number of training samples: 618
# Performance: {'f1_score': 0.7157894736842105}
# Active learning iteration: #19
# 2020-04-01 10:30:11,144 - biomed_ie - INFO - Number of training samples: 648
# Performance: {'f1_score': 0.71729587357331}
# Active learning iteration: #20
# 2020-04-01 10:30:13,655 - biomed_ie - INFO - Number of training samples: 678
# Performance: {'f1_score': 0.7227908000440191}
# Active learning iteration: #21
# 2020-04-01 10:30:16,067 - biomed_ie - INFO - Number of training samples: 708
# Performance: {'f1_score': 0.727791182276815}
# Active learning iteration: #22
# 2020-04-01 10:30:18,729 - biomed_ie - INFO - Number of training samples: 737
# Performance: {'f1_score': 0.7333772218564847}
# Active learning iteration: #23
# 2020-04-01 10:30:21,384 - biomed_ie - INFO - Number of training samples: 767
# Performance: {'f1_score': 0.7347878522091875}
# Active learning iteration: #24
# 2020-04-01 10:30:24,094 - biomed_ie - INFO - Number of training samples: 796
# Performance: {'f1_score': 0.7357252242397725}

# %%
max_samples_number = 30
repeats = 10
active_iterations = 25
N_SAMPLES_PER_AL_ITER = 100

for repeat in range(repeats):
    for strat_name, strat in strategies_to_try.items():
        
        path = os.path.join('../workdir/experiments/crf/', strat_name)
        if os.path.exists(os.path.join(path, f'statistics{repeat}.json')):
            print(f'statistics{repeat}.json already exists. Next')
            continue
    
        print('Active learning strategy', strat_name)
        print('Repeat', repeat)
    
        y_seed = y_train2y_seed(y_train, n_seeds_per_class=200)
    
        active_tagger = CRF_active(algorithm="lbfgs",
              c1=0.1,
              c2=0.1,
              max_iterations=100,
              all_possible_transitions=True)
        
        active_learn_alg_ctor = make_libact_strategy_ctor(lambda tr_ds: strat(tr_ds, active_tagger), max_samples_number=max_samples_number)
        
        active_learner = ActiveLearner1(active_learn_alg_ctor = active_learn_alg_ctor,
                                y_dtype = 'str',
                                X_full_dataset = X_train, 
                                y_full_dataset = y_seed,
                                X_test_dataset = X_test,
                                y_test_dataset = y_test,
                                model_evaluate=active_tagger,
                                eval_metrics=[f1_score],
                                rnd_start_steps=0,
                                rnd_start_samples=max_samples_number)                
            
        statistics = emulate_active_learning(y_train, active_learner, max_iterations=active_iterations)
        dump_file(statistics, path, f'statistics{repeat}.json')
# Out:
# statistics0.json already exists. Next
# Active learning strategy random
# Repeat 0
# Start emulating active learning.
# Evaluation: {'f1_score': 0.7591740665454155}
# Active learning iteration: #0
# 2020-04-01 06:40:15,828 - biomed_ie - INFO - Number of training samples: 974
# Performance: {'f1_score': 0.7613648518558134}
# Active learning iteration: #1
# 2020-04-01 06:40:19,297 - biomed_ie - INFO - Number of training samples: 1004
# Performance: {'f1_score': 0.7619047619047619}
# Active learning iteration: #2
# 2020-04-01 06:40:22,624 - biomed_ie - INFO - Number of training samples: 1034
# Performance: {'f1_score': 0.7620171673819741}
# Active learning iteration: #3
# 2020-04-01 06:40:26,163 - biomed_ie - INFO - Number of training samples: 1064
# Performance: {'f1_score': 0.7674643202060306}
# Active learning iteration: #4
# 2020-04-01 06:40:29,658 - biomed_ie - INFO - Number of training samples: 1094
# Performance: {'f1_score': 0.7686695278969957}
# Active learning iteration: #5
# 2020-04-01 06:40:33,306 - biomed_ie - INFO - Number of training samples: 1124
# Performance: {'f1_score': 0.773235800344234}
# Active learning iteration: #6
# 2020-04-01 06:40:36,943 - biomed_ie - INFO - Number of training samples: 1154
# Performance: {'f1_score': 0.7740963855421688}
# Active learning iteration: #7
# 2020-04-01 06:40:40,663 - biomed_ie - INFO - Number of training samples: 1184
# Performance: {'f1_score': 0.7758880516684606}
# Active learning iteration: #8
# 2020-04-01 06:40:44,308 - biomed_ie - INFO - Number of training samples: 1214
# Performance: {'f1_score': 0.7796063246208456}
# Active learning iteration: #9
# 2020-04-01 06:40:48,142 - biomed_ie - INFO - Number of training samples: 1244
# Performance: {'f1_score': 0.7785668173014849}
# Active learning iteration: #10
# 2020-04-01 06:40:51,929 - biomed_ie - INFO - Number of training samples: 1274
# Performance: {'f1_score': 0.7797413793103448}
# Active learning iteration: #11
# 2020-04-01 06:40:55,749 - biomed_ie - INFO - Number of training samples: 1304
# Performance: {'f1_score': 0.7822250914568538}
# Active learning iteration: #12
# 2020-04-01 06:40:59,743 - biomed_ie - INFO - Number of training samples: 1333
# Performance: {'f1_score': 0.7829457364341086}
# Active learning iteration: #13
# 2020-04-01 06:41:03,689 - biomed_ie - INFO - Number of training samples: 1363
# Performance: {'f1_score': 0.7835539769669572}
# Active learning iteration: #14
# 2020-04-01 06:41:07,781 - biomed_ie - INFO - Number of training samples: 1393
# Performance: {'f1_score': 0.7853064742001508}
# Active learning iteration: #15
# 2020-04-01 06:41:11,854 - biomed_ie - INFO - Number of training samples: 1423
# Performance: {'f1_score': 0.7891112545728427}
# Active learning iteration: #16
# 2020-04-01 06:41:16,034 - biomed_ie - INFO - Number of training samples: 1453
# Performance: {'f1_score': 0.7891566265060241}
# Active learning iteration: #17
# 2020-04-01 06:41:20,119 - biomed_ie - INFO - Number of training samples: 1483
# Performance: {'f1_score': 0.7895813152513185}
# Active learning iteration: #18
# 2020-04-01 06:41:24,312 - biomed_ie - INFO - Number of training samples: 1513
# Performance: {'f1_score': 0.791487532244196}
# Active learning iteration: #19
# 2020-04-01 06:41:28,525 - biomed_ie - INFO - Number of training samples: 1543
# Performance: {'f1_score': 0.7883415788341578}
# Active learning iteration: #20
# 2020-04-01 06:41:32,967 - biomed_ie - INFO - Number of training samples: 1573
# Performance: {'f1_score': 0.7932816537467701}
# Active learning iteration: #21
# 2020-04-01 06:41:37,316 - biomed_ie - INFO - Number of training samples: 1603
# Performance: {'f1_score': 0.7941872981700753}
# Active learning iteration: #22
# 2020-04-01 06:41:41,797 - biomed_ie - INFO - Number of training samples: 1633
# Performance: {'f1_score': 0.7944438462366749}
# Active learning iteration: #23
# 2020-04-01 06:41:46,409 - biomed_ie - INFO - Number of training samples: 1663
# Performance: {'f1_score': 0.7970249002910423}
# Active learning iteration: #24
# 2020-04-01 06:41:51,058 - biomed_ie - INFO - Number of training samples: 1693
# Performance: {'f1_score': 0.7989229940764674}
# statistics1.json already exists. Next
# Active learning strategy random
# Repeat 1
# Start emulating active learning.
# Evaluation: {'f1_score': 0.7653468551084259}
# Active learning iteration: #0
# 2020-04-01 06:41:58,569 - biomed_ie - INFO - Number of training samples: 974
# Performance: {'f1_score': 0.7689647719904906}
# Active learning iteration: #1
# 2020-04-01 06:42:02,058 - biomed_ie - INFO - Number of training samples: 1004
# Performance: {'f1_score': 0.7706441850410721}
# Active learning iteration: #2
# 2020-04-01 06:42:05,370 - biomed_ie - INFO - Number of training samples: 1034
# Performance: {'f1_score': 0.7687479709988096}
# Active learning iteration: #3
# 2020-04-01 06:42:08,932 - biomed_ie - INFO - Number of training samples: 1064
# Performance: {'f1_score': 0.776061358971589}
# Active learning iteration: #4
# 2020-04-01 06:42:12,364 - biomed_ie - INFO - Number of training samples: 1094
# Performance: {'f1_score': 0.7761194029850745}
# Active learning iteration: #5
# 2020-04-01 06:42:15,964 - biomed_ie - INFO - Number of training samples: 1124
# Performance: {'f1_score': 0.7796390359883281}
# Active learning iteration: #6
# 2020-04-01 06:42:19,579 - biomed_ie - INFO - Number of training samples: 1154
# Performance: {'f1_score': 0.7804086928316575}
# Active learning iteration: #7
# 2020-04-01 06:42:23,274 - biomed_ie - INFO - Number of training samples: 1184
# Performance: {'f1_score': 0.7844240129799891}
# Active learning iteration: #8
# 2020-04-01 06:42:26,897 - biomed_ie - INFO - Number of training samples: 1214
# Performance: {'f1_score': 0.7858843905607273}
# Active learning iteration: #9
# 2020-04-01 06:42:30,721 - biomed_ie - INFO - Number of training samples: 1244
# Performance: {'f1_score': 0.7867575462512172}
# Active learning iteration: #10
# 2020-04-01 06:42:34,557 - biomed_ie - INFO - Number of training samples: 1274
# Performance: {'f1_score': 0.7885343428880476}
# Active learning iteration: #11
# 2020-04-01 06:42:38,576 - biomed_ie - INFO - Number of training samples: 1304
# Performance: {'f1_score': 0.7865338817925959}
# Active learning iteration: #12
# 2020-04-01 06:42:42,506 - biomed_ie - INFO - Number of training samples: 1334
# Performance: {'f1_score': 0.7893142980748433}
# Active learning iteration: #13
# 2020-04-01 06:42:46,415 - biomed_ie - INFO - Number of training samples: 1364
# Performance: {'f1_score': 0.7945057322085227}
# Active learning iteration: #14
# 2020-04-01 06:42:50,527 - biomed_ie - INFO - Number of training samples: 1394
# Performance: {'f1_score': 0.7937675827742913}
# Active learning iteration: #15
# 2020-04-01 06:42:54,572 - biomed_ie - INFO - Number of training samples: 1424
# Performance: {'f1_score': 0.7929991356957649}
# Active learning iteration: #16
# 2020-04-01 06:42:58,856 - biomed_ie - INFO - Number of training samples: 1454
# Performance: {'f1_score': 0.7953709712308025}
# Active learning iteration: #17
# 2020-04-01 06:43:03,132 - biomed_ie - INFO - Number of training samples: 1484
# Performance: {'f1_score': 0.7947579334994043}
# Active learning iteration: #18
# 2020-04-01 06:43:07,363 - biomed_ie - INFO - Number of training samples: 1514
# Performance: {'f1_score': 0.7985284570439298}
# Active learning iteration: #19
# 2020-04-01 06:43:11,758 - biomed_ie - INFO - Number of training samples: 1544
# Performance: {'f1_score': 0.8040233614536015}
# Active learning iteration: #20
# 2020-04-01 06:43:16,228 - biomed_ie - INFO - Number of training samples: 1574
# Performance: {'f1_score': 0.8040233614536015}
# Active learning iteration: #21
# 2020-04-01 06:43:20,698 - biomed_ie - INFO - Number of training samples: 1604
# Performance: {'f1_score': 0.8069264069264069}
# Active learning iteration: #22
# 2020-04-01 06:43:25,223 - biomed_ie - INFO - Number of training samples: 1634
# Performance: {'f1_score': 0.8087360795761706}
# Active learning iteration: #23
# 2020-04-01 06:43:29,578 - biomed_ie - INFO - Number of training samples: 1664
# Performance: {'f1_score': 0.8076507456235141}
# Active learning iteration: #24
# 2020-04-01 06:43:34,240 - biomed_ie - INFO - Number of training samples: 1694
# Performance: {'f1_score': 0.8128376918089475}
# statistics2.json already exists. Next
# Active learning strategy random
# Repeat 2
# Start emulating active learning.
# Evaluation: {'f1_score': 0.7633457645178476}
# Active learning iteration: #0
# 2020-04-01 06:43:41,906 - biomed_ie - INFO - Number of training samples: 982
# Performance: {'f1_score': 0.7650191734128674}
# Active learning iteration: #1
# 2020-04-01 06:43:45,319 - biomed_ie - INFO - Number of training samples: 1012
# Performance: {'f1_score': 0.7650249973407084}
# Active learning iteration: #2
# 2020-04-01 06:43:48,689 - biomed_ie - INFO - Number of training samples: 1042
# Performance: {'f1_score': 0.771492489613295}
# Active learning iteration: #3
# 2020-04-01 06:43:52,234 - biomed_ie - INFO - Number of training samples: 1072
# Performance: {'f1_score': 0.7696898646488328}
# Active learning iteration: #4
# 2020-04-01 06:43:55,722 - biomed_ie - INFO - Number of training samples: 1102
# Performance: {'f1_score': 0.7738500851788757}
# Active learning iteration: #5
# 2020-04-01 06:43:59,398 - biomed_ie - INFO - Number of training samples: 1132
# Performance: {'f1_score': 0.7734783072167146}
# Active learning iteration: #6
# 2020-04-01 06:44:03,051 - biomed_ie - INFO - Number of training samples: 1162
# Performance: {'f1_score': 0.7760238907849828}
# Active learning iteration: #7
# 2020-04-01 06:44:06,825 - biomed_ie - INFO - Number of training samples: 1192
# Performance: {'f1_score': 0.7767571031830804}
# Active learning iteration: #8
# 2020-04-01 06:44:10,533 - biomed_ie - INFO - Number of training samples: 1222
# Performance: {'f1_score': 0.7803418803418803}
# Active learning iteration: #9
# 2020-04-01 06:44:14,223 - biomed_ie - INFO - Number of training samples: 1252
# Performance: {'f1_score': 0.784385026737968}
# Active learning iteration: #10
# 2020-04-01 06:44:18,112 - biomed_ie - INFO - Number of training samples: 1282
# Performance: {'f1_score': 0.7851708989606772}
# Active learning iteration: #11
# 2020-04-01 06:44:21,980 - biomed_ie - INFO - Number of training samples: 1312
# Performance: {'f1_score': 0.7869555889294143}
# Active learning iteration: #12
# 2020-04-01 06:44:26,036 - biomed_ie - INFO - Number of training samples: 1342
# Performance: {'f1_score': 0.7957890213771618}
# Active learning iteration: #13
# 2020-04-01 06:44:30,010 - biomed_ie - INFO - Number of training samples: 1372
# Performance: {'f1_score': 0.7953103151554266}
# Active learning iteration: #14
# 2020-04-01 06:44:34,049 - biomed_ie - INFO - Number of training samples: 1402
# Performance: {'f1_score': 0.7999138488046522}
# Active learning iteration: #15
# 2020-04-01 06:44:38,267 - biomed_ie - INFO - Number of training samples: 1432
# Performance: {'f1_score': 0.7982333297425401}
# Active learning iteration: #16
# 2020-04-01 06:44:42,460 - biomed_ie - INFO - Number of training samples: 1462
# Performance: {'f1_score': 0.8003015941404568}
# Active learning iteration: #17
# 2020-04-01 06:44:46,836 - biomed_ie - INFO - Number of training samples: 1492
# Performance: {'f1_score': 0.801078167115903}
# Active learning iteration: #18
# 2020-04-01 06:44:51,217 - biomed_ie - INFO - Number of training samples: 1522
# Performance: {'f1_score': 0.8023706896551724}
# Active learning iteration: #19
# 2020-04-01 06:44:55,652 - biomed_ie - INFO - Number of training samples: 1552
# Performance: {'f1_score': 0.8031903427462814}
# Active learning iteration: #20
# 2020-04-01 06:45:00,213 - biomed_ie - INFO - Number of training samples: 1582
# Performance: {'f1_score': 0.8068928379106084}
# Active learning iteration: #21
# 2020-04-01 06:45:04,696 - biomed_ie - INFO - Number of training samples: 1612
# Performance: {'f1_score': 0.806934424464305}
# Active learning iteration: #22
# 2020-04-01 06:45:09,327 - biomed_ie - INFO - Number of training samples: 1642
# Performance: {'f1_score': 0.8080068876452863}
# Active learning iteration: #23
# 2020-04-01 06:45:13,881 - biomed_ie - INFO - Number of training samples: 1672
# Performance: {'f1_score': 0.8090684431073386}
# Active learning iteration: #24
# 2020-04-01 06:45:18,589 - biomed_ie - INFO - Number of training samples: 1702
# Performance: {'f1_score': 0.8116938950988823}
# statistics3.json already exists. Next
# Active learning strategy random
# Repeat 3
# Start emulating active learning.
# Evaluation: {'f1_score': 0.7558499839726466}
# Active learning iteration: #0
# 2020-04-01 06:45:26,109 - biomed_ie - INFO - Number of training samples: 969
# Performance: {'f1_score': 0.7585838057546263}
# Active learning iteration: #1
# 2020-04-01 06:45:29,493 - biomed_ie - INFO - Number of training samples: 999
# Performance: {'f1_score': 0.7626900835296637}
# Active learning iteration: #2
# 2020-04-01 06:45:32,984 - biomed_ie - INFO - Number of training samples: 1029
# Performance: {'f1_score': 0.7704830245260791}
# Active learning iteration: #3
# 2020-04-01 06:45:36,408 - biomed_ie - INFO - Number of training samples: 1059
# Performance: {'f1_score': 0.7689337052134734}
# Active learning iteration: #4
# 2020-04-01 06:45:40,041 - biomed_ie - INFO - Number of training samples: 1089
# Performance: {'f1_score': 0.7698906283508472}
# Active learning iteration: #5
# 2020-04-01 06:45:43,557 - biomed_ie - INFO - Number of training samples: 1119
# Performance: {'f1_score': 0.7758787487907127}
# Active learning iteration: #6
# 2020-04-01 06:45:47,257 - biomed_ie - INFO - Number of training samples: 1149
# Performance: {'f1_score': 0.7767261776726176}
# Active learning iteration: #7
# 2020-04-01 06:45:50,861 - biomed_ie - INFO - Number of training samples: 1179
# Performance: {'f1_score': 0.7798471310151792}
# Active learning iteration: #8
# 2020-04-01 06:45:54,515 - biomed_ie - INFO - Number of training samples: 1209
# Performance: {'f1_score': 0.778148187977202}
# Active learning iteration: #9
# 2020-04-01 06:45:58,351 - biomed_ie - INFO - Number of training samples: 1239
# Performance: {'f1_score': 0.7805979780597979}
# Active learning iteration: #10
# 2020-04-01 06:46:02,146 - biomed_ie - INFO - Number of training samples: 1269
# Performance: {'f1_score': 0.7844021914276508}
# Active learning iteration: #11
# 2020-04-01 06:46:06,220 - biomed_ie - INFO - Number of training samples: 1299
# Performance: {'f1_score': 0.7828890799656062}
# Active learning iteration: #12
# 2020-04-01 06:46:10,067 - biomed_ie - INFO - Number of training samples: 1329
# Performance: {'f1_score': 0.7848618428126007}
# Active learning iteration: #13
# 2020-04-01 06:46:13,963 - biomed_ie - INFO - Number of training samples: 1359
# Performance: {'f1_score': 0.783403203267763}
# Active learning iteration: #14
# 2020-04-01 06:46:18,114 - biomed_ie - INFO - Number of training samples: 1389
# Performance: {'f1_score': 0.7829074511488083}
# Active learning iteration: #15
# 2020-04-01 06:46:22,107 - biomed_ie - INFO - Number of training samples: 1419
# Performance: {'f1_score': 0.7830198817839871}
# Active learning iteration: #16
# 2020-04-01 06:46:26,260 - biomed_ie - INFO - Number of training samples: 1449
# Performance: {'f1_score': 0.7854381443298969}
# Active learning iteration: #17
# 2020-04-01 06:46:30,406 - biomed_ie - INFO - Number of training samples: 1479
# Performance: {'f1_score': 0.786705388835108}
# Active learning iteration: #18
# 2020-04-01 06:46:34,713 - biomed_ie - INFO - Number of training samples: 1509
# Performance: {'f1_score': 0.7894284486463257}
# Active learning iteration: #19
# 2020-04-01 06:46:38,917 - biomed_ie - INFO - Number of training samples: 1539
# Performance: {'f1_score': 0.7925623387790197}
# Active learning iteration: #20
# 2020-04-01 06:46:43,426 - biomed_ie - INFO - Number of training samples: 1569
# Performance: {'f1_score': 0.7940324138671245}
# Active learning iteration: #21
# 2020-04-01 06:46:47,862 - biomed_ie - INFO - Number of training samples: 1599
# Performance: {'f1_score': 0.7945882100289918}
# Active learning iteration: #22
# 2020-04-01 06:46:52,288 - biomed_ie - INFO - Number of training samples: 1629
# Performance: {'f1_score': 0.7954447786850021}
# Active learning iteration: #23
# 2020-04-01 06:46:56,941 - biomed_ie - INFO - Number of training samples: 1659
# Performance: {'f1_score': 0.7948414830736165}
# Active learning iteration: #24
# 2020-04-01 06:47:01,483 - biomed_ie - INFO - Number of training samples: 1689
# Performance: {'f1_score': 0.7953983442640576}
# statistics4.json already exists. Next
# Active learning strategy random
# Repeat 4
# Start emulating active learning.
# Evaluation: {'f1_score': 0.7637297933840062}
# Active learning iteration: #0
# 2020-04-01 06:47:08,773 - biomed_ie - INFO - Number of training samples: 970
# Performance: {'f1_score': 0.7619353457503746}
# Active learning iteration: #1
# 2020-04-01 06:47:12,119 - biomed_ie - INFO - Number of training samples: 1000
# Performance: {'f1_score': 0.7654109589041096}
# Active learning iteration: #2
# 2020-04-01 06:47:15,576 - biomed_ie - INFO - Number of training samples: 1030
# Performance: {'f1_score': 0.7670880651382044}
# Active learning iteration: #3
# 2020-04-01 06:47:18,896 - biomed_ie - INFO - Number of training samples: 1060
# Performance: {'f1_score': 0.7678935508101727}
# Active learning iteration: #4
# 2020-04-01 06:47:22,471 - biomed_ie - INFO - Number of training samples: 1090
# Performance: {'f1_score': 0.7685035986679557}
# Active learning iteration: #5
# 2020-04-01 06:47:25,981 - biomed_ie - INFO - Number of training samples: 1120
# Performance: {'f1_score': 0.7691316947515294}
# Active learning iteration: #6
# 2020-04-01 06:47:29,640 - biomed_ie - INFO - Number of training samples: 1150
# Performance: {'f1_score': 0.7797810688989054}
# Active learning iteration: #7
# 2020-04-01 06:47:33,169 - biomed_ie - INFO - Number of training samples: 1180
# Performance: {'f1_score': 0.7786850021486892}
# Active learning iteration: #8
# 2020-04-01 06:47:36,797 - biomed_ie - INFO - Number of training samples: 1210
# Performance: {'f1_score': 0.7802575107296137}
# Active learning iteration: #9
# 2020-04-01 06:47:40,608 - biomed_ie - INFO - Number of training samples: 1240
# Performance: {'f1_score': 0.7813104189044039}
# Active learning iteration: #10
# 2020-04-01 06:47:44,347 - biomed_ie - INFO - Number of training samples: 1270
# Performance: {'f1_score': 0.7870787722687274}
# Active learning iteration: #11
# 2020-04-01 06:47:48,298 - biomed_ie - INFO - Number of training samples: 1300
# Performance: {'f1_score': 0.7867339272297951}
# Active learning iteration: #12
# 2020-04-01 06:47:52,077 - biomed_ie - INFO - Number of training samples: 1330
# Performance: {'f1_score': 0.7858752817430504}
# Active learning iteration: #13
# 2020-04-01 06:47:55,959 - biomed_ie - INFO - Number of training samples: 1360
# Performance: {'f1_score': 0.7848400257676617}
# Active learning iteration: #14
# 2020-04-01 06:47:59,997 - biomed_ie - INFO - Number of training samples: 1390
# Performance: {'f1_score': 0.785169263836647}
# Active learning iteration: #15
# 2020-04-01 06:48:04,043 - biomed_ie - INFO - Number of training samples: 1420
# Performance: {'f1_score': 0.7870051635111878}
# Active learning iteration: #16
# 2020-04-01 06:48:08,154 - biomed_ie - INFO - Number of training samples: 1450
# Performance: {'f1_score': 0.7874354561101549}
# Active learning iteration: #17
# 2020-04-01 06:48:12,248 - biomed_ie - INFO - Number of training samples: 1480
# Performance: {'f1_score': 0.7886021505376344}
# Active learning iteration: #18
# 2020-04-01 06:48:16,478 - biomed_ie - INFO - Number of training samples: 1509
# Performance: {'f1_score': 0.790187217559716}
# Active learning iteration: #19
# 2020-04-01 06:48:20,674 - biomed_ie - INFO - Number of training samples: 1539
# Performance: {'f1_score': 0.7925422998167906}
# Active learning iteration: #20
# 2020-04-01 06:48:24,971 - biomed_ie - INFO - Number of training samples: 1569
# Performance: {'f1_score': 0.7918103448275862}
# Active learning iteration: #21
# 2020-04-01 06:48:29,180 - biomed_ie - INFO - Number of training samples: 1599
# Performance: {'f1_score': 0.7947777298230472}
# Active learning iteration: #22
# 2020-04-01 06:48:33,514 - biomed_ie - INFO - Number of training samples: 1629
# Performance: {'f1_score': 0.7951703320396724}
# Active learning iteration: #23
# 2020-04-01 06:48:37,837 - biomed_ie - INFO - Number of training samples: 1659
# Performance: {'f1_score': 0.7993094518774276}
# Active learning iteration: #24
# 2020-04-01 06:48:42,279 - biomed_ie - INFO - Number of training samples: 1689
# Performance: {'f1_score': 0.7988772535895498}
# statistics5.json already exists. Next
# Active learning strategy random
# Repeat 5
# Start emulating active learning.
# Evaluation: {'f1_score': 0.7705516205194247}
# Active learning iteration: #0
# 2020-04-01 06:48:49,760 - biomed_ie - INFO - Number of training samples: 981
# Performance: {'f1_score': 0.7715420109453804}
# Active learning iteration: #1
# 2020-04-01 06:48:53,131 - biomed_ie - INFO - Number of training samples: 1011
# Performance: {'f1_score': 0.7722198368398454}
# Active learning iteration: #2
# 2020-04-01 06:48:56,702 - biomed_ie - INFO - Number of training samples: 1041
# Performance: {'f1_score': 0.7743804312841971}
# Active learning iteration: #3
# 2020-04-01 06:49:00,244 - biomed_ie - INFO - Number of training samples: 1071
# Performance: {'f1_score': 0.7782184585700503}
# Active learning iteration: #4
# 2020-04-01 06:49:03,993 - biomed_ie - INFO - Number of training samples: 1101
# Performance: {'f1_score': 0.7791147400085948}
# Active learning iteration: #5
# 2020-04-01 06:49:07,761 - biomed_ie - INFO - Number of training samples: 1131
# Performance: {'f1_score': 0.7835251102269062}
# Active learning iteration: #6
# 2020-04-01 06:49:11,362 - biomed_ie - INFO - Number of training samples: 1161
# Performance: {'f1_score': 0.7874879071267332}
# Active learning iteration: #7
# 2020-04-01 06:49:15,066 - biomed_ie - INFO - Number of training samples: 1191
# Performance: {'f1_score': 0.790597831920146}
# Active learning iteration: #8
# 2020-04-01 06:49:18,952 - biomed_ie - INFO - Number of training samples: 1221
# Performance: {'f1_score': 0.7917516915476318}
# Active learning iteration: #9
# 2020-04-01 06:49:22,771 - biomed_ie - INFO - Number of training samples: 1251
# Performance: {'f1_score': 0.7911426421584434}
# Active learning iteration: #10
# 2020-04-01 06:49:26,740 - biomed_ie - INFO - Number of training samples: 1281
# Performance: {'f1_score': 0.7921324161650903}
# Active learning iteration: #11
# 2020-04-01 06:49:30,653 - biomed_ie - INFO - Number of training samples: 1311
# Performance: {'f1_score': 0.7930292598967298}
# Active learning iteration: #12
# 2020-04-01 06:49:34,614 - biomed_ie - INFO - Number of training samples: 1341
# Performance: {'f1_score': 0.794285100440434}
# Active learning iteration: #13
# 2020-04-01 06:49:38,785 - biomed_ie - INFO - Number of training samples: 1371
# Performance: {'f1_score': 0.7975091260468112}
# Active learning iteration: #14
# 2020-04-01 06:49:42,896 - biomed_ie - INFO - Number of training samples: 1401
# Performance: {'f1_score': 0.7997852925389157}
# Active learning iteration: #15
# 2020-04-01 06:49:47,155 - biomed_ie - INFO - Number of training samples: 1431
# Performance: {'f1_score': 0.8011180391313697}
# Active learning iteration: #16
# 2020-04-01 06:49:51,361 - biomed_ie - INFO - Number of training samples: 1461
# Performance: {'f1_score': 0.8018512539016253}
# Active learning iteration: #17
# 2020-04-01 06:49:55,779 - biomed_ie - INFO - Number of training samples: 1491
# Performance: {'f1_score': 0.8023681377825619}
# Active learning iteration: #18
# 2020-04-01 06:50:00,191 - biomed_ie - INFO - Number of training samples: 1521
# Performance: {'f1_score': 0.8018482699333763}
# Active learning iteration: #19
# 2020-04-01 06:50:04,643 - biomed_ie - INFO - Number of training samples: 1551
# Performance: {'f1_score': 0.8024518765458651}
# Active learning iteration: #20
# 2020-04-01 06:50:09,013 - biomed_ie - INFO - Number of training samples: 1581
# Performance: {'f1_score': 0.8060632122124276}
# Active learning iteration: #21
# 2020-04-01 06:50:13,358 - biomed_ie - INFO - Number of training samples: 1611
# Performance: {'f1_score': 0.8062265163714439}
# Active learning iteration: #22
# 2020-04-01 06:50:17,887 - biomed_ie - INFO - Number of training samples: 1641
# Performance: {'f1_score': 0.8068743286788399}
# Active learning iteration: #23
# 2020-04-01 06:50:22,403 - biomed_ie - INFO - Number of training samples: 1671
# Performance: {'f1_score': 0.8082088750402923}
# Active learning iteration: #24
# 2020-04-01 06:50:27,004 - biomed_ie - INFO - Number of training samples: 1701
# Performance: {'f1_score': 0.8077832724145346}
# statistics6.json already exists. Next
# Active learning strategy random
# Repeat 6
# Start emulating active learning.
# Evaluation: {'f1_score': 0.7662449067124169}
# Active learning iteration: #0
# 2020-04-01 06:50:34,679 - biomed_ie - INFO - Number of training samples: 965
# Performance: {'f1_score': 0.7667560321715818}
# Active learning iteration: #1
# 2020-04-01 06:50:37,996 - biomed_ie - INFO - Number of training samples: 995
# Performance: {'f1_score': 0.7668204742998176}
# Active learning iteration: #2
# 2020-04-01 06:50:41,532 - biomed_ie - INFO - Number of training samples: 1025
# Performance: {'f1_score': 0.7706204968276159}
# Active learning iteration: #3
# 2020-04-01 06:50:45,148 - biomed_ie - INFO - Number of training samples: 1054
# Performance: {'f1_score': 0.7747767136554397}
# Active learning iteration: #4
# 2020-04-01 06:50:48,669 - biomed_ie - INFO - Number of training samples: 1084
# Performance: {'f1_score': 0.7731925439069066}
# Active learning iteration: #5
# 2020-04-01 06:50:52,339 - biomed_ie - INFO - Number of training samples: 1114
# Performance: {'f1_score': 0.7759327151175328}
# Active learning iteration: #6
# 2020-04-01 06:50:55,958 - biomed_ie - INFO - Number of training samples: 1144
# Performance: {'f1_score': 0.7741379310344827}
# Active learning iteration: #7
# 2020-04-01 06:50:59,820 - biomed_ie - INFO - Number of training samples: 1174
# Performance: {'f1_score': 0.7767722473604826}
# Active learning iteration: #8
# 2020-04-01 06:51:03,589 - biomed_ie - INFO - Number of training samples: 1204
# Performance: {'f1_score': 0.7803144518630196}
# Active learning iteration: #9
# 2020-04-01 06:51:07,330 - biomed_ie - INFO - Number of training samples: 1234
# Performance: {'f1_score': 0.7838772422736114}
# Active learning iteration: #10
# 2020-04-01 06:51:11,272 - biomed_ie - INFO - Number of training samples: 1264
# Performance: {'f1_score': 0.7842332613390929}
# Active learning iteration: #11
# 2020-04-01 06:51:15,129 - biomed_ie - INFO - Number of training samples: 1294
# Performance: {'f1_score': 0.7885134405700096}
# Active learning iteration: #12
# 2020-04-01 06:51:19,170 - biomed_ie - INFO - Number of training samples: 1323
# Performance: {'f1_score': 0.7916216799827251}
# Active learning iteration: #13
# 2020-04-01 06:51:23,153 - biomed_ie - INFO - Number of training samples: 1353
# Performance: {'f1_score': 0.7967198964177816}
# Active learning iteration: #14
# 2020-04-01 06:51:27,295 - biomed_ie - INFO - Number of training samples: 1383
# Performance: {'f1_score': 0.7964220282358013}
# Active learning iteration: #15
# 2020-04-01 06:51:31,317 - biomed_ie - INFO - Number of training samples: 1413
# Performance: {'f1_score': 0.795687331536388}
# Active learning iteration: #16
# 2020-04-01 06:51:35,497 - biomed_ie - INFO - Number of training samples: 1443
# Performance: {'f1_score': 0.7967654986522912}
# Active learning iteration: #17
# 2020-04-01 06:51:39,855 - biomed_ie - INFO - Number of training samples: 1473
# Performance: {'f1_score': 0.7987495957744961}
# Active learning iteration: #18
# 2020-04-01 06:51:44,073 - biomed_ie - INFO - Number of training samples: 1503
# Performance: {'f1_score': 0.8003020822095156}
# Active learning iteration: #19
# 2020-04-01 06:51:48,595 - biomed_ie - INFO - Number of training samples: 1533
# Performance: {'f1_score': 0.8019427954668107}
# Active learning iteration: #20
# 2020-04-01 06:51:52,932 - biomed_ie - INFO - Number of training samples: 1562
# Performance: {'f1_score': 0.8033211127884408}
# Active learning iteration: #21
# 2020-04-01 06:51:57,427 - biomed_ie - INFO - Number of training samples: 1592
# Performance: {'f1_score': 0.8035386773114684}
# Active learning iteration: #22
# 2020-04-01 06:52:02,150 - biomed_ie - INFO - Number of training samples: 1622
# Performance: {'f1_score': 0.8038411739318085}
# Active learning iteration: #23
# 2020-04-01 06:52:06,633 - biomed_ie - INFO - Number of training samples: 1652
# Performance: {'f1_score': 0.8094518774277083}
# Active learning iteration: #24
# 2020-04-01 06:52:11,282 - biomed_ie - INFO - Number of training samples: 1682
# Performance: {'f1_score': 0.8094107489747464}
# statistics7.json already exists. Next
# Active learning strategy random
# Repeat 7
# Start emulating active learning.
# Evaluation: {'f1_score': 0.7609022556390976}
# Active learning iteration: #0
# 2020-04-01 06:52:18,757 - biomed_ie - INFO - Number of training samples: 966
# Performance: {'f1_score': 0.7671350423683364}
# Active learning iteration: #1
# 2020-04-01 06:52:22,201 - biomed_ie - INFO - Number of training samples: 996
# Performance: {'f1_score': 0.7711645896003437}
# Active learning iteration: #2
# 2020-04-01 06:52:25,581 - biomed_ie - INFO - Number of training samples: 1026
# Performance: {'f1_score': 0.7700247285238146}
# Active learning iteration: #3
# 2020-04-01 06:52:29,131 - biomed_ie - INFO - Number of training samples: 1056
# Performance: {'f1_score': 0.7749569707401033}
# Active learning iteration: #4
# 2020-04-01 06:52:32,771 - biomed_ie - INFO - Number of training samples: 1086
# Performance: {'f1_score': 0.7779931093884582}
# Active learning iteration: #5
# 2020-04-01 06:52:36,379 - biomed_ie - INFO - Number of training samples: 1116
# Performance: {'f1_score': 0.7783166289470849}
# Active learning iteration: #6
# 2020-04-01 06:52:40,160 - biomed_ie - INFO - Number of training samples: 1146
# Performance: {'f1_score': 0.7808086253369272}
# Active learning iteration: #7
# 2020-04-01 06:52:43,836 - biomed_ie - INFO - Number of training samples: 1176
# Performance: {'f1_score': 0.7837808691901219}
# Active learning iteration: #8
# 2020-04-01 06:52:47,587 - biomed_ie - INFO - Number of training samples: 1206
# Performance: {'f1_score': 0.7825056554992997}
# Active learning iteration: #9
# 2020-04-01 06:52:51,612 - biomed_ie - INFO - Number of training samples: 1236
# Performance: {'f1_score': 0.7827493261455525}
# Active learning iteration: #10
# 2020-04-01 06:52:55,515 - biomed_ie - INFO - Number of training samples: 1265
# Performance: {'f1_score': 0.7842037116961588}
# Active learning iteration: #11
# 2020-04-01 06:52:59,541 - biomed_ie - INFO - Number of training samples: 1295
# Performance: {'f1_score': 0.7848511005610702}
# Active learning iteration: #12
# 2020-04-01 06:53:03,554 - biomed_ie - INFO - Number of training samples: 1325
# Performance: {'f1_score': 0.7872638963842418}
# Active learning iteration: #13
# 2020-04-01 06:53:07,613 - biomed_ie - INFO - Number of training samples: 1355
# Performance: {'f1_score': 0.7877414481493471}
# Active learning iteration: #14
# 2020-04-01 06:53:11,808 - biomed_ie - INFO - Number of training samples: 1385
# Performance: {'f1_score': 0.786439213992658}
# Active learning iteration: #15
# 2020-04-01 06:53:15,942 - biomed_ie - INFO - Number of training samples: 1414
# Performance: {'f1_score': 0.7891156462585034}
# Active learning iteration: #16
# 2020-04-01 06:53:20,235 - biomed_ie - INFO - Number of training samples: 1444
# Performance: {'f1_score': 0.7912301544443244}
# Active learning iteration: #17
# 2020-04-01 06:53:24,561 - biomed_ie - INFO - Number of training samples: 1474
# Performance: {'f1_score': 0.791099589544178}
# Active learning iteration: #18
# 2020-04-01 06:53:29,064 - biomed_ie - INFO - Number of training samples: 1504
# Performance: {'f1_score': 0.7939937344712111}
# Active learning iteration: #19
# 2020-04-01 06:53:33,370 - biomed_ie - INFO - Number of training samples: 1534
# Performance: {'f1_score': 0.793136937520233}
# Active learning iteration: #20
# 2020-04-01 06:53:37,845 - biomed_ie - INFO - Number of training samples: 1564
# Performance: {'f1_score': 0.79650032404407}
# Active learning iteration: #21
# 2020-04-01 06:53:42,370 - biomed_ie - INFO - Number of training samples: 1594
# Performance: {'f1_score': 0.7979296959240889}
# Active learning iteration: #22
# 2020-04-01 06:53:47,061 - biomed_ie - INFO - Number of training samples: 1624
# Performance: {'f1_score': 0.8011234741276871}
# Active learning iteration: #23
# 2020-04-01 06:53:51,674 - biomed_ie - INFO - Number of training samples: 1654
# Performance: {'f1_score': 0.8038876889848813}
# Active learning iteration: #24
# 2020-04-01 06:53:56,509 - biomed_ie - INFO - Number of training samples: 1684
# Performance: {'f1_score': 0.8020720915173755}
# statistics8.json already exists. Next
# Active learning strategy random
# Repeat 8
# Start emulating active learning.
# Evaluation: {'f1_score': 0.7746268656716419}
# Active learning iteration: #0
# 2020-04-01 06:54:04,088 - biomed_ie - INFO - Number of training samples: 982
# Performance: {'f1_score': 0.7738082542390956}
# Active learning iteration: #1
# 2020-04-01 06:54:07,525 - biomed_ie - INFO - Number of training samples: 1012
# Performance: {'f1_score': 0.7737802925162806}
# Active learning iteration: #2
# 2020-04-01 06:54:10,934 - biomed_ie - INFO - Number of training samples: 1042
# Performance: {'f1_score': 0.7764579989299091}
# Active learning iteration: #3
# 2020-04-01 06:54:14,667 - biomed_ie - INFO - Number of training samples: 1072
# Performance: {'f1_score': 0.7780628608082105}
# Active learning iteration: #4
# 2020-04-01 06:54:18,224 - biomed_ie - INFO - Number of training samples: 1102
# Performance: {'f1_score': 0.7822641105280068}
# Active learning iteration: #5
# 2020-04-01 06:54:21,698 - biomed_ie - INFO - Number of training samples: 1132
# Performance: {'f1_score': 0.7824595261070011}
# Active learning iteration: #6
# 2020-04-01 06:54:25,198 - biomed_ie - INFO - Number of training samples: 1162
# Performance: {'f1_score': 0.7835493199100353}
# Active learning iteration: #7
# 2020-04-01 06:54:28,851 - biomed_ie - INFO - Number of training samples: 1192
# Performance: {'f1_score': 0.7825714591585483}
# Active learning iteration: #8
# 2020-04-01 06:54:32,513 - biomed_ie - INFO - Number of training samples: 1222
# Performance: {'f1_score': 0.7863796980404754}
# Active learning iteration: #9
# 2020-04-01 06:54:36,310 - biomed_ie - INFO - Number of training samples: 1252
# Performance: {'f1_score': 0.7860205831903946}
# Active learning iteration: #10
# 2020-04-01 06:54:40,059 - biomed_ie - INFO - Number of training samples: 1282
# Performance: {'f1_score': 0.7869168900804289}
# Active learning iteration: #11
# 2020-04-01 06:54:44,028 - biomed_ie - INFO - Number of training samples: 1312
# Performance: {'f1_score': 0.7891857096878017}
# Active learning iteration: #12
# 2020-04-01 06:54:47,862 - biomed_ie - INFO - Number of training samples: 1342
# Performance: {'f1_score': 0.7906079125120618}
# Active learning iteration: #13
# 2020-04-01 06:54:51,777 - biomed_ie - INFO - Number of training samples: 1372
# Performance: {'f1_score': 0.7890952023183428}
# Active learning iteration: #14
# 2020-04-01 06:54:55,844 - biomed_ie - INFO - Number of training samples: 1402
# Performance: {'f1_score': 0.792282958199357}
# Active learning iteration: #15
# 2020-04-01 06:54:59,795 - biomed_ie - INFO - Number of training samples: 1432
# Performance: {'f1_score': 0.7938685818415693}
# Active learning iteration: #16
# 2020-04-01 06:55:04,068 - biomed_ie - INFO - Number of training samples: 1462
# Performance: {'f1_score': 0.7952789699570816}
# Active learning iteration: #17
# 2020-04-01 06:55:08,175 - biomed_ie - INFO - Number of training samples: 1492
# Performance: {'f1_score': 0.7967322369128238}
# Active learning iteration: #18
# 2020-04-01 06:55:12,525 - biomed_ie - INFO - Number of training samples: 1522
# Performance: {'f1_score': 0.8007753607581305}
# Active learning iteration: #19
# 2020-04-01 06:55:16,817 - biomed_ie - INFO - Number of training samples: 1552
# Performance: {'f1_score': 0.802499730632475}
# Active learning iteration: #20
# 2020-04-01 06:55:21,049 - biomed_ie - INFO - Number of training samples: 1582
# Performance: {'f1_score': 0.8015967202502966}
# Active learning iteration: #21
# 2020-04-01 06:55:25,384 - biomed_ie - INFO - Number of training samples: 1612
# Performance: {'f1_score': 0.8009499136442142}
# Active learning iteration: #22
# 2020-04-01 06:55:29,749 - biomed_ie - INFO - Number of training samples: 1642
# Performance: {'f1_score': 0.8050463661850333}
# Active learning iteration: #23
# 2020-04-01 06:55:34,171 - biomed_ie - INFO - Number of training samples: 1671
# Performance: {'f1_score': 0.8049622437971953}
# Active learning iteration: #24
# 2020-04-01 06:55:38,662 - biomed_ie - INFO - Number of training samples: 1701
# Performance: {'f1_score': 0.806771619581626}
# statistics9.json already exists. Next
# Active learning strategy random
# Repeat 9
# Start emulating active learning.
# Evaluation: {'f1_score': 0.7605694102536659}
# Active learning iteration: #0
# 2020-04-01 06:55:46,295 - biomed_ie - INFO - Number of training samples: 973
# Performance: {'f1_score': 0.7621801049362887}
# Active learning iteration: #1
# 2020-04-01 06:55:49,559 - biomed_ie - INFO - Number of training samples: 1003
# Performance: {'f1_score': 0.7679279665559009}
# Active learning iteration: #2
# 2020-04-01 06:55:53,029 - biomed_ie - INFO - Number of training samples: 1033
# Performance: {'f1_score': 0.7668238319759966}
# Active learning iteration: #3
# 2020-04-01 06:55:56,398 - biomed_ie - INFO - Number of training samples: 1063
# Performance: {'f1_score': 0.7673871174834154}
# Active learning iteration: #4
# 2020-04-01 06:55:59,985 - biomed_ie - INFO - Number of training samples: 1093
# Performance: {'f1_score': 0.7706500750911822}
# Active learning iteration: #5
# 2020-04-01 06:56:03,631 - biomed_ie - INFO - Number of training samples: 1123
# Performance: {'f1_score': 0.77588241604978}
# Active learning iteration: #6
# 2020-04-01 06:56:07,183 - biomed_ie - INFO - Number of training samples: 1153
# Performance: {'f1_score': 0.781712813908564}
# Active learning iteration: #7
# 2020-04-01 06:56:10,765 - biomed_ie - INFO - Number of training samples: 1183
# Performance: {'f1_score': 0.7822355717657157}
# Active learning iteration: #8
# 2020-04-01 06:56:14,486 - biomed_ie - INFO - Number of training samples: 1213
# Performance: {'f1_score': 0.7845197255574613}
# Active learning iteration: #9
# 2020-04-01 06:56:18,188 - biomed_ie - INFO - Number of training samples: 1243
# Performance: {'f1_score': 0.7880154639175257}
# Active learning iteration: #10
# 2020-04-01 06:56:22,099 - biomed_ie - INFO - Number of training samples: 1273
# Performance: {'f1_score': 0.7881847475832439}
# Active learning iteration: #11
# 2020-04-01 06:56:25,886 - biomed_ie - INFO - Number of training samples: 1303
# Performance: {'f1_score': 0.7894680279419667}
# Active learning iteration: #12
# 2020-04-01 06:56:29,760 - biomed_ie - INFO - Number of training samples: 1333
# Performance: {'f1_score': 0.7911283376399655}
# Active learning iteration: #13
# 2020-04-01 06:56:33,829 - biomed_ie - INFO - Number of training samples: 1363
# Performance: {'f1_score': 0.7921965940935546}
# Active learning iteration: #14
# 2020-04-01 06:56:37,835 - biomed_ie - INFO - Number of training samples: 1393
# Performance: {'f1_score': 0.7933081489476524}
# Active learning iteration: #15
# 2020-04-01 06:56:42,082 - biomed_ie - INFO - Number of training samples: 1423
# Performance: {'f1_score': 0.7972812601143598}
# Active learning iteration: #16
# 2020-04-01 06:56:46,239 - biomed_ie - INFO - Number of training samples: 1453
# Performance: {'f1_score': 0.7990074441687345}
# Active learning iteration: #17
# 2020-04-01 06:56:50,599 - biomed_ie - INFO - Number of training samples: 1483
# Performance: {'f1_score': 0.8009918068132815}
# Active learning iteration: #18
# 2020-04-01 06:56:54,936 - biomed_ie - INFO - Number of training samples: 1513
# Performance: {'f1_score': 0.8031104870936385}
# Active learning iteration: #19
# 2020-04-01 06:56:59,133 - biomed_ie - INFO - Number of training samples: 1543
# Performance: {'f1_score': 0.8046967575137348}
# Active learning iteration: #20
# 2020-04-01 06:57:03,518 - biomed_ie - INFO - Number of training samples: 1573
# Performance: {'f1_score': 0.8068206345780271}
# Active learning iteration: #21
# 2020-04-01 06:57:07,906 - biomed_ie - INFO - Number of training samples: 1603
# Performance: {'f1_score': 0.8079370214601531}
# Active learning iteration: #22
# 2020-04-01 06:57:12,248 - biomed_ie - INFO - Number of training samples: 1633
# Performance: {'f1_score': 0.8076301325573877}
# Active learning iteration: #23
# 2020-04-01 06:57:16,730 - biomed_ie - INFO - Number of training samples: 1663
# Performance: {'f1_score': 0.8099084544964997}
# Active learning iteration: #24
# 2020-04-01 06:57:21,339 - biomed_ie - INFO - Number of training samples: 1693
# Performance: {'f1_score': 0.8108981262115011}

# %%
max_samples_number = 30
repeats = 10
active_iterations = 25
N_SAMPLES_PER_AL_ITER = 100

for repeat in range(repeats):
    #task, emb_name, emb, strat_name, strat = experiments_to_try[experiment_id]
    strat_name = 'uncertainty'
    strat = lambda trn_ds, libact_model: UncertaintySampling(trn_ds, model=libact_model, method='lc')

    path = os.path.join('../workdir/experiments/crf/', strat_name)
    if os.path.exists(os.path.join(path, f'statistics{repeat}.json')):
        print(f'statistics{repeat}.json already exists. Next')
        continue

    print('Active learning strategy', strat_name)
    print('Repeat', repeat)

    #X_train, X_test, y_train, y_test, tag_dictionary = load_task(task)
    y_seed = y_train2y_seed(y_train, n_seeds_per_class=200)

    active_tagger = CRF_active(algorithm="lbfgs",
          c1=0.1,
          c2=0.1,
          max_iterations=100,
          all_possible_transitions=True)
    
    active_learn_alg_ctor = make_libact_strategy_ctor(lambda tr_ds: strat(tr_ds, active_tagger), max_samples_number=max_samples_number)
    
    active_learner = ActiveLearner1(active_learn_alg_ctor = active_learn_alg_ctor,
                            y_dtype = 'str',
                            X_full_dataset = X_train, 
                            y_full_dataset = y_seed,
                            X_test_dataset = X_test,
                            y_test_dataset = y_test,
                            model_evaluate=active_tagger,
                            eval_metrics=[f1_score],
                            rnd_start_steps=0,
                            rnd_start_samples=max_samples_number)                

    #statistics = emulate_active_learning2(y_train, active_learner, max_iterations=active_iterations,
    #                                     n_annotations_per_iter=N_SAMPLES_PER_AL_ITER, stats_path='../workdir/logs')
        
    statistics = emulate_active_learning(y_train, active_learner, max_iterations=active_iterations)
    print(statistics)
    dump_file(statistics, path, f'statistics{repeat}.json')
# Out:
# Active learning strategy uncertainty
# Repeat 0
# Start emulating active learning.
# Evaluation: {'f1_score': 0.7731691510045366}
# Active learning iteration: #0
# 2020-03-31 20:18:52,105 - biomed_ie - INFO - Number of training samples: 983
# Performance: {'f1_score': 0.7727567567567568}
# Active learning iteration: #1
# 2020-03-31 20:18:56,945 - biomed_ie - INFO - Number of training samples: 1013
# Performance: {'f1_score': 0.7733218030483191}
# Active learning iteration: #2
# 2020-03-31 20:19:02,000 - biomed_ie - INFO - Number of training samples: 1043
# Performance: {'f1_score': 0.7741237559498054}
# Active learning iteration: #3
# 2020-03-31 20:19:06,973 - biomed_ie - INFO - Number of training samples: 1073
# Performance: {'f1_score': 0.7766107200866269}
# Active learning iteration: #4
# 2020-03-31 20:19:11,826 - biomed_ie - INFO - Number of training samples: 1103
# Performance: {'f1_score': 0.7768254312683086}
# Active learning iteration: #5
# 2020-03-31 20:19:16,666 - biomed_ie - INFO - Number of training samples: 1133
# Performance: {'f1_score': 0.7772223429689198}
# Active learning iteration: #6
# 2020-03-31 20:19:21,446 - biomed_ie - INFO - Number of training samples: 1163
# Performance: {'f1_score': 0.7814267072640279}
# Active learning iteration: #7
# 2020-03-31 20:19:26,243 - biomed_ie - INFO - Number of training samples: 1193
# Performance: {'f1_score': 0.7838278447994783}
# Active learning iteration: #8
# 2020-03-31 20:19:31,219 - biomed_ie - INFO - Number of training samples: 1223
# Performance: {'f1_score': 0.7850609756097561}
# Active learning iteration: #9
# 2020-03-31 20:19:36,133 - biomed_ie - INFO - Number of training samples: 1253
# Performance: {'f1_score': 0.7873981531776207}
# Active learning iteration: #10
# 2020-03-31 20:19:41,176 - biomed_ie - INFO - Number of training samples: 1283
# Performance: {'f1_score': 0.7896855619627897}
# Active learning iteration: #11
# 2020-03-31 20:19:46,162 - biomed_ie - INFO - Number of training samples: 1313
# Performance: {'f1_score': 0.7940408873423227}
# Active learning iteration: #12
# 2020-03-31 20:19:51,082 - biomed_ie - INFO - Number of training samples: 1343
# Performance: {'f1_score': 0.7960490611093021}
# Active learning iteration: #13
# 2020-03-31 20:19:56,127 - biomed_ie - INFO - Number of training samples: 1373
# Performance: {'f1_score': 0.8001303497718879}
# Active learning iteration: #14
# 2020-03-31 20:20:01,109 - biomed_ie - INFO - Number of training samples: 1403
# Performance: {'f1_score': 0.8013446107135112}
# Active learning iteration: #15
# 2020-03-31 20:20:06,173 - biomed_ie - INFO - Number of training samples: 1433
# Performance: {'f1_score': 0.8038173733868345}
# Active learning iteration: #16
# 2020-03-31 20:20:11,323 - biomed_ie - INFO - Number of training samples: 1463
# Performance: {'f1_score': 0.8046425859637705}
# Active learning iteration: #17
# 2020-03-31 20:20:16,400 - biomed_ie - INFO - Number of training samples: 1493
# Performance: {'f1_score': 0.8068231203824424}
# Active learning iteration: #18
# 2020-03-31 20:20:21,479 - biomed_ie - INFO - Number of training samples: 1523
# Performance: {'f1_score': 0.8091669381991963}
# Active learning iteration: #19
# 2020-03-31 20:20:26,733 - biomed_ie - INFO - Number of training samples: 1553
# Performance: {'f1_score': 0.811773650483328}
# Active learning iteration: #20
# 2020-03-31 20:20:31,862 - biomed_ie - INFO - Number of training samples: 1583
# Performance: {'f1_score': 0.8164329964134333}
# Active learning iteration: #21
# 2020-03-31 20:20:37,060 - biomed_ie - INFO - Number of training samples: 1613
# Performance: {'f1_score': 0.8179643323183993}
# Active learning iteration: #22
# 2020-03-31 20:20:42,391 - biomed_ie - INFO - Number of training samples: 1643
# Performance: {'f1_score': 0.8211143695014662}
# Active learning iteration: #23
# 2020-03-31 20:20:47,618 - biomed_ie - INFO - Number of training samples: 1673
# Performance: {'f1_score': 0.8192194803783021}
# Active learning iteration: #24
# 2020-03-31 20:20:53,011 - biomed_ie - INFO - Number of training samples: 1703
# Performance: {'f1_score': 0.8186167899086559}
# [{'f1_score': 0.7727567567567568}, {'f1_score': 0.7733218030483191}, {'f1_score': 0.7741237559498054}, {'f1_score': 0.7766107200866269}, {'f1_score': 0.7768254312683086}, {'f1_score': 0.7772223429689198}, {'f1_score': 0.7814267072640279}, {'f1_score': 0.7838278447994783}, {'f1_score': 0.7850609756097561}, {'f1_score': 0.7873981531776207}, {'f1_score': 0.7896855619627897}, {'f1_score': 0.7940408873423227}, {'f1_score': 0.7960490611093021}, {'f1_score': 0.8001303497718879}, {'f1_score': 0.8013446107135112}, {'f1_score': 0.8038173733868345}, {'f1_score': 0.8046425859637705}, {'f1_score': 0.8068231203824424}, {'f1_score': 0.8091669381991963}, {'f1_score': 0.811773650483328}, {'f1_score': 0.8164329964134333}, {'f1_score': 0.8179643323183993}, {'f1_score': 0.8211143695014662}, {'f1_score': 0.8192194803783021}, {'f1_score': 0.8186167899086559}]
# Active learning strategy uncertainty
# Repeat 1
# Start emulating active learning.
# Evaluation: {'f1_score': 0.7682573726541556}
# Active learning iteration: #0
# 2020-03-31 20:21:01,031 - biomed_ie - INFO - Number of training samples: 973
# Performance: {'f1_score': 0.7701050825648725}
# Active learning iteration: #1
# 2020-03-31 20:21:05,745 - biomed_ie - INFO - Number of training samples: 1003
# Performance: {'f1_score': 0.7719072164948453}
# Active learning iteration: #2
# 2020-03-31 20:21:10,577 - biomed_ie - INFO - Number of training samples: 1033
# Performance: {'f1_score': 0.7756637643770826}
# Active learning iteration: #3
# 2020-03-31 20:21:15,339 - biomed_ie - INFO - Number of training samples: 1063
# Performance: {'f1_score': 0.776594600408734}
# Active learning iteration: #4
# 2020-03-31 20:21:20,153 - biomed_ie - INFO - Number of training samples: 1093
# Performance: {'f1_score': 0.7792573346324565}
# Active learning iteration: #5
# 2020-03-31 20:21:24,976 - biomed_ie - INFO - Number of training samples: 1123
# Performance: {'f1_score': 0.7831729209473344}
# Active learning iteration: #6
# 2020-03-31 20:21:29,827 - biomed_ie - INFO - Number of training samples: 1153
# Performance: {'f1_score': 0.784941583729987}
# Active learning iteration: #7
# 2020-03-31 20:21:34,726 - biomed_ie - INFO - Number of training samples: 1183
# Performance: {'f1_score': 0.7860233665080052}
# Active learning iteration: #8
# 2020-03-31 20:21:39,508 - biomed_ie - INFO - Number of training samples: 1213
# Performance: {'f1_score': 0.7879904617385649}
# Active learning iteration: #9
# 2020-03-31 20:21:44,354 - biomed_ie - INFO - Number of training samples: 1243
# Performance: {'f1_score': 0.7899123281740449}
# Active learning iteration: #10
# 2020-03-31 20:21:49,254 - biomed_ie - INFO - Number of training samples: 1273
# Performance: {'f1_score': 0.7912468854945294}
# Active learning iteration: #11
# 2020-03-31 20:21:54,083 - biomed_ie - INFO - Number of training samples: 1303
# Performance: {'f1_score': 0.7943631436314363}
# Active learning iteration: #12
# 2020-03-31 20:21:58,923 - biomed_ie - INFO - Number of training samples: 1333
# Performance: {'f1_score': 0.7966616084977238}
# Active learning iteration: #13
# 2020-03-31 20:22:03,915 - biomed_ie - INFO - Number of training samples: 1363
# Performance: {'f1_score': 0.7981780717926472}
# Active learning iteration: #14
# 2020-03-31 20:22:08,776 - biomed_ie - INFO - Number of training samples: 1393
# Performance: {'f1_score': 0.7977430555555556}
# Active learning iteration: #15
# 2020-03-31 20:22:13,766 - biomed_ie - INFO - Number of training samples: 1423
# Performance: {'f1_score': 0.794919118445337}
# Active learning iteration: #16
# 2020-03-31 20:22:18,706 - biomed_ie - INFO - Number of training samples: 1453
# Performance: {'f1_score': 0.7980028220992077}
# Active learning iteration: #17
# 2020-03-31 20:22:23,637 - biomed_ie - INFO - Number of training samples: 1483
# Performance: {'f1_score': 0.8010420058612829}
# Active learning iteration: #18
# 2020-03-31 20:22:28,725 - biomed_ie - INFO - Number of training samples: 1513
# Performance: {'f1_score': 0.8043076253671271}
# Active learning iteration: #19
# 2020-03-31 20:22:33,758 - biomed_ie - INFO - Number of training samples: 1543
# Performance: {'f1_score': 0.8061291023690502}
# Active learning iteration: #20
# 2020-03-31 20:22:38,802 - biomed_ie - INFO - Number of training samples: 1573
# Performance: {'f1_score': 0.8068688186066731}
# Active learning iteration: #21
# 2020-03-31 20:22:43,985 - biomed_ie - INFO - Number of training samples: 1603
# Performance: {'f1_score': 0.809352909189777}
# Active learning iteration: #22
# 2020-03-31 20:22:49,038 - biomed_ie - INFO - Number of training samples: 1633
# Performance: {'f1_score': 0.8104759834818518}
# Active learning iteration: #23
# 2020-03-31 20:22:54,116 - biomed_ie - INFO - Number of training samples: 1663
# Performance: {'f1_score': 0.8118682751874797}
# Active learning iteration: #24
# 2020-03-31 20:22:59,397 - biomed_ie - INFO - Number of training samples: 1693
# Performance: {'f1_score': 0.815}
# [{'f1_score': 0.7701050825648725}, {'f1_score': 0.7719072164948453}, {'f1_score': 0.7756637643770826}, {'f1_score': 0.776594600408734}, {'f1_score': 0.7792573346324565}, {'f1_score': 0.7831729209473344}, {'f1_score': 0.784941583729987}, {'f1_score': 0.7860233665080052}, {'f1_score': 0.7879904617385649}, {'f1_score': 0.7899123281740449}, {'f1_score': 0.7912468854945294}, {'f1_score': 0.7943631436314363}, {'f1_score': 0.7966616084977238}, {'f1_score': 0.7981780717926472}, {'f1_score': 0.7977430555555556}, {'f1_score': 0.794919118445337}, {'f1_score': 0.7980028220992077}, {'f1_score': 0.8010420058612829}, {'f1_score': 0.8043076253671271}, {'f1_score': 0.8061291023690502}, {'f1_score': 0.8068688186066731}, {'f1_score': 0.809352909189777}, {'f1_score': 0.8104759834818518}, {'f1_score': 0.8118682751874797}, {'f1_score': 0.815}]
# Active learning strategy uncertainty
# Repeat 2
# Start emulating active learning.
# Evaluation: {'f1_score': 0.7579195205479452}
# Active learning iteration: #0
# 2020-03-31 20:23:07,212 - biomed_ie - INFO - Number of training samples: 971
# Performance: {'f1_score': 0.7616802400342907}
# Active learning iteration: #1
# 2020-03-31 20:23:11,770 - biomed_ie - INFO - Number of training samples: 1001
# Performance: {'f1_score': 0.7624261943102523}
# Active learning iteration: #2
# 2020-03-31 20:23:16,438 - biomed_ie - INFO - Number of training samples: 1031
# Performance: {'f1_score': 0.7629821159232923}
# Active learning iteration: #3
# 2020-03-31 20:23:21,020 - biomed_ie - INFO - Number of training samples: 1061
# Performance: {'f1_score': 0.7678879310344828}
# Active learning iteration: #4
# 2020-03-31 20:23:25,738 - biomed_ie - INFO - Number of training samples: 1091
# Performance: {'f1_score': 0.7710401381096246}
# Active learning iteration: #5
# 2020-03-31 20:23:30,372 - biomed_ie - INFO - Number of training samples: 1121
# Performance: {'f1_score': 0.7730947504581224}
# Active learning iteration: #6
# 2020-03-31 20:23:35,026 - biomed_ie - INFO - Number of training samples: 1151
# Performance: {'f1_score': 0.7757392618173969}
# Active learning iteration: #7
# 2020-03-31 20:23:39,797 - biomed_ie - INFO - Number of training samples: 1181
# Performance: {'f1_score': 0.7771874661173154}
# Active learning iteration: #8
# 2020-03-31 20:23:44,527 - biomed_ie - INFO - Number of training samples: 1211
# Performance: {'f1_score': 0.7791617025885411}
# Active learning iteration: #9
# 2020-03-31 20:23:49,181 - biomed_ie - INFO - Number of training samples: 1241
# Performance: {'f1_score': 0.7794516094071745}
# Active learning iteration: #10
# 2020-03-31 20:23:53,971 - biomed_ie - INFO - Number of training samples: 1271
# Performance: {'f1_score': 0.783982683982684}
# Active learning iteration: #11
# 2020-03-31 20:23:58,708 - biomed_ie - INFO - Number of training samples: 1301
# Performance: {'f1_score': 0.7867042009527934}
# Active learning iteration: #12
# 2020-03-31 20:24:03,488 - biomed_ie - INFO - Number of training samples: 1331
# Performance: {'f1_score': 0.7889033376679669}
# Active learning iteration: #13
# 2020-03-31 20:24:08,375 - biomed_ie - INFO - Number of training samples: 1361
# Performance: {'f1_score': 0.7896334851442205}
# Active learning iteration: #14
# 2020-03-31 20:24:13,162 - biomed_ie - INFO - Number of training samples: 1391
# Performance: {'f1_score': 0.7939262472885033}
# Active learning iteration: #15
# 2020-03-31 20:24:18,105 - biomed_ie - INFO - Number of training samples: 1421
# Performance: {'f1_score': 0.7961375718780513}
# Active learning iteration: #16
# 2020-03-31 20:24:22,962 - biomed_ie - INFO - Number of training samples: 1451
# Performance: {'f1_score': 0.7989171629669736}
# Active learning iteration: #17
# 2020-03-31 20:24:27,818 - biomed_ie - INFO - Number of training samples: 1481
# Performance: {'f1_score': 0.8007380073800737}
# Active learning iteration: #18
# 2020-03-31 20:24:32,898 - biomed_ie - INFO - Number of training samples: 1511
# Performance: {'f1_score': 0.8}
# Active learning iteration: #19
# 2020-03-31 20:24:37,802 - biomed_ie - INFO - Number of training samples: 1541
# Performance: {'f1_score': 0.8035171515414676}
# Active learning iteration: #20
# 2020-03-31 20:24:42,818 - biomed_ie - INFO - Number of training samples: 1571
# Performance: {'f1_score': 0.8041752745460476}
# Active learning iteration: #21
# 2020-03-31 20:24:47,907 - biomed_ie - INFO - Number of training samples: 1601
# Performance: {'f1_score': 0.8049178544228048}
# Active learning iteration: #22
# 2020-03-31 20:24:52,876 - biomed_ie - INFO - Number of training samples: 1631
# Performance: {'f1_score': 0.8069489685124863}
# Active learning iteration: #23
# 2020-03-31 20:24:58,218 - biomed_ie - INFO - Number of training samples: 1661
# Performance: {'f1_score': 0.8073574227252938}
# Active learning iteration: #24
# 2020-03-31 20:25:03,375 - biomed_ie - INFO - Number of training samples: 1691
# Performance: {'f1_score': 0.8051382538645766}
# [{'f1_score': 0.7616802400342907}, {'f1_score': 0.7624261943102523}, {'f1_score': 0.7629821159232923}, {'f1_score': 0.7678879310344828}, {'f1_score': 0.7710401381096246}, {'f1_score': 0.7730947504581224}, {'f1_score': 0.7757392618173969}, {'f1_score': 0.7771874661173154}, {'f1_score': 0.7791617025885411}, {'f1_score': 0.7794516094071745}, {'f1_score': 0.783982683982684}, {'f1_score': 0.7867042009527934}, {'f1_score': 0.7889033376679669}, {'f1_score': 0.7896334851442205}, {'f1_score': 0.7939262472885033}, {'f1_score': 0.7961375718780513}, {'f1_score': 0.7989171629669736}, {'f1_score': 0.8007380073800737}, {'f1_score': 0.8}, {'f1_score': 0.8035171515414676}, {'f1_score': 0.8041752745460476}, {'f1_score': 0.8049178544228048}, {'f1_score': 0.8069489685124863}, {'f1_score': 0.8073574227252938}, {'f1_score': 0.8051382538645766}]
# Active learning strategy uncertainty
# Repeat 3
# Start emulating active learning.
# Evaluation: {'f1_score': 0.7610943558810858}
# Active learning iteration: #0
# 2020-03-31 20:25:11,159 - biomed_ie - INFO - Number of training samples: 958
# Performance: {'f1_score': 0.7609798208697529}
# Active learning iteration: #1
# 2020-03-31 20:25:15,920 - biomed_ie - INFO - Number of training samples: 988
# Performance: {'f1_score': 0.7608038029386344}
# Active learning iteration: #2
# 2020-03-31 20:25:20,603 - biomed_ie - INFO - Number of training samples: 1018
# Performance: {'f1_score': 0.7652719212887878}
# Active learning iteration: #3
# 2020-03-31 20:25:25,244 - biomed_ie - INFO - Number of training samples: 1048
# Performance: {'f1_score': 0.7687817533239651}
# Active learning iteration: #4
# 2020-03-31 20:25:30,080 - biomed_ie - INFO - Number of training samples: 1078
# Performance: {'f1_score': 0.7749540391478318}
# Active learning iteration: #5
# 2020-03-31 20:25:34,796 - biomed_ie - INFO - Number of training samples: 1108
# Performance: {'f1_score': 0.7775256618044301}
# Active learning iteration: #6
# 2020-03-31 20:25:39,601 - biomed_ie - INFO - Number of training samples: 1138
# Performance: {'f1_score': 0.7801081081081082}
# Active learning iteration: #7
# 2020-03-31 20:25:44,346 - biomed_ie - INFO - Number of training samples: 1168
# Performance: {'f1_score': 0.7832485661724921}
# Active learning iteration: #8
# 2020-03-31 20:25:49,138 - biomed_ie - INFO - Number of training samples: 1198
# Performance: {'f1_score': 0.7877409573316007}
# Active learning iteration: #9
# 2020-03-31 20:25:53,999 - biomed_ie - INFO - Number of training samples: 1228
# Performance: {'f1_score': 0.7885949696444058}
# Active learning iteration: #10
# 2020-03-31 20:25:58,771 - biomed_ie - INFO - Number of training samples: 1258
# Performance: {'f1_score': 0.7893483437973586}
# Active learning iteration: #11
# 2020-03-31 20:26:03,599 - biomed_ie - INFO - Number of training samples: 1288
# Performance: {'f1_score': 0.7911515940143135}
# Active learning iteration: #12
# 2020-03-31 20:26:08,521 - biomed_ie - INFO - Number of training samples: 1318
# Performance: {'f1_score': 0.7911873236379423}
# Active learning iteration: #13
# 2020-03-31 20:26:13,420 - biomed_ie - INFO - Number of training samples: 1348
# Performance: {'f1_score': 0.7920104211897525}
# Active learning iteration: #14
# 2020-03-31 20:26:18,313 - biomed_ie - INFO - Number of training samples: 1378
# Performance: {'f1_score': 0.7976979042241286}
# Active learning iteration: #15
# 2020-03-31 20:26:23,280 - biomed_ie - INFO - Number of training samples: 1408
# Performance: {'f1_score': 0.7981352992194276}
# Active learning iteration: #16
# 2020-03-31 20:26:28,210 - biomed_ie - INFO - Number of training samples: 1438
# Performance: {'f1_score': 0.8008676789587853}
# Active learning iteration: #17
# 2020-03-31 20:26:33,130 - biomed_ie - INFO - Number of training samples: 1468
# Performance: {'f1_score': 0.8027801911381407}
# Active learning iteration: #18
# 2020-03-31 20:26:38,166 - biomed_ie - INFO - Number of training samples: 1498
# Performance: {'f1_score': 0.8060869565217392}
# Active learning iteration: #19
# 2020-03-31 20:26:43,159 - biomed_ie - INFO - Number of training samples: 1528
# Performance: {'f1_score': 0.8087003806416531}
# Active learning iteration: #20
# 2020-03-31 20:26:48,180 - biomed_ie - INFO - Number of training samples: 1558
# Performance: {'f1_score': 0.8093114326117697}
# Active learning iteration: #21
# 2020-03-31 20:26:53,255 - biomed_ie - INFO - Number of training samples: 1588
# Performance: {'f1_score': 0.8102229472539425}
# Active learning iteration: #22
# 2020-03-31 20:26:58,318 - biomed_ie - INFO - Number of training samples: 1618
# Performance: {'f1_score': 0.8130983463881636}
# Active learning iteration: #23
# 2020-03-31 20:27:03,484 - biomed_ie - INFO - Number of training samples: 1648
# Performance: {'f1_score': 0.8116352543850093}
# Active learning iteration: #24
# 2020-03-31 20:27:08,698 - biomed_ie - INFO - Number of training samples: 1678
# Performance: {'f1_score': 0.81014035469481}
# [{'f1_score': 0.7609798208697529}, {'f1_score': 0.7608038029386344}, {'f1_score': 0.7652719212887878}, {'f1_score': 0.7687817533239651}, {'f1_score': 0.7749540391478318}, {'f1_score': 0.7775256618044301}, {'f1_score': 0.7801081081081082}, {'f1_score': 0.7832485661724921}, {'f1_score': 0.7877409573316007}, {'f1_score': 0.7885949696444058}, {'f1_score': 0.7893483437973586}, {'f1_score': 0.7911515940143135}, {'f1_score': 0.7911873236379423}, {'f1_score': 0.7920104211897525}, {'f1_score': 0.7976979042241286}, {'f1_score': 0.7981352992194276}, {'f1_score': 0.8008676789587853}, {'f1_score': 0.8027801911381407}, {'f1_score': 0.8060869565217392}, {'f1_score': 0.8087003806416531}, {'f1_score': 0.8093114326117697}, {'f1_score': 0.8102229472539425}, {'f1_score': 0.8130983463881636}, {'f1_score': 0.8116352543850093}, {'f1_score': 0.81014035469481}]
# Active learning strategy uncertainty
# Repeat 4
# Start emulating active learning.
# Evaluation: {'f1_score': 0.7745528542358359}
# Active learning iteration: #0
# 2020-03-31 20:27:16,627 - biomed_ie - INFO - Number of training samples: 972
# Performance: {'f1_score': 0.7778255264288785}
# Active learning iteration: #1
# 2020-03-31 20:27:21,459 - biomed_ie - INFO - Number of training samples: 1002
# Performance: {'f1_score': 0.776989247311828}
# Active learning iteration: #2
# 2020-03-31 20:27:26,207 - biomed_ie - INFO - Number of training samples: 1032
# Performance: {'f1_score': 0.7773706896551724}
# Active learning iteration: #3
# 2020-03-31 20:27:30,976 - biomed_ie - INFO - Number of training samples: 1062
# Performance: {'f1_score': 0.7824024153547552}
# Active learning iteration: #4
# 2020-03-31 20:27:35,783 - biomed_ie - INFO - Number of training samples: 1092
# Performance: {'f1_score': 0.7844530577088716}
# Active learning iteration: #5
# 2020-03-31 20:27:40,548 - biomed_ie - INFO - Number of training samples: 1122
# Performance: {'f1_score': 0.7888900850468296}
# Active learning iteration: #6
# 2020-03-31 20:27:45,468 - biomed_ie - INFO - Number of training samples: 1152
# Performance: {'f1_score': 0.7873557018017047}
# Active learning iteration: #7
# 2020-03-31 20:27:50,296 - biomed_ie - INFO - Number of training samples: 1182
# Performance: {'f1_score': 0.7930513595166163}
# Active learning iteration: #8
# 2020-03-31 20:27:55,093 - biomed_ie - INFO - Number of training samples: 1212
# Performance: {'f1_score': 0.7928355632283124}
# Active learning iteration: #9
# 2020-03-31 20:28:00,123 - biomed_ie - INFO - Number of training samples: 1242
# Performance: {'f1_score': 0.795334269359542}
# Active learning iteration: #10
# 2020-03-31 20:28:04,964 - biomed_ie - INFO - Number of training samples: 1272
# Performance: {'f1_score': 0.7962802768166091}
# Active learning iteration: #11
# 2020-03-31 20:28:09,872 - biomed_ie - INFO - Number of training samples: 1302
# Performance: {'f1_score': 0.7987027027027026}
# Active learning iteration: #12
# 2020-03-31 20:28:14,871 - biomed_ie - INFO - Number of training samples: 1332
# Performance: {'f1_score': 0.7963183540877098}
# Active learning iteration: #13
# 2020-03-31 20:28:19,744 - biomed_ie - INFO - Number of training samples: 1362
# Performance: {'f1_score': 0.7986998916576382}
# Active learning iteration: #14
# 2020-03-31 20:28:24,681 - biomed_ie - INFO - Number of training samples: 1392
# Performance: {'f1_score': 0.8008217993079585}
# Active learning iteration: #15
# 2020-03-31 20:28:29,744 - biomed_ie - INFO - Number of training samples: 1422
# Performance: {'f1_score': 0.803677663601947}
# Active learning iteration: #16
# 2020-03-31 20:28:34,714 - biomed_ie - INFO - Number of training samples: 1452
# Performance: {'f1_score': 0.8068390866789308}
# Active learning iteration: #17
# 2020-03-31 20:28:39,695 - biomed_ie - INFO - Number of training samples: 1482
# Performance: {'f1_score': 0.8105297367565811}
# Active learning iteration: #18
# 2020-03-31 20:28:44,850 - biomed_ie - INFO - Number of training samples: 1512
# Performance: {'f1_score': 0.8141344283553059}
# Active learning iteration: #19
# 2020-03-31 20:28:49,893 - biomed_ie - INFO - Number of training samples: 1542
# Performance: {'f1_score': 0.8163618655989611}
# Active learning iteration: #20
# 2020-03-31 20:28:55,006 - biomed_ie - INFO - Number of training samples: 1572
# Performance: {'f1_score': 0.8179453836150845}
# Active learning iteration: #21
# 2020-03-31 20:29:00,264 - biomed_ie - INFO - Number of training samples: 1602
# Performance: {'f1_score': 0.8192953929539296}
# Active learning iteration: #22
# 2020-03-31 20:29:05,409 - biomed_ie - INFO - Number of training samples: 1632
# Performance: {'f1_score': 0.8187033228704405}
# Active learning iteration: #23
# 2020-03-31 20:29:10,577 - biomed_ie - INFO - Number of training samples: 1662
# Performance: {'f1_score': 0.8201516793066089}
# Active learning iteration: #24
# 2020-03-31 20:29:15,859 - biomed_ie - INFO - Number of training samples: 1692
# Performance: {'f1_score': 0.8208130081300813}
# [{'f1_score': 0.7778255264288785}, {'f1_score': 0.776989247311828}, {'f1_score': 0.7773706896551724}, {'f1_score': 0.7824024153547552}, {'f1_score': 0.7844530577088716}, {'f1_score': 0.7888900850468296}, {'f1_score': 0.7873557018017047}, {'f1_score': 0.7930513595166163}, {'f1_score': 0.7928355632283124}, {'f1_score': 0.795334269359542}, {'f1_score': 0.7962802768166091}, {'f1_score': 0.7987027027027026}, {'f1_score': 0.7963183540877098}, {'f1_score': 0.7986998916576382}, {'f1_score': 0.8008217993079585}, {'f1_score': 0.803677663601947}, {'f1_score': 0.8068390866789308}, {'f1_score': 0.8105297367565811}, {'f1_score': 0.8141344283553059}, {'f1_score': 0.8163618655989611}, {'f1_score': 0.8179453836150845}, {'f1_score': 0.8192953929539296}, {'f1_score': 0.8187033228704405}, {'f1_score': 0.8201516793066089}, {'f1_score': 0.8208130081300813}]
# Active learning strategy uncertainty
# Repeat 5
# Start emulating active learning.
# Evaluation: {'f1_score': 0.7712065616231383}
# Active learning iteration: #0
# 2020-03-31 20:29:23,843 - biomed_ie - INFO - Number of training samples: 980
# Performance: {'f1_score': 0.7704599438566185}
# Active learning iteration: #1
# 2020-03-31 20:29:28,697 - biomed_ie - INFO - Number of training samples: 1010
# Performance: {'f1_score': 0.7719640342324775}
# Active learning iteration: #2
# 2020-03-31 20:29:33,411 - biomed_ie - INFO - Number of training samples: 1040
# Performance: {'f1_score': 0.7729741472952423}
# Active learning iteration: #3
# 2020-03-31 20:29:38,153 - biomed_ie - INFO - Number of training samples: 1070
# Performance: {'f1_score': 0.775505764629106}
# Active learning iteration: #4
# 2020-03-31 20:29:42,943 - biomed_ie - INFO - Number of training samples: 1100
# Performance: {'f1_score': 0.7775485832157203}
# Active learning iteration: #5
# 2020-03-31 20:29:47,701 - biomed_ie - INFO - Number of training samples: 1130
# Performance: {'f1_score': 0.7806360577444914}
# Active learning iteration: #6
# 2020-03-31 20:29:52,440 - biomed_ie - INFO - Number of training samples: 1160
# Performance: {'f1_score': 0.7847606642787366}
# Active learning iteration: #7
# 2020-03-31 20:29:57,337 - biomed_ie - INFO - Number of training samples: 1190
# Performance: {'f1_score': 0.7850609756097561}
# Active learning iteration: #8
# 2020-03-31 20:30:02,154 - biomed_ie - INFO - Number of training samples: 1220
# Performance: {'f1_score': 0.7867639055186676}
# Active learning iteration: #9
# 2020-03-31 20:30:06,897 - biomed_ie - INFO - Number of training samples: 1250
# Performance: {'f1_score': 0.7882480957562569}
# Active learning iteration: #10
# 2020-03-31 20:30:11,843 - biomed_ie - INFO - Number of training samples: 1280
# Performance: {'f1_score': 0.7921936327954646}
# Active learning iteration: #11
# 2020-03-31 20:30:16,709 - biomed_ie - INFO - Number of training samples: 1310
# Performance: {'f1_score': 0.7985634998367613}
# Active learning iteration: #12
# 2020-03-31 20:30:21,572 - biomed_ie - INFO - Number of training samples: 1340
# Performance: {'f1_score': 0.7995635570103655}
# Active learning iteration: #13
# 2020-03-31 20:30:26,532 - biomed_ie - INFO - Number of training samples: 1370
# Performance: {'f1_score': 0.8014408907324528}
# Active learning iteration: #14
# 2020-03-31 20:30:31,446 - biomed_ie - INFO - Number of training samples: 1400
# Performance: {'f1_score': 0.8039279869067103}
# Active learning iteration: #15
# 2020-03-31 20:30:36,449 - biomed_ie - INFO - Number of training samples: 1430
# Performance: {'f1_score': 0.8053647366699379}
# Active learning iteration: #16
# 2020-03-31 20:30:41,456 - biomed_ie - INFO - Number of training samples: 1460
# Performance: {'f1_score': 0.8047982551799346}
# Active learning iteration: #17
# 2020-03-31 20:30:46,478 - biomed_ie - INFO - Number of training samples: 1490
# Performance: {'f1_score': 0.8060579646981914}
# Active learning iteration: #18
# 2020-03-31 20:30:51,636 - biomed_ie - INFO - Number of training samples: 1520
# Performance: {'f1_score': 0.8072394243349325}
# Active learning iteration: #19
# 2020-03-31 20:30:56,940 - biomed_ie - INFO - Number of training samples: 1550
# Performance: {'f1_score': 0.8117711171662125}
# Active learning iteration: #20
# 2020-03-31 20:31:01,968 - biomed_ie - INFO - Number of training samples: 1580
# Performance: {'f1_score': 0.813732970027248}
# Active learning iteration: #21
# 2020-03-31 20:31:07,102 - biomed_ie - INFO - Number of training samples: 1610
# Performance: {'f1_score': 0.8147100424328148}
# Active learning iteration: #22
# 2020-03-31 20:31:12,189 - biomed_ie - INFO - Number of training samples: 1640
# Performance: {'f1_score': 0.81618446813139}
# Active learning iteration: #23
# 2020-03-31 20:31:17,323 - biomed_ie - INFO - Number of training samples: 1670
# Performance: {'f1_score': 0.8180137060807137}
# Active learning iteration: #24
# 2020-03-31 20:31:22,643 - biomed_ie - INFO - Number of training samples: 1700
# Performance: {'f1_score': 0.815210285465243}
# [{'f1_score': 0.7704599438566185}, {'f1_score': 0.7719640342324775}, {'f1_score': 0.7729741472952423}, {'f1_score': 0.775505764629106}, {'f1_score': 0.7775485832157203}, {'f1_score': 0.7806360577444914}, {'f1_score': 0.7847606642787366}, {'f1_score': 0.7850609756097561}, {'f1_score': 0.7867639055186676}, {'f1_score': 0.7882480957562569}, {'f1_score': 0.7921936327954646}, {'f1_score': 0.7985634998367613}, {'f1_score': 0.7995635570103655}, {'f1_score': 0.8014408907324528}, {'f1_score': 0.8039279869067103}, {'f1_score': 0.8053647366699379}, {'f1_score': 0.8047982551799346}, {'f1_score': 0.8060579646981914}, {'f1_score': 0.8072394243349325}, {'f1_score': 0.8117711171662125}, {'f1_score': 0.813732970027248}, {'f1_score': 0.8147100424328148}, {'f1_score': 0.81618446813139}, {'f1_score': 0.8180137060807137}, {'f1_score': 0.815210285465243}]
# Active learning strategy uncertainty
# Repeat 6
# Start emulating active learning.
# Evaluation: {'f1_score': 0.7660352991820921}
# Active learning iteration: #0
# 2020-03-31 20:31:30,550 - biomed_ie - INFO - Number of training samples: 981
# Performance: {'f1_score': 0.7658978228066394}
# Active learning iteration: #1
# 2020-03-31 20:31:35,282 - biomed_ie - INFO - Number of training samples: 1011
# Performance: {'f1_score': 0.7664619032223299}
# Active learning iteration: #2
# 2020-03-31 20:31:39,920 - biomed_ie - INFO - Number of training samples: 1041
# Performance: {'f1_score': 0.7723392760669907}
# Active learning iteration: #3
# 2020-03-31 20:31:44,565 - biomed_ie - INFO - Number of training samples: 1071
# Performance: {'f1_score': 0.7761194029850745}
# Active learning iteration: #4
# 2020-03-31 20:31:49,398 - biomed_ie - INFO - Number of training samples: 1101
# Performance: {'f1_score': 0.7798918918918919}
# Active learning iteration: #5
# 2020-03-31 20:31:54,095 - biomed_ie - INFO - Number of training samples: 1131
# Performance: {'f1_score': 0.7809152872444011}
# Active learning iteration: #6
# 2020-03-31 20:31:58,969 - biomed_ie - INFO - Number of training samples: 1161
# Performance: {'f1_score': 0.7828534314786751}
# Active learning iteration: #7
# 2020-03-31 20:32:03,757 - biomed_ie - INFO - Number of training samples: 1191
# Performance: {'f1_score': 0.7880234324148406}
# Active learning iteration: #8
# 2020-03-31 20:32:08,503 - biomed_ie - INFO - Number of training samples: 1221
# Performance: {'f1_score': 0.791065813726553}
# Active learning iteration: #9
# 2020-03-31 20:32:13,383 - biomed_ie - INFO - Number of training samples: 1251
# Performance: {'f1_score': 0.7902998809137165}
# Active learning iteration: #10
# 2020-03-31 20:32:18,171 - biomed_ie - INFO - Number of training samples: 1281
# Performance: {'f1_score': 0.7922851879943658}
# Active learning iteration: #11
# 2020-03-31 20:32:22,972 - biomed_ie - INFO - Number of training samples: 1311
# Performance: {'f1_score': 0.7929391379683777}
# Active learning iteration: #12
# 2020-03-31 20:32:27,913 - biomed_ie - INFO - Number of training samples: 1341
# Performance: {'f1_score': 0.7960112724907867}
# Active learning iteration: #13
# 2020-03-31 20:32:32,757 - biomed_ie - INFO - Number of training samples: 1371
# Performance: {'f1_score': 0.8002171552660153}
# Active learning iteration: #14
# 2020-03-31 20:32:37,605 - biomed_ie - INFO - Number of training samples: 1401
# Performance: {'f1_score': 0.7993045745952407}
# Active learning iteration: #15
# 2020-03-31 20:32:42,606 - biomed_ie - INFO - Number of training samples: 1431
# Performance: {'f1_score': 0.8048621662687215}
# Active learning iteration: #16
# 2020-03-31 20:32:47,531 - biomed_ie - INFO - Number of training samples: 1461
# Performance: {'f1_score': 0.8043903499239297}
# Active learning iteration: #17
# 2020-03-31 20:32:52,442 - biomed_ie - INFO - Number of training samples: 1491
# Performance: {'f1_score': 0.8048727430933217}
# Active learning iteration: #18
# 2020-03-31 20:32:57,452 - biomed_ie - INFO - Number of training samples: 1521
# Performance: {'f1_score': 0.8076923076923078}
# Active learning iteration: #19
# 2020-03-31 20:33:02,420 - biomed_ie - INFO - Number of training samples: 1551
# Performance: {'f1_score': 0.8089643167972149}
# Active learning iteration: #20
# 2020-03-31 20:33:07,507 - biomed_ie - INFO - Number of training samples: 1581
# Performance: {'f1_score': 0.812683244651971}
# Active learning iteration: #21
# 2020-03-31 20:33:12,700 - biomed_ie - INFO - Number of training samples: 1611
# Performance: {'f1_score': 0.8138725809958687}
# Active learning iteration: #22
# 2020-03-31 20:33:17,744 - biomed_ie - INFO - Number of training samples: 1641
# Performance: {'f1_score': 0.8129004234987511}
# Active learning iteration: #23
# 2020-03-31 20:33:22,947 - biomed_ie - INFO - Number of training samples: 1671
# Performance: {'f1_score': 0.8141785364792867}
# Active learning iteration: #24
# 2020-03-31 20:33:28,066 - biomed_ie - INFO - Number of training samples: 1701
# Performance: {'f1_score': 0.8189730200174064}
# [{'f1_score': 0.7658978228066394}, {'f1_score': 0.7664619032223299}, {'f1_score': 0.7723392760669907}, {'f1_score': 0.7761194029850745}, {'f1_score': 0.7798918918918919}, {'f1_score': 0.7809152872444011}, {'f1_score': 0.7828534314786751}, {'f1_score': 0.7880234324148406}, {'f1_score': 0.791065813726553}, {'f1_score': 0.7902998809137165}, {'f1_score': 0.7922851879943658}, {'f1_score': 0.7929391379683777}, {'f1_score': 0.7960112724907867}, {'f1_score': 0.8002171552660153}, {'f1_score': 0.7993045745952407}, {'f1_score': 0.8048621662687215}, {'f1_score': 0.8043903499239297}, {'f1_score': 0.8048727430933217}, {'f1_score': 0.8076923076923078}, {'f1_score': 0.8089643167972149}, {'f1_score': 0.812683244651971}, {'f1_score': 0.8138725809958687}, {'f1_score': 0.8129004234987511}, {'f1_score': 0.8141785364792867}, {'f1_score': 0.8189730200174064}]
# Active learning strategy uncertainty
# Repeat 7
# Start emulating active learning.
# Evaluation: {'f1_score': 0.7564088812613965}
# Active learning iteration: #0
# 2020-03-31 20:33:36,048 - biomed_ie - INFO - Number of training samples: 971
# Performance: {'f1_score': 0.7585539057456424}
# Active learning iteration: #1
# 2020-03-31 20:33:40,763 - biomed_ie - INFO - Number of training samples: 1001
# Performance: {'f1_score': 0.7563785122187535}
# Active learning iteration: #2
# 2020-03-31 20:33:45,483 - biomed_ie - INFO - Number of training samples: 1031
# Performance: {'f1_score': 0.7552778974579922}
# Active learning iteration: #3
# 2020-03-31 20:33:50,287 - biomed_ie - INFO - Number of training samples: 1061
# Performance: {'f1_score': 0.7637888399096872}
# Active learning iteration: #4
# 2020-03-31 20:33:55,007 - biomed_ie - INFO - Number of training samples: 1091
# Performance: {'f1_score': 0.7664335664335664}
# Active learning iteration: #5
# 2020-03-31 20:33:59,825 - biomed_ie - INFO - Number of training samples: 1121
# Performance: {'f1_score': 0.7670760611937082}
# Active learning iteration: #6
# 2020-03-31 20:34:04,625 - biomed_ie - INFO - Number of training samples: 1151
# Performance: {'f1_score': 0.771198280494358}
# Active learning iteration: #7
# 2020-03-31 20:34:09,432 - biomed_ie - INFO - Number of training samples: 1181
# Performance: {'f1_score': 0.7748443872075552}
# Active learning iteration: #8
# 2020-03-31 20:34:14,219 - biomed_ie - INFO - Number of training samples: 1211
# Performance: {'f1_score': 0.7778375470683162}
# Active learning iteration: #9
# 2020-03-31 20:34:19,168 - biomed_ie - INFO - Number of training samples: 1241
# Performance: {'f1_score': 0.7778855480116392}
# Active learning iteration: #10
# 2020-03-31 20:34:23,957 - biomed_ie - INFO - Number of training samples: 1271
# Performance: {'f1_score': 0.7795403043056006}
# Active learning iteration: #11
# 2020-03-31 20:34:28,809 - biomed_ie - INFO - Number of training samples: 1301
# Performance: {'f1_score': 0.7770700636942676}
# Active learning iteration: #12
# 2020-03-31 20:34:33,808 - biomed_ie - INFO - Number of training samples: 1331
# Performance: {'f1_score': 0.7793640493186242}
# Active learning iteration: #13
# 2020-03-31 20:34:38,709 - biomed_ie - INFO - Number of training samples: 1361
# Performance: {'f1_score': 0.7837925445705025}
# Active learning iteration: #14
# 2020-03-31 20:34:43,674 - biomed_ie - INFO - Number of training samples: 1391
# Performance: {'f1_score': 0.7864707153663282}
# Active learning iteration: #15
# 2020-03-31 20:34:48,721 - biomed_ie - INFO - Number of training samples: 1421
# Performance: {'f1_score': 0.787073065283182}
# Active learning iteration: #16
# 2020-03-31 20:34:53,653 - biomed_ie - INFO - Number of training samples: 1451
# Performance: {'f1_score': 0.7877935288388702}
# Active learning iteration: #17
# 2020-03-31 20:34:58,749 - biomed_ie - INFO - Number of training samples: 1481
# Performance: {'f1_score': 0.7864876569943698}
# Active learning iteration: #18
# 2020-03-31 20:35:03,740 - biomed_ie - INFO - Number of training samples: 1511
# Performance: {'f1_score': 0.7893085163943296}
# Active learning iteration: #19
# 2020-03-31 20:35:08,740 - biomed_ie - INFO - Number of training samples: 1541
# Performance: {'f1_score': 0.7918110918544194}
# Active learning iteration: #20
# 2020-03-31 20:35:13,843 - biomed_ie - INFO - Number of training samples: 1571
# Performance: {'f1_score': 0.7984848484848485}
# Active learning iteration: #21
# 2020-03-31 20:35:18,903 - biomed_ie - INFO - Number of training samples: 1601
# Performance: {'f1_score': 0.7988306626245127}
# Active learning iteration: #22
# 2020-03-31 20:35:23,982 - biomed_ie - INFO - Number of training samples: 1631
# Performance: {'f1_score': 0.8}
# Active learning iteration: #23
# 2020-03-31 20:35:29,187 - biomed_ie - INFO - Number of training samples: 1661
# Performance: {'f1_score': 0.8043832049473799}
# Active learning iteration: #24
# 2020-03-31 20:35:34,325 - biomed_ie - INFO - Number of training samples: 1691
# Performance: {'f1_score': 0.8081269013472403}
# [{'f1_score': 0.7585539057456424}, {'f1_score': 0.7563785122187535}, {'f1_score': 0.7552778974579922}, {'f1_score': 0.7637888399096872}, {'f1_score': 0.7664335664335664}, {'f1_score': 0.7670760611937082}, {'f1_score': 0.771198280494358}, {'f1_score': 0.7748443872075552}, {'f1_score': 0.7778375470683162}, {'f1_score': 0.7778855480116392}, {'f1_score': 0.7795403043056006}, {'f1_score': 0.7770700636942676}, {'f1_score': 0.7793640493186242}, {'f1_score': 0.7837925445705025}, {'f1_score': 0.7864707153663282}, {'f1_score': 0.787073065283182}, {'f1_score': 0.7877935288388702}, {'f1_score': 0.7864876569943698}, {'f1_score': 0.7893085163943296}, {'f1_score': 0.7918110918544194}, {'f1_score': 0.7984848484848485}, {'f1_score': 0.7988306626245127}, {'f1_score': 0.8}, {'f1_score': 0.8043832049473799}, {'f1_score': 0.8081269013472403}]
# Active learning strategy uncertainty
# Repeat 8
# Start emulating active learning.
# Evaluation: {'f1_score': 0.7610903260288615}
# Active learning iteration: #0
# 2020-03-31 20:35:42,201 - biomed_ie - INFO - Number of training samples: 967
# Performance: {'f1_score': 0.76077424874345}
# Active learning iteration: #1
# 2020-03-31 20:35:46,975 - biomed_ie - INFO - Number of training samples: 997
# Performance: {'f1_score': 0.7644473035273935}
# Active learning iteration: #2
# 2020-03-31 20:35:51,662 - biomed_ie - INFO - Number of training samples: 1027
# Performance: {'f1_score': 0.7675118177911475}
# Active learning iteration: #3
# 2020-03-31 20:35:56,441 - biomed_ie - INFO - Number of training samples: 1057
# Performance: {'f1_score': 0.7668672110012892}
# Active learning iteration: #4
# 2020-03-31 20:36:01,176 - biomed_ie - INFO - Number of training samples: 1087
# Performance: {'f1_score': 0.7711335771133578}
# Active learning iteration: #5
# 2020-03-31 20:36:05,891 - biomed_ie - INFO - Number of training samples: 1117
# Performance: {'f1_score': 0.7731416925882226}
# Active learning iteration: #6
# 2020-03-31 20:36:10,718 - biomed_ie - INFO - Number of training samples: 1147
# Performance: {'f1_score': 0.7820677820677819}
# Active learning iteration: #7
# 2020-03-31 20:36:15,434 - biomed_ie - INFO - Number of training samples: 1177
# Performance: {'f1_score': 0.78453276047261}
# Active learning iteration: #8
# 2020-03-31 20:36:20,188 - biomed_ie - INFO - Number of training samples: 1207
# Performance: {'f1_score': 0.783760499676933}
# Active learning iteration: #9
# 2020-03-31 20:36:25,024 - biomed_ie - INFO - Number of training samples: 1237
# Performance: {'f1_score': 0.7881136950904393}
# Active learning iteration: #10
# 2020-03-31 20:36:29,828 - biomed_ie - INFO - Number of training samples: 1267
# Performance: {'f1_score': 0.7884076707606119}
# Active learning iteration: #11
# 2020-03-31 20:36:34,644 - biomed_ie - INFO - Number of training samples: 1297
# Performance: {'f1_score': 0.7909433962264151}
# Active learning iteration: #12
# 2020-03-31 20:36:39,624 - biomed_ie - INFO - Number of training samples: 1327
# Performance: {'f1_score': 0.78866257139778}
# Active learning iteration: #13
# 2020-03-31 20:36:44,472 - biomed_ie - INFO - Number of training samples: 1357
# Performance: {'f1_score': 0.7918059299191375}
# Active learning iteration: #14
# 2020-03-31 20:36:49,302 - biomed_ie - INFO - Number of training samples: 1387
# Performance: {'f1_score': 0.7914461604924938}
# Active learning iteration: #15
# 2020-03-31 20:36:54,290 - biomed_ie - INFO - Number of training samples: 1417
# Performance: {'f1_score': 0.7919231184537306}
# Active learning iteration: #16
# 2020-03-31 20:36:59,170 - biomed_ie - INFO - Number of training samples: 1447
# Performance: {'f1_score': 0.7924813654531706}
# Active learning iteration: #17
# 2020-03-31 20:37:04,173 - biomed_ie - INFO - Number of training samples: 1477
# Performance: {'f1_score': 0.7968446077371948}
# Active learning iteration: #18
# 2020-03-31 20:37:09,095 - biomed_ie - INFO - Number of training samples: 1507
# Performance: {'f1_score': 0.7990058353144587}
# Active learning iteration: #19
# 2020-03-31 20:37:14,051 - biomed_ie - INFO - Number of training samples: 1537
# Performance: {'f1_score': 0.7979688850475368}
# Active learning iteration: #20
# 2020-03-31 20:37:19,150 - biomed_ie - INFO - Number of training samples: 1567
# Performance: {'f1_score': 0.8028960449535336}
# Active learning iteration: #21
# 2020-03-31 20:37:24,145 - biomed_ie - INFO - Number of training samples: 1597
# Performance: {'f1_score': 0.8049729729729729}
# Active learning iteration: #22
# 2020-03-31 20:37:29,271 - biomed_ie - INFO - Number of training samples: 1627
# Performance: {'f1_score': 0.8059217635617032}
# Active learning iteration: #23
# 2020-03-31 20:37:34,409 - biomed_ie - INFO - Number of training samples: 1657
# Performance: {'f1_score': 0.8052313013402508}
# Active learning iteration: #24
# 2020-03-31 20:37:39,492 - biomed_ie - INFO - Number of training samples: 1687
# Performance: {'f1_score': 0.8062283737024222}
# [{'f1_score': 0.76077424874345}, {'f1_score': 0.7644473035273935}, {'f1_score': 0.7675118177911475}, {'f1_score': 0.7668672110012892}, {'f1_score': 0.7711335771133578}, {'f1_score': 0.7731416925882226}, {'f1_score': 0.7820677820677819}, {'f1_score': 0.78453276047261}, {'f1_score': 0.783760499676933}, {'f1_score': 0.7881136950904393}, {'f1_score': 0.7884076707606119}, {'f1_score': 0.7909433962264151}, {'f1_score': 0.78866257139778}, {'f1_score': 0.7918059299191375}, {'f1_score': 0.7914461604924938}, {'f1_score': 0.7919231184537306}, {'f1_score': 0.7924813654531706}, {'f1_score': 0.7968446077371948}, {'f1_score': 0.7990058353144587}, {'f1_score': 0.7979688850475368}, {'f1_score': 0.8028960449535336}, {'f1_score': 0.8049729729729729}, {'f1_score': 0.8059217635617032}, {'f1_score': 0.8052313013402508}, {'f1_score': 0.8062283737024222}]
# Active learning strategy uncertainty
# Repeat 9
# Start emulating active learning.
# Evaluation: {'f1_score': 0.7667992688958176}
# Active learning iteration: #0
# 2020-03-31 20:37:47,441 - biomed_ie - INFO - Number of training samples: 973
# Performance: {'f1_score': 0.7677725118483413}
# Active learning iteration: #1
# 2020-03-31 20:37:52,105 - biomed_ie - INFO - Number of training samples: 1003
# Performance: {'f1_score': 0.7695455524445403}
# Active learning iteration: #2
# 2020-03-31 20:37:56,747 - biomed_ie - INFO - Number of training samples: 1033
# Performance: {'f1_score': 0.7697779693899547}
# Active learning iteration: #3
# 2020-03-31 20:38:01,538 - biomed_ie - INFO - Number of training samples: 1063
# Performance: {'f1_score': 0.7684017674318353}
# Active learning iteration: #4
# 2020-03-31 20:38:06,262 - biomed_ie - INFO - Number of training samples: 1093
# Performance: {'f1_score': 0.7683518378786245}
# Active learning iteration: #5
# 2020-03-31 20:38:10,939 - biomed_ie - INFO - Number of training samples: 1123
# Performance: {'f1_score': 0.7716569453445669}
# Active learning iteration: #6
# 2020-03-31 20:38:15,751 - biomed_ie - INFO - Number of training samples: 1153
# Performance: {'f1_score': 0.7749756467150124}
# Active learning iteration: #7
# 2020-03-31 20:38:20,469 - biomed_ie - INFO - Number of training samples: 1183
# Performance: {'f1_score': 0.7778258050572725}
# Active learning iteration: #8
# 2020-03-31 20:38:25,230 - biomed_ie - INFO - Number of training samples: 1213
# Performance: {'f1_score': 0.7841524139424118}
# Active learning iteration: #9
# 2020-03-31 20:38:30,125 - biomed_ie - INFO - Number of training samples: 1243
# Performance: {'f1_score': 0.7859770612421553}
# Active learning iteration: #10
# 2020-03-31 20:38:34,925 - biomed_ie - INFO - Number of training samples: 1273
# Performance: {'f1_score': 0.7917253330445143}
# Active learning iteration: #11
# 2020-03-31 20:38:39,711 - biomed_ie - INFO - Number of training samples: 1303
# Performance: {'f1_score': 0.7935889105479749}
# Active learning iteration: #12
# 2020-03-31 20:38:44,669 - biomed_ie - INFO - Number of training samples: 1333
# Performance: {'f1_score': 0.7949356130288929}
# Active learning iteration: #13
# 2020-03-31 20:38:49,496 - biomed_ie - INFO - Number of training samples: 1363
# Performance: {'f1_score': 0.7967426710097718}
# Active learning iteration: #14
# 2020-03-31 20:38:54,466 - biomed_ie - INFO - Number of training samples: 1393
# Performance: {'f1_score': 0.8016079965232507}
# Active learning iteration: #15
# 2020-03-31 20:38:59,325 - biomed_ie - INFO - Number of training samples: 1423
# Performance: {'f1_score': 0.8014338474907668}
# Active learning iteration: #16
# 2020-03-31 20:39:04,256 - biomed_ie - INFO - Number of training samples: 1453
# Performance: {'f1_score': 0.8065111231687465}
# Active learning iteration: #17
# 2020-03-31 20:39:09,246 - biomed_ie - INFO - Number of training samples: 1483
# Performance: {'f1_score': 0.8063326827152462}
# Active learning iteration: #18
# 2020-03-31 20:39:14,159 - biomed_ie - INFO - Number of training samples: 1513
# Performance: {'f1_score': 0.8088012139605462}
# Active learning iteration: #19
# 2020-03-31 20:39:19,074 - biomed_ie - INFO - Number of training samples: 1543
# Performance: {'f1_score': 0.8092811449636779}
# Active learning iteration: #20
# 2020-03-31 20:39:24,150 - biomed_ie - INFO - Number of training samples: 1573
# Performance: {'f1_score': 0.8104121475054229}
# Active learning iteration: #21
# 2020-03-31 20:39:29,187 - biomed_ie - INFO - Number of training samples: 1603
# Performance: {'f1_score': 0.8082563824008692}
# Active learning iteration: #22
# 2020-03-31 20:39:34,207 - biomed_ie - INFO - Number of training samples: 1633
# Performance: {'f1_score': 0.812459301063599}
# Active learning iteration: #23
# 2020-03-31 20:39:39,328 - biomed_ie - INFO - Number of training samples: 1663
# Performance: {'f1_score': 0.8137691388858725}
# Active learning iteration: #24
# 2020-03-31 20:39:44,474 - biomed_ie - INFO - Number of training samples: 1693
# Performance: {'f1_score': 0.8151525018994897}
# [{'f1_score': 0.7677725118483413}, {'f1_score': 0.7695455524445403}, {'f1_score': 0.7697779693899547}, {'f1_score': 0.7684017674318353}, {'f1_score': 0.7683518378786245}, {'f1_score': 0.7716569453445669}, {'f1_score': 0.7749756467150124}, {'f1_score': 0.7778258050572725}, {'f1_score': 0.7841524139424118}, {'f1_score': 0.7859770612421553}, {'f1_score': 0.7917253330445143}, {'f1_score': 0.7935889105479749}, {'f1_score': 0.7949356130288929}, {'f1_score': 0.7967426710097718}, {'f1_score': 0.8016079965232507}, {'f1_score': 0.8014338474907668}, {'f1_score': 0.8065111231687465}, {'f1_score': 0.8063326827152462}, {'f1_score': 0.8088012139605462}, {'f1_score': 0.8092811449636779}, {'f1_score': 0.8104121475054229}, {'f1_score': 0.8082563824008692}, {'f1_score': 0.812459301063599}, {'f1_score': 0.8137691388858725}, {'f1_score': 0.8151525018994897}]

# %% [markdown]
# ## Plotting results

# %%
# %matplotlib inline

# %%
from itertools import cycle
from matplotlib import pyplot as plt
import os
import json
import numpy as np


def generate_plot(np_stats, color_bg, color_line, marker, label, metric_dim=0):
    if len(np_stats.shape) > 2:
        np_stats = np_stats[:, :, metric_dim]
    
    disp = np_stats.std(axis=0)
    means = np_stats.mean(axis=0)
    
    x = list(range(1, means.shape[0] + 1))

    line_thikness = 0.5
    plt.fill_between(x, means - disp, means + disp, color=color_bg, alpha=0.5)
    plt.xticks(range(1, means.shape[0] + 2, 2))
    return plt.plot(x, means, color=color_line, label=label, 
                    marker=marker, linewidth=line_thikness)


def create_chart(expert_dir, attr_type, metric_dim=0, save_dir=None):
    fig = plt.figure(num=None, figsize=(8, 6), 
                     dpi=200, facecolor='w', edgecolor='k')
    plt_list = []
    
    color_pool = cycle([('red', 'darksalmon', 'o'), 
                        ('midnightblue', 'skyblue', 'v'), 
                        ('g', 'lightgreen', 's'), 
                        #('gold', 'palegoldenrod', '*'),
                        ('maroon', 'rosybrown', '*'),
                        ('purple', 'violet', '+'),
                        ('slategrey', 'lightgrey', '1'),
                        ('darkorange', 'wheat', 's'),
                        ('darkcyan', 'lightcyan', 'P')])
    

    for stratname in sorted(os.listdir(expert_dir)):
        #noext = os.path.splitext(filename)[0]
        #if '.' in noext:
            #continue
        
        #f_strat = noext
        
        all_stats = []
        
        color = next(color_pool)
        folder_path = os.path.join(expert_dir, stratname)
        print(folder_path)
        for file in sorted(os.listdir(folder_path))[1:]:
            file_path = os.path.join(folder_path, file)
            #print(file_path)
            with open(file_path) as f:
                stats = np.array([np.array(stat['f1_score']) for stat in json.load(f)])
            all_stats.append(stats)
        
        chart, = generate_plot(np.array(all_stats), 
                                   color_bg=color[1], 
                                   color_line=color[0], 
                                   marker=color[2],
                                   label=stratname,
                                   metric_dim=metric_dim)
        plt_list.append(chart)
        
    plt.legend(handles=plt_list, loc='lower right', fontsize='x-large')
    plt.ylabel('Performance, F1', fontdict={'size' : 15})
    plt.xlabel('AL iteration, #', fontdict={'size' : 15})
    plt.tick_params(labelsize=12)
    
    if save_dir is not None:
        plt.savefig(os.path.join(save_dir, f'{attr_type}.png'))
        
    plt.show()

# %%
#from generate_chart import create_chart
create_chart('../workdir/experiments/crf', 'crf', save_dir='../workdir/')
# Out:
# ../workdir/experiments/crf/random
# ../workdir/experiments/crf/uncertainty

# %%
create_chart('../workdir/experiments/crf_10', 'crf_10', save_dir='../workdir/')
# Out:
# ../workdir/experiments/crf_10/random
# ../workdir/experiments/crf_10/uncertainty

# %%
#from generate_chart import create_chart
create_chart('../workdir/experiments/crf/uncertainty', 'genia', save_dir='../workdir/')

# %%
max_samples_number = 100
repeats = 10
active_iterations = 60
N_SAMPLES_PER_AL_ITER = 100

for repeat in range(repeats):
    #task, emb_name, emb, strat_name, strat = experiments_to_try[experiment_id]
    strat_name = 'uncertainty'
    strat = lambda trn_ds, libact_model: UncertaintySampling(trn_ds, model=libact_model, method='lc')

    #path = os.path.join(models_path, task, emb_name, strat_name)
    #if os.path.exists(os.path.join(path, f'statistics{repeat}.json')):
        #print(f'statistics{repeat}.json already exists. Next')
        #continue

    print('Active learning strategy', strat_name)
    print('Repeat', repeat)

    #X_train, X_test, y_train, y_test, tag_dictionary = load_task(task)
    y_seed = y_train2y_seed(y_train, n_seeds_per_class=200)

    active_tagger = CRF_active(algorithm="lbfgs",
          c1=0.1,
          c2=0.1,
          max_iterations=100,
          all_possible_transitions=True)
    
    active_learn_alg_ctor = make_libact_strategy_ctor(lambda tr_ds: strat(tr_ds, active_tagger), max_samples_number=max_samples_number)
    
    active_learner = ActiveLearner1(active_learn_alg_ctor = active_learn_alg_ctor,
                            y_dtype = 'str',
                            X_full_dataset = X_train, 
                            y_full_dataset = y_seed,
                            X_test_dataset = X_test,
                            y_test_dataset = y_test,
                            model_evaluate=active_tagger,
                            eval_metrics=[f1_score],
                            rnd_start_steps=0,
                            rnd_start_samples=max_samples_number)                

    #statistics = emulate_active_learning2(y_train, active_learner, max_iterations=active_iterations,
    #                                     n_annotations_per_iter=N_SAMPLES_PER_AL_ITER, stats_path='../workdir/logs')
        
    statistics = emulate_active_learning(y_train, active_learner, max_iterations=active_iterations)
    print(statistics)
    #dump_file(statistics, path, f'statistics{repeat}.json')
# Out:
# Active learning strategy uncertainty
# Repeat 0
# Start emulating active learning.
# Evaluation: {'f1_score': 0.7577083111063694}
# Active learning iteration: #0
# 2020-03-25 11:32:22,560 - biomed_ie - INFO - Number of training samples: 1032
# Performance: {'f1_score': 0.7650963597430407}
# Active learning iteration: #1
# 2020-03-25 11:32:27,357 - biomed_ie - INFO - Number of training samples: 1132
# Performance: {'f1_score': 0.7746857204254862}
# Active learning iteration: #2
# 2020-03-25 11:32:32,142 - biomed_ie - INFO - Number of training samples: 1232
# Performance: {'f1_score': 0.7808782176076141}
# Active learning iteration: #3
# 2020-03-25 11:32:36,948 - biomed_ie - INFO - Number of training samples: 1332
# Performance: {'f1_score': 0.7878067235974489}
# Active learning iteration: #4
# 2020-03-25 11:32:41,949 - biomed_ie - INFO - Number of training samples: 1432
# Performance: {'f1_score': 0.7916531516920748}
# Active learning iteration: #5
# 2020-03-25 11:32:46,932 - biomed_ie - INFO - Number of training samples: 1532
# Performance: {'f1_score': 0.7994811371743596}
# Active learning iteration: #6
# 2020-03-25 11:32:51,985 - biomed_ie - INFO - Number of training samples: 1632
# Performance: {'f1_score': 0.8066262451277609}
# Active learning iteration: #7
# 2020-03-25 11:32:57,251 - biomed_ie - INFO - Number of training samples: 1732
# Performance: {'f1_score': 0.8131701505469512}
# Active learning iteration: #8
# 2020-03-25 11:33:02,484 - biomed_ie - INFO - Number of training samples: 1832
# Performance: {'f1_score': 0.8152797316307758}
# Active learning iteration: #9
# 2020-03-25 11:33:07,829 - biomed_ie - INFO - Number of training samples: 1932
# Performance: {'f1_score': 0.8144855253171419}
# Active learning iteration: #10
# 2020-03-25 11:33:13,358 - biomed_ie - INFO - Number of training samples: 2032
# Performance: {'f1_score': 0.8209408194233687}
# Active learning iteration: #11
# 2020-03-25 11:33:18,894 - biomed_ie - INFO - Number of training samples: 2132
# Performance: {'f1_score': 0.8275338753387534}
# Active learning iteration: #12
# 2020-03-25 11:33:24,563 - biomed_ie - INFO - Number of training samples: 2232
# Performance: {'f1_score': 0.8321610215344659}
# Active learning iteration: #13
# 2020-03-25 11:33:30,445 - biomed_ie - INFO - Number of training samples: 2332
# Performance: {'f1_score': 0.8375661947476494}
# Active learning iteration: #14
# 2020-03-25 11:33:36,339 - biomed_ie - INFO - Number of training samples: 2432
# Performance: {'f1_score': 0.8414792387543252}
# Active learning iteration: #15
# 2020-03-25 11:33:42,377 - biomed_ie - INFO - Number of training samples: 2532
# Performance: {'f1_score': 0.8458216367955085}
# Active learning iteration: #16
# 2020-03-25 11:33:48,627 - biomed_ie - INFO - Number of training samples: 2632
# Performance: {'f1_score': 0.8478754459941615}
# Active learning iteration: #17
# 2020-03-25 11:33:55,056 - biomed_ie - INFO - Number of training samples: 2732
# Performance: {'f1_score': 0.8496590540101742}
# Active learning iteration: #18
# 2020-03-25 11:34:01,577 - biomed_ie - INFO - Number of training samples: 2832
# Performance: {'f1_score': 0.8548892490545651}
# Active learning iteration: #19
# 2020-03-25 11:34:08,351 - biomed_ie - INFO - Number of training samples: 2932
# Performance: {'f1_score': 0.8576062277002919}
# Active learning iteration: #20
# 2020-03-25 11:34:15,233 - biomed_ie - INFO - Number of training samples: 3032
# Performance: {'f1_score': 0.8594612138915937}
# Active learning iteration: #21
# 2020-03-25 11:34:22,188 - biomed_ie - INFO - Number of training samples: 3132
# Performance: {'f1_score': 0.8620838737570256}
# Active learning iteration: #22
# 2020-03-25 11:34:29,421 - biomed_ie - INFO - Number of training samples: 3232
# Performance: {'f1_score': 0.8637837837837837}
# Active learning iteration: #23
# 2020-03-25 11:34:36,715 - biomed_ie - INFO - Number of training samples: 3332
# Performance: {'f1_score': 0.8659749243406831}
# Active learning iteration: #24
# 2020-03-25 11:34:44,207 - biomed_ie - INFO - Number of training samples: 3432
# Performance: {'f1_score': 0.8674230145867098}
# Active learning iteration: #25
# 2020-03-25 11:34:52,096 - biomed_ie - INFO - Number of training samples: 3532
# Performance: {'f1_score': 0.8689267976678903}
# Active learning iteration: #26
# 2020-03-25 11:34:59,890 - biomed_ie - INFO - Number of training samples: 3632
# Performance: {'f1_score': 0.8723151645979492}
# Active learning iteration: #27
# 2020-03-25 11:35:07,940 - biomed_ie - INFO - Number of training samples: 3732
# Performance: {'f1_score': 0.8744476775514602}
# Active learning iteration: #28
# 2020-03-25 11:35:16,219 - biomed_ie - INFO - Number of training samples: 3832
# Performance: {'f1_score': 0.8749865170963218}
# Active learning iteration: #29
# 2020-03-25 11:35:24,647 - biomed_ie - INFO - Number of training samples: 3932
# Performance: {'f1_score': 0.8759439050701185}
# Active learning iteration: #30
# 2020-03-25 11:35:33,196 - biomed_ie - INFO - Number of training samples: 4032
# Performance: {'f1_score': 0.8779276848354021}
# Active learning iteration: #31
# 2020-03-25 11:35:42,106 - biomed_ie - INFO - Number of training samples: 4132
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-239-8bff955eef53> in <module>
#      42     #                                     n_annotations_per_iter=N_SAMPLES_PER_AL_ITER, stats_path='../workdir/logs')
#      43
# ---> 44     statistics = emulate_active_learning(y_train, active_learner, max_iterations=active_iterations)
#      45     print(statistics)
#      46     #dump_file(statistics, path, f'statistics{repeat}.json')
#
# <ipython-input-236-88a68fc01935> in emulate_active_learning(train_tags, active_learner, max_iterations, fit_model)
#      13         #print(len(annotations))
#      14         active_learner.make_iteration(samples_to_annotate, annotations)
# ---> 15         perf = active_learner.evaluate(fit_model=True)
#      16         statistics.append(perf)
#      17         print('Performance:', perf)
#
# <ipython-input-231-175883383fb7> in evaluate(self, fit_model)
#      88             logger.info('Number of training samples: {}'.format(len(y_fit)))
#      89
# ---> 90             self._model_evaluate.train(Dataset(self._X_full_dataset, self._y_full_dataset), np.ravel(np.argwhere(np.array(selector) == True)))
#      91
#      92         preds = self._model_evaluate.predict(self._X_test_dataset)
#
# <ipython-input-230-6c3479af82fd> in train(self, libact_dataset, indexes)
#      12
#      13         X, y = libact_dataset.format_sklearn()
# ---> 14         return self.model.fit(X, y)
#      15
#      16     def predict(self, feature, *args, **kwargs):
#
# /opt/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sklearn_crfsuite/estimator.py in fit(self, X, y, X_dev, y_dev)
#     329                 print("")
#     330
# --> 331         trainer.train(self.modelfile.name, holdout=-1 if X_dev is None else 1)
#     332         self.training_log_ = trainer.logparser
#     333         return self
#
# pycrfsuite/_pycrfsuite.pyx in pycrfsuite._pycrfsuite.BaseTrainer.train()
#
# pycrfsuite/_pycrfsuite.pyx in pycrfsuite._pycrfsuite.BaseTrainer._on_message()
#
# pycrfsuite/_pycrfsuite.pyx in pycrfsuite._pycrfsuite.Trainer.message()
#
# /opt/.pyenv/versions/3.7.4/lib/python3.7/site-packages/pycrfsuite/_logparser.py in feed(self, line)
#      23         self.events = []
#      24
# ---> 25     def feed(self, line):
#      26         # if line != '\n':
#      27         self.log.append(line)
#
# KeyboardInterrupt:

# %% [markdown]
# ##
